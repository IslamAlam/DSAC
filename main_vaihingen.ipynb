# %%
import tensorflow as tf
import scipy.misc
import numpy as np
import csv
import os
import matplotlib.pyplot as plt
from active_contours_fast import draw_poly,derivatives_poly,draw_poly_fill
from snake_utils import imrotate, plot_snakes, CNN_B, snake_graph, plot_for_figure
from scipy import interpolate
from skimage.filters import gaussian
import scipy
import time
import math
from PIL import Image, ImageOps
from tensorflow.python.client import timeline

import matplotlib.pyplot as plt


from pathlib import Path

BASE_DIR = Path().resolve()

# %% [markdown]
# from argparse import ArgumentParser
#
# parser = ArgumentParser()
# parser.add_argument("-i", "--datapath", dest="inputdatapath",
#                     help="Enter the path of the dataset report to FILE", metavar="FILE")
# parser.add_argument("-o", "--outputfile", dest="outputfilename",
#                     help="write report to FILE", metavar="FILE")
#
# parser.add_argument("-q", "--quiet",
#                     action="store_false", dest="verbose", default=True,
#                     help="don't print status messages to stdout")
#
# args = parser.parse_args()
# print(args)
# print(args.inputdatapath)
# data_path = str(BASE_DIR.joinpath(str(args.inputdatapath)))  + "/"

# %%
def snake_process (mapE, mapA, mapB, mapK, init_snake):

    for i in range(mapE.shape[3]):
        Du = np.gradient(mapE[:,:,0,i], axis=0)
        Dv = np.gradient(mapE[:,:,0,i], axis=1)
        u = init_snake[:,0:1]
        v = init_snake[:,1:2]
        du = np.zeros(u.shape)
        dv = np.zeros(v.shape)
        snake_hist = []
        snake_hist.append(np.array([u[:, 0], v[:, 0]]).T)
        tic = time.time()
        for j in range(1):
            u, v, du, dv = sess2.run([tf_u, tf_v, tf_du, tf_dv], feed_dict={tf_Du: Du, tf_Dv: Dv,
                                                                               tf_u0: u, tf_v0: v, tf_du0: du, tf_dv0: dv,
                                                                               tf_alpha: mapA[:,:,0,i], tf_beta: mapB[:,:,0,i],
                                                                               tf_kappa: mapK[:,:,0,i]}) #,options=run_options, run_metadata=run_metadata
            snake_hist.append(np.array([u[:, 0], v[:, 0]]).T)

        #print('%.2f' % (time.time() - tic) + ' s snake')

    return np.array([u[:,0],v[:,0]]).T,snake_hist

# %%
#outputfile = inputfile[:-4] + "_features" + inputfile[-4:]
#outputfile = str(args.outputfilename)

data_path = '/mnt/bighd/Data/Vaihingen/buildings/'
data_path = str(BASE_DIR.joinpath(str('./dataset/buildings/')))  + "/"


model_path = 'models/vaihingen/'
do_plot = False
do_train = True
start_test = 100


#Load data
L = 60
batch_size = 1
numfilt = [32,64,128,128,256,256]
im_size = 512
out_size = 256

csvfile=open(data_path + 'polygons.csv', newline='')
reader = csv.reader(csvfile)
images = np.zeros([im_size,im_size,3,168])
masks = np.zeros([out_size,out_size,1,168])
GT = np.zeros([L,2,168])
for i in range(168):
    corners = reader.__next__()
    num_points = np.int32(corners[0])
    poly = np.zeros([num_points, 2])
    for c in range(num_points):
        poly[c, 0] = np.float(corners[1+2*c])*out_size/im_size
        poly[c, 1] = np.float(corners[2+2*c])*out_size/im_size
    [tck, u] = interpolate.splprep([poly[:, 0], poly[:, 1]], s=2, k=1, per=1)
    [GT[:,0,i], GT[:,1,i]] = interpolate.splev(np.linspace(0, 1, L), tck)
    this_im  = scipy.misc.imread(data_path+'building_'+str(i+1).zfill(3)+'.tif')
    images[:,:,:,i] = np.float32(this_im)/255
    img_mask = scipy.misc.imread(data_path+'building_mask_' + str(i+1).zfill(3) + '.tif')/255
    masks[:,:,0,i] = scipy.misc.imresize(img_mask,[out_size,out_size])/255
GT = np.minimum(GT,out_size-1)
GT = np.maximum(GT,0)

with tf.device('/gpu:0'):
    tvars, grads, predE, predA, predB, predK, l2loss, grad_predE, \
    grad_predA, grad_predB, grad_predK, grad_l2loss, x, y_ = CNN_B(im_size, out_size, L, batch_size=1,wd=0.01,layers=len(numfilt),numfilt=numfilt)


#Prepare folder to save network
if not os.path.isdir(model_path):
    os.makedirs(model_path)

if not do_train and not os.path.isdir(model_path+'results'):
    os.makedirs(model_path+'results')
elif os.path.isdir(model_path+'results/polygons.csv'):
    os.remove(model_path+'results/polygons.csv')


# Add ops to save and restore all the variables.
saver = tf.train.Saver()

#Initialize CNN
optimizer = tf.train.AdamOptimizer(1e-4, epsilon=1e-6)
apply_gradients = optimizer.apply_gradients(zip(grads, tvars))

with tf.device('/cpu:0'):
    tf_u, tf_v, tf_du, tf_dv, tf_Du, tf_Dv, tf_u0, tf_v0, tf_du0, tf_dv0, \
    tf_alpha, tf_beta, tf_kappa = snake_graph(out_size, L)
# Out:
# /opt/conda/envs/tensorflow_1_4/lib/python3.6/site-packages/ipykernel_launcher.py:35: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /opt/conda/envs/tensorflow_1_4/lib/python3.6/site-packages/ipykernel_launcher.py:37: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /opt/conda/envs/tensorflow_1_4/lib/python3.6/site-packages/ipykernel_launcher.py:38: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
# Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.
# /opt/conda/envs/tensorflow_1_4/lib/python3.6/site-packages/scipy/interpolate/_fitpack_impl.py:299: RuntimeWarning: The maximal number of iterations (20) allowed for finding smoothing
# spline with fp=s has been reached. Probable cause: s too small.
# (abs(fp-s)/s>0.001)
#   warnings.warn(RuntimeWarning(_iermess[ier][0]))

# %%
def epoch(n,i,mode):
    # mode (str): train or test
    batch_ind = np.arange(i,i+batch_size)
    batch = np.copy(images[:, :, :, batch_ind])
    batch_mask = np.copy(masks[:, :, :, batch_ind])
    thisGT = np.copy(GT[:, :, batch_ind[0]])
    if mode is 'train':
        ang = np.random.rand() * 360
        for j in range(len(batch_ind)):
            for b in range(batch.shape[2]):
                batch[:, :, b, j] = imrotate(batch[:, :, b, j], ang)
            batch_mask[:, :, 0, j] = imrotate(batch_mask[:, :, 0, j], ang, resample='nearest')
        R = [[np.cos(ang * np.pi / 180), np.sin(ang * np.pi / 180)],
             [-np.sin(ang * np.pi / 180), np.cos(ang * np.pi / 180)]]
        thisGT -= out_size / 2
        thisGT = np.matmul(thisGT, R)
        thisGT += out_size / 2
    # prediction_np = sess.run(prediction,feed_dict={x:batch})
    tic = time.time()
    [mapE, mapA, mapB, mapK, l2] = sess.run([predE, predA, predB, predK, l2loss], feed_dict={x: batch})
    mapA = np.maximum(mapA, 0)
    mapB = np.maximum(mapB,0)
    mapK = np.maximum(mapK, 0)
    #print('%.2f' % (time.time() - tic) + ' s tf inference')
    if mode is 'train':
        for j in range(mapK.shape[3]):
            mapK[:, :, 0, j] -= batch_mask[:, :, 0, j] * 0.5 - 0.5 / 2
        # mapE_aug[:,:,0,j] = mapE[:,:,0,j]+np.maximum(0,20-batch_dists[:,:,0,j])*max_val/50
    # Do snake inference
    s = np.linspace(0, 2 * np.pi, L)
    init_u = out_size / 2 + 20 * np.cos(s)
    init_v = out_size / 2 + 20 * np.sin(s)
    init_u = init_u.reshape([L, 1])
    init_v = init_v.reshape([L, 1])
    init_snake = np.array([init_u[:, 0], init_v[:, 0]]).T
    for j in range(batch_size):
        snake, snake_hist = snake_process(mapE, mapA, mapB, mapK, init_snake)
        # Get last layer gradients
        M = mapE.shape[0]
        N = mapE.shape[1]
        der1, der2 = derivatives_poly(snake)


        der1_GT, der2_GT = derivatives_poly(thisGT)

        grads_arrayE = mapE * 0.01
        grads_arrayA = mapA * 0.01
        grads_arrayB = mapB * 0.01
        grads_arrayK = mapK * 0.01
        grads_arrayE[:, :, 0, 0] -= draw_poly(snake, 1, [M, N],12) - draw_poly(thisGT, 1, [M, N],12)
        grads_arrayA[:, :, 0, 0] -= (np.mean(der1) - np.mean(der1_GT))
        grads_arrayB[:, :, 0, 0] -= (draw_poly(snake, der2, [M, N],12) - draw_poly(thisGT, der2_GT, [M, N],12))
        mask_gt = draw_poly_fill(thisGT, [M, N])
        mask_snake = draw_poly_fill(snake, [M, N])
        grads_arrayK[:, :, 0, 0] -= mask_gt - mask_snake

        intersection = (mask_gt+mask_snake) == 2
        union = (mask_gt + mask_snake) >= 1
        iou = np.sum(intersection) / np.sum(union)
    if mode is 'train':
        tic = time.time()
        apply_gradients.run(
            feed_dict={x: batch, grad_predE: grads_arrayE, grad_predA: grads_arrayA, grad_predB: grads_arrayB,
                       grad_predK: grads_arrayK, grad_l2loss: 1})
        #print('%.2f' % (time.time() - tic) + ' s apply gradients')
        #print('IoU = %.2f' % (iou))
    #if mode is 'test':
        #print('IoU = %.2f' % (iou))
    if do_plot:
        plot_snakes(snake, snake_hist, thisGT, mapE, mapA, mapB, mapK, \
                grads_arrayE, grads_arrayA, grads_arrayB, grads_arrayK, batch, batch_mask)
        #plt.show()
    return iou,snake

# %%
with tf.Session(config=tf.ConfigProto(allow_soft_placement=True,log_device_placement=True)) as sess:
    sess2 = tf.Session(config=tf.ConfigProto(allow_soft_placement=True,log_device_placement=True))
    save_path = tf.train.latest_checkpoint(model_path)
    init = tf.global_variables_initializer()
    sess.run(init)
    start_epoch = 0
    if save_path is not None:
        saver.restore(sess,save_path)
        start_epoch = int(save_path.split('-')[-1].split('.')[0])+1

    if do_train:
        end_epoch = 100
    else:
        end_epoch = start_epoch + 1
        polygons_csvfile = open(model_path + 'results/' 'polygons.csv', 'a', newline='')
        polygons_writer = csv.writer(polygons_csvfile)

    for n in range(start_epoch,end_epoch):
        iou_test = 0
        iou_train = 0
        iter_count = 0
        if do_train:
            for i in range(0,100,batch_size):
                #print(i)
                #Do CNN inference
                new_iou_train,snake = epoch(n,i,'train')
                iou_train += new_iou_train
                iter_count += 1
                print('Train. Epoch ' + str(n) + '. Iter ' + str(iter_count) + '/' + str(100) + ', IoU = %.2f' % (
                iou_train / iter_count))
            iou_train /= 100

            saver.save(sess,model_path+'model', global_step=n)
        iter_count = 0
        for i in range(start_test,168):
            new_iou_test, snake = epoch(n, i, 'test')
            if not do_train:
                list_to_write = [len(snake)]
                snake = np.reshape(snake,2*len(snake)).tolist()
                for el in snake:
                    list_to_write.append(el)
                polygons_writer.writerow(list_to_write)
            iou_test += new_iou_test
            iter_count += 1
            print('Test. Epoch ' + str(n) + '. Iter ' + str(iter_count) + '/' + str(68) + ', IoU = %.2f' % (
            iou_test / iter_count))
        iou_test /= iter_count
        if not do_train:
            iou_csvfile = open(model_path + 'iuo_train_test.csv', 'a', newline='')
            iou_writer = csv.writer(iou_csvfile)
            iou_writer.writerow([n,iou_train,iou_test])
            iou_csvfile.close()
            polygons_csvfile.close()


#if os.path.isfile(model_path+'iuo_train_test.csv'):

#else:
# Out:
# Train. Epoch 0. Iter 1/100, IoU = 0.16
# Train. Epoch 0. Iter 2/100, IoU = 0.29
# Train. Epoch 0. Iter 3/100, IoU = 0.26
# Train. Epoch 0. Iter 4/100, IoU = 0.28
# Train. Epoch 0. Iter 5/100, IoU = 0.26
# Train. Epoch 0. Iter 6/100, IoU = 0.26
# Train. Epoch 0. Iter 7/100, IoU = 0.26
# Train. Epoch 0. Iter 8/100, IoU = 0.28
# Train. Epoch 0. Iter 9/100, IoU = 0.26
# Train. Epoch 0. Iter 10/100, IoU = 0.27
# Train. Epoch 0. Iter 11/100, IoU = 0.27
# Train. Epoch 0. Iter 12/100, IoU = 0.26
# Train. Epoch 0. Iter 13/100, IoU = 0.25
# Train. Epoch 0. Iter 14/100, IoU = 0.24
# Train. Epoch 0. Iter 15/100, IoU = 0.24
# Train. Epoch 0. Iter 16/100, IoU = 0.24
# Train. Epoch 0. Iter 17/100, IoU = 0.23
# Train. Epoch 0. Iter 18/100, IoU = 0.23
# Train. Epoch 0. Iter 19/100, IoU = 0.23
# Train. Epoch 0. Iter 20/100, IoU = 0.23
# Train. Epoch 0. Iter 21/100, IoU = 0.23
# Train. Epoch 0. Iter 22/100, IoU = 0.23
# Train. Epoch 0. Iter 23/100, IoU = 0.23
# Train. Epoch 0. Iter 24/100, IoU = 0.22
# Train. Epoch 0. Iter 25/100, IoU = 0.23
# Train. Epoch 0. Iter 26/100, IoU = 0.23
# Train. Epoch 0. Iter 27/100, IoU = 0.23
# Train. Epoch 0. Iter 28/100, IoU = 0.23
# Train. Epoch 0. Iter 29/100, IoU = 0.23
# Train. Epoch 0. Iter 30/100, IoU = 0.23
# Train. Epoch 0. Iter 31/100, IoU = 0.23
# Train. Epoch 0. Iter 32/100, IoU = 0.23
# Train. Epoch 0. Iter 33/100, IoU = 0.22
# Train. Epoch 0. Iter 34/100, IoU = 0.22
# Train. Epoch 0. Iter 35/100, IoU = 0.22
# Train. Epoch 0. Iter 36/100, IoU = 0.22
# Train. Epoch 0. Iter 37/100, IoU = 0.22
# Train. Epoch 0. Iter 38/100, IoU = 0.23
# Train. Epoch 0. Iter 39/100, IoU = 0.22
# Train. Epoch 0. Iter 40/100, IoU = 0.22
# Train. Epoch 0. Iter 41/100, IoU = 0.22
# Train. Epoch 0. Iter 42/100, IoU = 0.22
# Train. Epoch 0. Iter 43/100, IoU = 0.22
# Train. Epoch 0. Iter 44/100, IoU = 0.22
# Train. Epoch 0. Iter 45/100, IoU = 0.22
# Train. Epoch 0. Iter 46/100, IoU = 0.22
# Train. Epoch 0. Iter 47/100, IoU = 0.23
# Train. Epoch 0. Iter 48/100, IoU = 0.23
# Train. Epoch 0. Iter 49/100, IoU = 0.23
# Train. Epoch 0. Iter 50/100, IoU = 0.23
# Train. Epoch 0. Iter 51/100, IoU = 0.23
# Train. Epoch 0. Iter 52/100, IoU = 0.23
# Train. Epoch 0. Iter 53/100, IoU = 0.23
# Train. Epoch 0. Iter 54/100, IoU = 0.23
# Train. Epoch 0. Iter 55/100, IoU = 0.23
# Train. Epoch 0. Iter 56/100, IoU = 0.23
# Train. Epoch 0. Iter 57/100, IoU = 0.23
# Train. Epoch 0. Iter 58/100, IoU = 0.23
# Train. Epoch 0. Iter 59/100, IoU = 0.23
# Train. Epoch 0. Iter 60/100, IoU = 0.23
# Train. Epoch 0. Iter 61/100, IoU = 0.23
# Train. Epoch 0. Iter 62/100, IoU = 0.23
# Train. Epoch 0. Iter 63/100, IoU = 0.23
# Train. Epoch 0. Iter 64/100, IoU = 0.24
# Train. Epoch 0. Iter 65/100, IoU = 0.24
# Train. Epoch 0. Iter 66/100, IoU = 0.24
# Train. Epoch 0. Iter 67/100, IoU = 0.24
# Train. Epoch 0. Iter 68/100, IoU = 0.24
# Train. Epoch 0. Iter 69/100, IoU = 0.24
# Train. Epoch 0. Iter 70/100, IoU = 0.24
# Train. Epoch 0. Iter 71/100, IoU = 0.24
# Train. Epoch 0. Iter 72/100, IoU = 0.24
# Train. Epoch 0. Iter 73/100, IoU = 0.24
# Train. Epoch 0. Iter 74/100, IoU = 0.24
# Train. Epoch 0. Iter 75/100, IoU = 0.24
# Train. Epoch 0. Iter 76/100, IoU = 0.24
# Train. Epoch 0. Iter 77/100, IoU = 0.24
# Train. Epoch 0. Iter 78/100, IoU = 0.24
# Train. Epoch 0. Iter 79/100, IoU = 0.24
# Train. Epoch 0. Iter 80/100, IoU = 0.24
# Train. Epoch 0. Iter 81/100, IoU = 0.24
# Train. Epoch 0. Iter 82/100, IoU = 0.24
# Train. Epoch 0. Iter 83/100, IoU = 0.24
# Train. Epoch 0. Iter 84/100, IoU = 0.24
# Train. Epoch 0. Iter 85/100, IoU = 0.24
# Train. Epoch 0. Iter 86/100, IoU = 0.24
# Train. Epoch 0. Iter 87/100, IoU = 0.24
# Train. Epoch 0. Iter 88/100, IoU = 0.24
# Train. Epoch 0. Iter 89/100, IoU = 0.24
# Train. Epoch 0. Iter 90/100, IoU = 0.24
# Train. Epoch 0. Iter 91/100, IoU = 0.25
# Train. Epoch 0. Iter 92/100, IoU = 0.25
# Train. Epoch 0. Iter 93/100, IoU = 0.25
# Train. Epoch 0. Iter 94/100, IoU = 0.25
# Train. Epoch 0. Iter 95/100, IoU = 0.25
# Train. Epoch 0. Iter 96/100, IoU = 0.25
# Train. Epoch 0. Iter 97/100, IoU = 0.25
# Train. Epoch 0. Iter 98/100, IoU = 0.25
# Train. Epoch 0. Iter 99/100, IoU = 0.25
# Train. Epoch 0. Iter 100/100, IoU = 0.25
# Test. Epoch 0. Iter 1/68, IoU = 0.67
# Test. Epoch 0. Iter 2/68, IoU = 0.62
# Test. Epoch 0. Iter 3/68, IoU = 0.57
# Test. Epoch 0. Iter 4/68, IoU = 0.55
# Test. Epoch 0. Iter 5/68, IoU = 0.57
# Test. Epoch 0. Iter 6/68, IoU = 0.55
# Test. Epoch 0. Iter 7/68, IoU = 0.52
# Test. Epoch 0. Iter 8/68, IoU = 0.52
# Test. Epoch 0. Iter 9/68, IoU = 0.52
# Test. Epoch 0. Iter 10/68, IoU = 0.51
# Test. Epoch 0. Iter 11/68, IoU = 0.51
# Test. Epoch 0. Iter 12/68, IoU = 0.52
# Test. Epoch 0. Iter 13/68, IoU = 0.52
# Test. Epoch 0. Iter 14/68, IoU = 0.52
# Test. Epoch 0. Iter 15/68, IoU = 0.53
# Test. Epoch 0. Iter 16/68, IoU = 0.55
# Test. Epoch 0. Iter 17/68, IoU = 0.56
# Test. Epoch 0. Iter 18/68, IoU = 0.55
# Test. Epoch 0. Iter 19/68, IoU = 0.54
# Test. Epoch 0. Iter 20/68, IoU = 0.55
# Test. Epoch 0. Iter 21/68, IoU = 0.55
# Test. Epoch 0. Iter 22/68, IoU = 0.55
# Test. Epoch 0. Iter 23/68, IoU = 0.56
# Test. Epoch 0. Iter 24/68, IoU = 0.55
# Test. Epoch 0. Iter 25/68, IoU = 0.55
# Test. Epoch 0. Iter 26/68, IoU = 0.54
# Test. Epoch 0. Iter 27/68, IoU = 0.54
# Test. Epoch 0. Iter 28/68, IoU = 0.54
# Test. Epoch 0. Iter 29/68, IoU = 0.54
# Test. Epoch 0. Iter 30/68, IoU = 0.54
# Test. Epoch 0. Iter 31/68, IoU = 0.55
# Test. Epoch 0. Iter 32/68, IoU = 0.54
# Test. Epoch 0. Iter 33/68, IoU = 0.54
# Test. Epoch 0. Iter 34/68, IoU = 0.55
# Test. Epoch 0. Iter 35/68, IoU = 0.54
# Test. Epoch 0. Iter 36/68, IoU = 0.53
# Test. Epoch 0. Iter 37/68, IoU = 0.53
# Test. Epoch 0. Iter 38/68, IoU = 0.52
# Test. Epoch 0. Iter 39/68, IoU = 0.53
# Test. Epoch 0. Iter 40/68, IoU = 0.53
# Test. Epoch 0. Iter 41/68, IoU = 0.54
# Test. Epoch 0. Iter 42/68, IoU = 0.54
# Test. Epoch 0. Iter 43/68, IoU = 0.54
# Test. Epoch 0. Iter 44/68, IoU = 0.55
# Test. Epoch 0. Iter 45/68, IoU = 0.55
# Test. Epoch 0. Iter 46/68, IoU = 0.55
# Test. Epoch 0. Iter 47/68, IoU = 0.55
# Test. Epoch 0. Iter 48/68, IoU = 0.55
# Test. Epoch 0. Iter 49/68, IoU = 0.54
# Test. Epoch 0. Iter 50/68, IoU = 0.55
# Test. Epoch 0. Iter 51/68, IoU = 0.54
# Test. Epoch 0. Iter 52/68, IoU = 0.54
# Test. Epoch 0. Iter 53/68, IoU = 0.53
# Test. Epoch 0. Iter 54/68, IoU = 0.53
# Test. Epoch 0. Iter 55/68, IoU = 0.53
# Test. Epoch 0. Iter 56/68, IoU = 0.53
# Test. Epoch 0. Iter 57/68, IoU = 0.52
# Test. Epoch 0. Iter 58/68, IoU = 0.52
# Test. Epoch 0. Iter 59/68, IoU = 0.52
# Test. Epoch 0. Iter 60/68, IoU = 0.52
# Test. Epoch 0. Iter 61/68, IoU = 0.52
# Test. Epoch 0. Iter 62/68, IoU = 0.52
# Test. Epoch 0. Iter 63/68, IoU = 0.52
# Test. Epoch 0. Iter 64/68, IoU = 0.52
# Test. Epoch 0. Iter 65/68, IoU = 0.52
# Test. Epoch 0. Iter 66/68, IoU = 0.52
# Test. Epoch 0. Iter 67/68, IoU = 0.52
# Test. Epoch 0. Iter 68/68, IoU = 0.51
# Train. Epoch 1. Iter 1/100, IoU = 0.12
# Train. Epoch 1. Iter 2/100, IoU = 0.24
# Train. Epoch 1. Iter 3/100, IoU = 0.26
# Train. Epoch 1. Iter 4/100, IoU = 0.27
# Train. Epoch 1. Iter 5/100, IoU = 0.25
# Train. Epoch 1. Iter 6/100, IoU = 0.24
# Train. Epoch 1. Iter 7/100, IoU = 0.26
# Train. Epoch 1. Iter 8/100, IoU = 0.28
# Train. Epoch 1. Iter 9/100, IoU = 0.28
# Train. Epoch 1. Iter 10/100, IoU = 0.28
# Train. Epoch 1. Iter 11/100, IoU = 0.27
# Train. Epoch 1. Iter 12/100, IoU = 0.29
# Train. Epoch 1. Iter 13/100, IoU = 0.28
# Train. Epoch 1. Iter 14/100, IoU = 0.28
# Train. Epoch 1. Iter 15/100, IoU = 0.30
# Train. Epoch 1. Iter 16/100, IoU = 0.30
# Train. Epoch 1. Iter 17/100, IoU = 0.32
# Train. Epoch 1. Iter 18/100, IoU = 0.32
# Train. Epoch 1. Iter 19/100, IoU = 0.33
# Train. Epoch 1. Iter 20/100, IoU = 0.34
# Train. Epoch 1. Iter 21/100, IoU = 0.33
# Train. Epoch 1. Iter 22/100, IoU = 0.34
# Train. Epoch 1. Iter 23/100, IoU = 0.33
# Train. Epoch 1. Iter 24/100, IoU = 0.34
# Train. Epoch 1. Iter 25/100, IoU = 0.34
# Train. Epoch 1. Iter 26/100, IoU = 0.34
# Train. Epoch 1. Iter 27/100, IoU = 0.34
# Train. Epoch 1. Iter 28/100, IoU = 0.34
# Train. Epoch 1. Iter 29/100, IoU = 0.33
# Train. Epoch 1. Iter 30/100, IoU = 0.33
# Train. Epoch 1. Iter 31/100, IoU = 0.33
# Train. Epoch 1. Iter 32/100, IoU = 0.32
# Train. Epoch 1. Iter 33/100, IoU = 0.32
# Train. Epoch 1. Iter 34/100, IoU = 0.32
# Train. Epoch 1. Iter 35/100, IoU = 0.31
# Train. Epoch 1. Iter 36/100, IoU = 0.31
# Train. Epoch 1. Iter 37/100, IoU = 0.31
# Train. Epoch 1. Iter 38/100, IoU = 0.32
# Train. Epoch 1. Iter 39/100, IoU = 0.32
# Train. Epoch 1. Iter 40/100, IoU = 0.32
# Train. Epoch 1. Iter 41/100, IoU = 0.31
# Train. Epoch 1. Iter 42/100, IoU = 0.31
# Train. Epoch 1. Iter 43/100, IoU = 0.31
# Train. Epoch 1. Iter 44/100, IoU = 0.30
# Train. Epoch 1. Iter 45/100, IoU = 0.30
# Train. Epoch 1. Iter 46/100, IoU = 0.30
# Train. Epoch 1. Iter 47/100, IoU = 0.30
# Train. Epoch 1. Iter 48/100, IoU = 0.30
# Train. Epoch 1. Iter 49/100, IoU = 0.31
# Train. Epoch 1. Iter 50/100, IoU = 0.31
# Train. Epoch 1. Iter 51/100, IoU = 0.30
# Train. Epoch 1. Iter 52/100, IoU = 0.30
# Train. Epoch 1. Iter 53/100, IoU = 0.30
# Train. Epoch 1. Iter 54/100, IoU = 0.29
# Train. Epoch 1. Iter 55/100, IoU = 0.29
# Train. Epoch 1. Iter 56/100, IoU = 0.29
# Train. Epoch 1. Iter 57/100, IoU = 0.29
# Train. Epoch 1. Iter 58/100, IoU = 0.29
# Train. Epoch 1. Iter 59/100, IoU = 0.29
# Train. Epoch 1. Iter 60/100, IoU = 0.29
# Train. Epoch 1. Iter 61/100, IoU = 0.29
# Train. Epoch 1. Iter 62/100, IoU = 0.28
# Train. Epoch 1. Iter 63/100, IoU = 0.28
# Train. Epoch 1. Iter 64/100, IoU = 0.28
# Train. Epoch 1. Iter 65/100, IoU = 0.28
# Train. Epoch 1. Iter 66/100, IoU = 0.28
# Train. Epoch 1. Iter 67/100, IoU = 0.28
# Train. Epoch 1. Iter 68/100, IoU = 0.28
# Train. Epoch 1. Iter 69/100, IoU = 0.28
# Train. Epoch 1. Iter 70/100, IoU = 0.28
# Train. Epoch 1. Iter 71/100, IoU = 0.28
# Train. Epoch 1. Iter 72/100, IoU = 0.28
# Train. Epoch 1. Iter 73/100, IoU = 0.28
# Train. Epoch 1. Iter 74/100, IoU = 0.28
# Train. Epoch 1. Iter 75/100, IoU = 0.28
# Train. Epoch 1. Iter 76/100, IoU = 0.27
# Train. Epoch 1. Iter 77/100, IoU = 0.27
# Train. Epoch 1. Iter 78/100, IoU = 0.27
# Train. Epoch 1. Iter 79/100, IoU = 0.28
# Train. Epoch 1. Iter 80/100, IoU = 0.27
# Train. Epoch 1. Iter 81/100, IoU = 0.27
# Train. Epoch 1. Iter 82/100, IoU = 0.27
# Train. Epoch 1. Iter 83/100, IoU = 0.27
# Train. Epoch 1. Iter 84/100, IoU = 0.27
# Train. Epoch 1. Iter 85/100, IoU = 0.27
# Train. Epoch 1. Iter 86/100, IoU = 0.27
# Train. Epoch 1. Iter 87/100, IoU = 0.27
# Train. Epoch 1. Iter 88/100, IoU = 0.27
# Train. Epoch 1. Iter 89/100, IoU = 0.27
# Train. Epoch 1. Iter 90/100, IoU = 0.26
# Train. Epoch 1. Iter 91/100, IoU = 0.27
# Train. Epoch 1. Iter 92/100, IoU = 0.27
# Train. Epoch 1. Iter 93/100, IoU = 0.27
# Train. Epoch 1. Iter 94/100, IoU = 0.27
# Train. Epoch 1. Iter 95/100, IoU = 0.27
# Train. Epoch 1. Iter 96/100, IoU = 0.26
# Train. Epoch 1. Iter 97/100, IoU = 0.27
# Train. Epoch 1. Iter 98/100, IoU = 0.27
# Train. Epoch 1. Iter 99/100, IoU = 0.27
# Train. Epoch 1. Iter 100/100, IoU = 0.27
# Test. Epoch 1. Iter 1/68, IoU = 0.51
# Test. Epoch 1. Iter 2/68, IoU = 0.55
# Test. Epoch 1. Iter 3/68, IoU = 0.55
# Test. Epoch 1. Iter 4/68, IoU = 0.54
# Test. Epoch 1. Iter 5/68, IoU = 0.55
# Test. Epoch 1. Iter 6/68, IoU = 0.55
# Test. Epoch 1. Iter 7/68, IoU = 0.53
# Test. Epoch 1. Iter 8/68, IoU = 0.52
# Test. Epoch 1. Iter 9/68, IoU = 0.53
# Test. Epoch 1. Iter 10/68, IoU = 0.52
# Test. Epoch 1. Iter 11/68, IoU = 0.52
# Test. Epoch 1. Iter 12/68, IoU = 0.52
# Test. Epoch 1. Iter 13/68, IoU = 0.53
# Test. Epoch 1. Iter 14/68, IoU = 0.53
# Test. Epoch 1. Iter 15/68, IoU = 0.54
# Test. Epoch 1. Iter 16/68, IoU = 0.56
# Test. Epoch 1. Iter 17/68, IoU = 0.57
# Test. Epoch 1. Iter 18/68, IoU = 0.56
# Test. Epoch 1. Iter 19/68, IoU = 0.56
# Test. Epoch 1. Iter 20/68, IoU = 0.56
# Test. Epoch 1. Iter 21/68, IoU = 0.56
# Test. Epoch 1. Iter 22/68, IoU = 0.57
# Test. Epoch 1. Iter 23/68, IoU = 0.57
# Test. Epoch 1. Iter 24/68, IoU = 0.57
# Test. Epoch 1. Iter 25/68, IoU = 0.57
# Test. Epoch 1. Iter 26/68, IoU = 0.56
# Test. Epoch 1. Iter 27/68, IoU = 0.56
# Test. Epoch 1. Iter 28/68, IoU = 0.56
# Test. Epoch 1. Iter 29/68, IoU = 0.56
# Test. Epoch 1. Iter 30/68, IoU = 0.56
# Test. Epoch 1. Iter 31/68, IoU = 0.56
# Test. Epoch 1. Iter 32/68, IoU = 0.56
# Test. Epoch 1. Iter 33/68, IoU = 0.55
# Test. Epoch 1. Iter 34/68, IoU = 0.56
# Test. Epoch 1. Iter 35/68, IoU = 0.55
# Test. Epoch 1. Iter 36/68, IoU = 0.54
# Test. Epoch 1. Iter 37/68, IoU = 0.54
# Test. Epoch 1. Iter 38/68, IoU = 0.54
# Test. Epoch 1. Iter 39/68, IoU = 0.53
# Test. Epoch 1. Iter 40/68, IoU = 0.54
# Test. Epoch 1. Iter 41/68, IoU = 0.55
# Test. Epoch 1. Iter 42/68, IoU = 0.55
# Test. Epoch 1. Iter 43/68, IoU = 0.55
# Test. Epoch 1. Iter 44/68, IoU = 0.56
# Test. Epoch 1. Iter 45/68, IoU = 0.57
# Test. Epoch 1. Iter 46/68, IoU = 0.56
# Test. Epoch 1. Iter 47/68, IoU = 0.56
# Test. Epoch 1. Iter 48/68, IoU = 0.57
# Test. Epoch 1. Iter 49/68, IoU = 0.56
# Test. Epoch 1. Iter 50/68, IoU = 0.57
# Test. Epoch 1. Iter 51/68, IoU = 0.56
# Test. Epoch 1. Iter 52/68, IoU = 0.56
# Test. Epoch 1. Iter 53/68, IoU = 0.56
# Test. Epoch 1. Iter 54/68, IoU = 0.56
# Test. Epoch 1. Iter 55/68, IoU = 0.56
# Test. Epoch 1. Iter 56/68, IoU = 0.56
# Test. Epoch 1. Iter 57/68, IoU = 0.56
# Test. Epoch 1. Iter 58/68, IoU = 0.56
# Test. Epoch 1. Iter 59/68, IoU = 0.56
# Test. Epoch 1. Iter 60/68, IoU = 0.56
# Test. Epoch 1. Iter 61/68, IoU = 0.56
# Test. Epoch 1. Iter 62/68, IoU = 0.56
# Test. Epoch 1. Iter 63/68, IoU = 0.56
# Test. Epoch 1. Iter 64/68, IoU = 0.56
# Test. Epoch 1. Iter 65/68, IoU = 0.56
# Test. Epoch 1. Iter 66/68, IoU = 0.56
# Test. Epoch 1. Iter 67/68, IoU = 0.55
# Test. Epoch 1. Iter 68/68, IoU = 0.55
# Train. Epoch 2. Iter 1/100, IoU = 0.27
# Train. Epoch 2. Iter 2/100, IoU = 0.24
# Train. Epoch 2. Iter 3/100, IoU = 0.24
# Train. Epoch 2. Iter 4/100, IoU = 0.27
# Train. Epoch 2. Iter 5/100, IoU = 0.25
# Train. Epoch 2. Iter 6/100, IoU = 0.24
# Train. Epoch 2. Iter 7/100, IoU = 0.26
# Train. Epoch 2. Iter 8/100, IoU = 0.29
# Train. Epoch 2. Iter 9/100, IoU = 0.30
# Train. Epoch 2. Iter 10/100, IoU = 0.34
# Train. Epoch 2. Iter 11/100, IoU = 0.32
# Train. Epoch 2. Iter 12/100, IoU = 0.31
# Train. Epoch 2. Iter 13/100, IoU = 0.30
# Train. Epoch 2. Iter 14/100, IoU = 0.29
# Train. Epoch 2. Iter 15/100, IoU = 0.30
# Train. Epoch 2. Iter 16/100, IoU = 0.29
# Train. Epoch 2. Iter 17/100, IoU = 0.29
# Train. Epoch 2. Iter 18/100, IoU = 0.29
# Train. Epoch 2. Iter 19/100, IoU = 0.29
# Train. Epoch 2. Iter 20/100, IoU = 0.31
# Train. Epoch 2. Iter 21/100, IoU = 0.30
# Train. Epoch 2. Iter 22/100, IoU = 0.30
# Train. Epoch 2. Iter 23/100, IoU = 0.30
# Train. Epoch 2. Iter 24/100, IoU = 0.30
# Train. Epoch 2. Iter 25/100, IoU = 0.30
# Train. Epoch 2. Iter 26/100, IoU = 0.30
# Train. Epoch 2. Iter 27/100, IoU = 0.31
# Train. Epoch 2. Iter 28/100, IoU = 0.31
# Train. Epoch 2. Iter 29/100, IoU = 0.31
# Train. Epoch 2. Iter 30/100, IoU = 0.31
# Train. Epoch 2. Iter 31/100, IoU = 0.31
# Train. Epoch 2. Iter 32/100, IoU = 0.30
# Train. Epoch 2. Iter 33/100, IoU = 0.30
# Train. Epoch 2. Iter 34/100, IoU = 0.30
# Train. Epoch 2. Iter 35/100, IoU = 0.30
# Train. Epoch 2. Iter 36/100, IoU = 0.31
# Train. Epoch 2. Iter 37/100, IoU = 0.31
# Train. Epoch 2. Iter 38/100, IoU = 0.30
# Train. Epoch 2. Iter 39/100, IoU = 0.31
# Train. Epoch 2. Iter 40/100, IoU = 0.31
# Train. Epoch 2. Iter 41/100, IoU = 0.31
# Train. Epoch 2. Iter 42/100, IoU = 0.30
# Train. Epoch 2. Iter 43/100, IoU = 0.30
# Train. Epoch 2. Iter 44/100, IoU = 0.30
# Train. Epoch 2. Iter 45/100, IoU = 0.30
# Train. Epoch 2. Iter 46/100, IoU = 0.30
# Train. Epoch 2. Iter 47/100, IoU = 0.31
# Train. Epoch 2. Iter 48/100, IoU = 0.31
# Train. Epoch 2. Iter 49/100, IoU = 0.32
# Train. Epoch 2. Iter 50/100, IoU = 0.32
# Train. Epoch 2. Iter 51/100, IoU = 0.32
# Train. Epoch 2. Iter 52/100, IoU = 0.32
# Train. Epoch 2. Iter 53/100, IoU = 0.32
# Train. Epoch 2. Iter 54/100, IoU = 0.31
# Train. Epoch 2. Iter 55/100, IoU = 0.31
# Train. Epoch 2. Iter 56/100, IoU = 0.31
# Train. Epoch 2. Iter 57/100, IoU = 0.31
# Train. Epoch 2. Iter 58/100, IoU = 0.31
# Train. Epoch 2. Iter 59/100, IoU = 0.31
# Train. Epoch 2. Iter 60/100, IoU = 0.31
# Train. Epoch 2. Iter 61/100, IoU = 0.32
# Train. Epoch 2. Iter 62/100, IoU = 0.31
# Train. Epoch 2. Iter 63/100, IoU = 0.31
# Train. Epoch 2. Iter 64/100, IoU = 0.31
# Train. Epoch 2. Iter 65/100, IoU = 0.31
# Train. Epoch 2. Iter 66/100, IoU = 0.32
# Train. Epoch 2. Iter 67/100, IoU = 0.32
# Train. Epoch 2. Iter 68/100, IoU = 0.32
# Train. Epoch 2. Iter 69/100, IoU = 0.32
# Train. Epoch 2. Iter 70/100, IoU = 0.32
# Train. Epoch 2. Iter 71/100, IoU = 0.32
# Train. Epoch 2. Iter 72/100, IoU = 0.31
# Train. Epoch 2. Iter 73/100, IoU = 0.31
# Train. Epoch 2. Iter 74/100, IoU = 0.32
# Train. Epoch 2. Iter 75/100, IoU = 0.32
# Train. Epoch 2. Iter 76/100, IoU = 0.32
# Train. Epoch 2. Iter 77/100, IoU = 0.32
# Train. Epoch 2. Iter 78/100, IoU = 0.32
# Train. Epoch 2. Iter 79/100, IoU = 0.32
# Train. Epoch 2. Iter 80/100, IoU = 0.32
# Train. Epoch 2. Iter 81/100, IoU = 0.31
# Train. Epoch 2. Iter 82/100, IoU = 0.31
# Train. Epoch 2. Iter 83/100, IoU = 0.31
# Train. Epoch 2. Iter 84/100, IoU = 0.31
# Train. Epoch 2. Iter 85/100, IoU = 0.31
# Train. Epoch 2. Iter 86/100, IoU = 0.31
# Train. Epoch 2. Iter 87/100, IoU = 0.31
# Train. Epoch 2. Iter 88/100, IoU = 0.31
# Train. Epoch 2. Iter 89/100, IoU = 0.31
# Train. Epoch 2. Iter 90/100, IoU = 0.31
# Train. Epoch 2. Iter 91/100, IoU = 0.31
# Train. Epoch 2. Iter 92/100, IoU = 0.31
# Train. Epoch 2. Iter 93/100, IoU = 0.31
# Train. Epoch 2. Iter 94/100, IoU = 0.31
# Train. Epoch 2. Iter 95/100, IoU = 0.31
# Train. Epoch 2. Iter 96/100, IoU = 0.31
# Train. Epoch 2. Iter 97/100, IoU = 0.31
# Train. Epoch 2. Iter 98/100, IoU = 0.31
# Train. Epoch 2. Iter 99/100, IoU = 0.31
# Train. Epoch 2. Iter 100/100, IoU = 0.31
# Test. Epoch 2. Iter 1/68, IoU = 0.54
# Test. Epoch 2. Iter 2/68, IoU = 0.57
# Test. Epoch 2. Iter 3/68, IoU = 0.58
# Test. Epoch 2. Iter 4/68, IoU = 0.57
# Test. Epoch 2. Iter 5/68, IoU = 0.61
# Test. Epoch 2. Iter 6/68, IoU = 0.61
# Test. Epoch 2. Iter 7/68, IoU = 0.61
# Test. Epoch 2. Iter 8/68, IoU = 0.60
# Test. Epoch 2. Iter 9/68, IoU = 0.60
# Test. Epoch 2. Iter 10/68, IoU = 0.60
# Test. Epoch 2. Iter 11/68, IoU = 0.59
# Test. Epoch 2. Iter 12/68, IoU = 0.59
# Test. Epoch 2. Iter 13/68, IoU = 0.59
# Test. Epoch 2. Iter 14/68, IoU = 0.59
# Test. Epoch 2. Iter 15/68, IoU = 0.59
# Test. Epoch 2. Iter 16/68, IoU = 0.61
# Test. Epoch 2. Iter 17/68, IoU = 0.62
# Test. Epoch 2. Iter 18/68, IoU = 0.61
# Test. Epoch 2. Iter 19/68, IoU = 0.60
# Test. Epoch 2. Iter 20/68, IoU = 0.60
# Test. Epoch 2. Iter 21/68, IoU = 0.60
# Test. Epoch 2. Iter 22/68, IoU = 0.61
# Test. Epoch 2. Iter 23/68, IoU = 0.62
# Test. Epoch 2. Iter 24/68, IoU = 0.62
# Test. Epoch 2. Iter 25/68, IoU = 0.61
# Test. Epoch 2. Iter 26/68, IoU = 0.60
# Test. Epoch 2. Iter 27/68, IoU = 0.60
# Test. Epoch 2. Iter 28/68, IoU = 0.60
# Test. Epoch 2. Iter 29/68, IoU = 0.60
# Test. Epoch 2. Iter 30/68, IoU = 0.60
# Test. Epoch 2. Iter 31/68, IoU = 0.59
# Test. Epoch 2. Iter 32/68, IoU = 0.60
# Test. Epoch 2. Iter 33/68, IoU = 0.59
# Test. Epoch 2. Iter 34/68, IoU = 0.59
# Test. Epoch 2. Iter 35/68, IoU = 0.58
# Test. Epoch 2. Iter 36/68, IoU = 0.58
# Test. Epoch 2. Iter 37/68, IoU = 0.58
# Test. Epoch 2. Iter 38/68, IoU = 0.57
# Test. Epoch 2. Iter 39/68, IoU = 0.57
# Test. Epoch 2. Iter 40/68, IoU = 0.58
# Test. Epoch 2. Iter 41/68, IoU = 0.59
# Test. Epoch 2. Iter 42/68, IoU = 0.59
# Test. Epoch 2. Iter 43/68, IoU = 0.59
# Test. Epoch 2. Iter 44/68, IoU = 0.60
# Test. Epoch 2. Iter 45/68, IoU = 0.60
# Test. Epoch 2. Iter 46/68, IoU = 0.60
# Test. Epoch 2. Iter 47/68, IoU = 0.60
# Test. Epoch 2. Iter 48/68, IoU = 0.61
# Test. Epoch 2. Iter 49/68, IoU = 0.61
# Test. Epoch 2. Iter 50/68, IoU = 0.61
# Test. Epoch 2. Iter 51/68, IoU = 0.61
# Test. Epoch 2. Iter 52/68, IoU = 0.61
# Test. Epoch 2. Iter 53/68, IoU = 0.61
# Test. Epoch 2. Iter 54/68, IoU = 0.61
# Test. Epoch 2. Iter 55/68, IoU = 0.61
# Test. Epoch 2. Iter 56/68, IoU = 0.61
# Test. Epoch 2. Iter 57/68, IoU = 0.61
# Test. Epoch 2. Iter 58/68, IoU = 0.61
# Test. Epoch 2. Iter 59/68, IoU = 0.61
# Test. Epoch 2. Iter 60/68, IoU = 0.61
# Test. Epoch 2. Iter 61/68, IoU = 0.61
# Test. Epoch 2. Iter 62/68, IoU = 0.61
# Test. Epoch 2. Iter 63/68, IoU = 0.61
# Test. Epoch 2. Iter 64/68, IoU = 0.62
# Test. Epoch 2. Iter 65/68, IoU = 0.61
# Test. Epoch 2. Iter 66/68, IoU = 0.62
# Test. Epoch 2. Iter 67/68, IoU = 0.61
# Test. Epoch 2. Iter 68/68, IoU = 0.61
# Train. Epoch 3. Iter 1/100, IoU = 0.40
# Train. Epoch 3. Iter 2/100, IoU = 0.50
# Train. Epoch 3. Iter 3/100, IoU = 0.50
# Train. Epoch 3. Iter 4/100, IoU = 0.44
# Train. Epoch 3. Iter 5/100, IoU = 0.40
# Train. Epoch 3. Iter 6/100, IoU = 0.36
# Train. Epoch 3. Iter 7/100, IoU = 0.38
# Train. Epoch 3. Iter 8/100, IoU = 0.37
# Train. Epoch 3. Iter 9/100, IoU = 0.36
# Train. Epoch 3. Iter 10/100, IoU = 0.37
# Train. Epoch 3. Iter 11/100, IoU = 0.35
# Train. Epoch 3. Iter 12/100, IoU = 0.34
# Train. Epoch 3. Iter 13/100, IoU = 0.33
# Train. Epoch 3. Iter 14/100, IoU = 0.34
# Train. Epoch 3. Iter 15/100, IoU = 0.34
# Train. Epoch 3. Iter 16/100, IoU = 0.35
# Train. Epoch 3. Iter 17/100, IoU = 0.37
# Train. Epoch 3. Iter 18/100, IoU = 0.36
# Train. Epoch 3. Iter 19/100, IoU = 0.37
# Train. Epoch 3. Iter 20/100, IoU = 0.38
# Train. Epoch 3. Iter 21/100, IoU = 0.37
# Train. Epoch 3. Iter 22/100, IoU = 0.37
# Train. Epoch 3. Iter 23/100, IoU = 0.37
# Train. Epoch 3. Iter 24/100, IoU = 0.37
# Train. Epoch 3. Iter 25/100, IoU = 0.38
# Train. Epoch 3. Iter 26/100, IoU = 0.39
# Train. Epoch 3. Iter 27/100, IoU = 0.40
# Train. Epoch 3. Iter 28/100, IoU = 0.40
# Train. Epoch 3. Iter 29/100, IoU = 0.41
# Train. Epoch 3. Iter 30/100, IoU = 0.41
# Train. Epoch 3. Iter 31/100, IoU = 0.41
# Train. Epoch 3. Iter 32/100, IoU = 0.41
# Train. Epoch 3. Iter 33/100, IoU = 0.40
# Train. Epoch 3. Iter 34/100, IoU = 0.40
# Train. Epoch 3. Iter 35/100, IoU = 0.40
# Train. Epoch 3. Iter 36/100, IoU = 0.41
# Train. Epoch 3. Iter 37/100, IoU = 0.41
# Train. Epoch 3. Iter 38/100, IoU = 0.41
# Train. Epoch 3. Iter 39/100, IoU = 0.41
# Train. Epoch 3. Iter 40/100, IoU = 0.41
# Train. Epoch 3. Iter 41/100, IoU = 0.41
# Train. Epoch 3. Iter 42/100, IoU = 0.41
# Train. Epoch 3. Iter 43/100, IoU = 0.40
# Train. Epoch 3. Iter 44/100, IoU = 0.40
# Train. Epoch 3. Iter 45/100, IoU = 0.40
# Train. Epoch 3. Iter 46/100, IoU = 0.40
# Train. Epoch 3. Iter 47/100, IoU = 0.40
# Train. Epoch 3. Iter 48/100, IoU = 0.40
# Train. Epoch 3. Iter 49/100, IoU = 0.41
# Train. Epoch 3. Iter 50/100, IoU = 0.41
# Train. Epoch 3. Iter 51/100, IoU = 0.40
# Train. Epoch 3. Iter 52/100, IoU = 0.40
# Train. Epoch 3. Iter 53/100, IoU = 0.40
# Train. Epoch 3. Iter 54/100, IoU = 0.39
# Train. Epoch 3. Iter 55/100, IoU = 0.39
# Train. Epoch 3. Iter 56/100, IoU = 0.39
# Train. Epoch 3. Iter 57/100, IoU = 0.39
# Train. Epoch 3. Iter 58/100, IoU = 0.39
# Train. Epoch 3. Iter 59/100, IoU = 0.39
# Train. Epoch 3. Iter 60/100, IoU = 0.39
# Train. Epoch 3. Iter 61/100, IoU = 0.39
# Train. Epoch 3. Iter 62/100, IoU = 0.38
# Train. Epoch 3. Iter 63/100, IoU = 0.38
# Train. Epoch 3. Iter 64/100, IoU = 0.38
# Train. Epoch 3. Iter 65/100, IoU = 0.38
# Train. Epoch 3. Iter 66/100, IoU = 0.38
# Train. Epoch 3. Iter 67/100, IoU = 0.38
# Train. Epoch 3. Iter 68/100, IoU = 0.38
# Train. Epoch 3. Iter 69/100, IoU = 0.37
# Train. Epoch 3. Iter 70/100, IoU = 0.37
# Train. Epoch 3. Iter 71/100, IoU = 0.37
# Train. Epoch 3. Iter 72/100, IoU = 0.37
# Train. Epoch 3. Iter 73/100, IoU = 0.37
# Train. Epoch 3. Iter 74/100, IoU = 0.37
# Train. Epoch 3. Iter 75/100, IoU = 0.37
# Train. Epoch 3. Iter 76/100, IoU = 0.37
# Train. Epoch 3. Iter 77/100, IoU = 0.37
# Train. Epoch 3. Iter 78/100, IoU = 0.37
# Train. Epoch 3. Iter 79/100, IoU = 0.36
# Train. Epoch 3. Iter 80/100, IoU = 0.36
# Train. Epoch 3. Iter 81/100, IoU = 0.36
# Train. Epoch 3. Iter 82/100, IoU = 0.36
# Train. Epoch 3. Iter 83/100, IoU = 0.35
# Train. Epoch 3. Iter 84/100, IoU = 0.35
# Train. Epoch 3. Iter 85/100, IoU = 0.35
# Train. Epoch 3. Iter 86/100, IoU = 0.35
# Train. Epoch 3. Iter 87/100, IoU = 0.35
# Train. Epoch 3. Iter 88/100, IoU = 0.35
# Train. Epoch 3. Iter 89/100, IoU = 0.35
# Train. Epoch 3. Iter 90/100, IoU = 0.35
# Train. Epoch 3. Iter 91/100, IoU = 0.36
# Train. Epoch 3. Iter 92/100, IoU = 0.36
# Train. Epoch 3. Iter 93/100, IoU = 0.36
# Train. Epoch 3. Iter 94/100, IoU = 0.35
# Train. Epoch 3. Iter 95/100, IoU = 0.35
# Train. Epoch 3. Iter 96/100, IoU = 0.35
# Train. Epoch 3. Iter 97/100, IoU = 0.35
# Train. Epoch 3. Iter 98/100, IoU = 0.35
# Train. Epoch 3. Iter 99/100, IoU = 0.35
# Train. Epoch 3. Iter 100/100, IoU = 0.35
# Test. Epoch 3. Iter 1/68, IoU = 0.55
# Test. Epoch 3. Iter 2/68, IoU = 0.61
# Test. Epoch 3. Iter 3/68, IoU = 0.65
# Test. Epoch 3. Iter 4/68, IoU = 0.64
# Test. Epoch 3. Iter 5/68, IoU = 0.66
# Test. Epoch 3. Iter 6/68, IoU = 0.66
# Test. Epoch 3. Iter 7/68, IoU = 0.66
# Test. Epoch 3. Iter 8/68, IoU = 0.65
# Test. Epoch 3. Iter 9/68, IoU = 0.65
# Test. Epoch 3. Iter 10/68, IoU = 0.65
# Test. Epoch 3. Iter 11/68, IoU = 0.63
# Test. Epoch 3. Iter 12/68, IoU = 0.64
# Test. Epoch 3. Iter 13/68, IoU = 0.64
# Test. Epoch 3. Iter 14/68, IoU = 0.64
# Test. Epoch 3. Iter 15/68, IoU = 0.63
# Test. Epoch 3. Iter 16/68, IoU = 0.65
# Test. Epoch 3. Iter 17/68, IoU = 0.66
# Test. Epoch 3. Iter 18/68, IoU = 0.65
# Test. Epoch 3. Iter 19/68, IoU = 0.63
# Test. Epoch 3. Iter 20/68, IoU = 0.63
# Test. Epoch 3. Iter 21/68, IoU = 0.64
# Test. Epoch 3. Iter 22/68, IoU = 0.65
# Test. Epoch 3. Iter 23/68, IoU = 0.66
# Test. Epoch 3. Iter 24/68, IoU = 0.66
# Test. Epoch 3. Iter 25/68, IoU = 0.65
# Test. Epoch 3. Iter 26/68, IoU = 0.65
# Test. Epoch 3. Iter 27/68, IoU = 0.65
# Test. Epoch 3. Iter 28/68, IoU = 0.65
# Test. Epoch 3. Iter 29/68, IoU = 0.66
# Test. Epoch 3. Iter 30/68, IoU = 0.65
# Test. Epoch 3. Iter 31/68, IoU = 0.65
# Test. Epoch 3. Iter 32/68, IoU = 0.65
# Test. Epoch 3. Iter 33/68, IoU = 0.64
# Test. Epoch 3. Iter 34/68, IoU = 0.65
# Test. Epoch 3. Iter 35/68, IoU = 0.63
# Test. Epoch 3. Iter 36/68, IoU = 0.63
# Test. Epoch 3. Iter 37/68, IoU = 0.63
# Test. Epoch 3. Iter 38/68, IoU = 0.63
# Test. Epoch 3. Iter 39/68, IoU = 0.63
# Test. Epoch 3. Iter 40/68, IoU = 0.64
# Test. Epoch 3. Iter 41/68, IoU = 0.65
# Test. Epoch 3. Iter 42/68, IoU = 0.64
# Test. Epoch 3. Iter 43/68, IoU = 0.65
# Test. Epoch 3. Iter 44/68, IoU = 0.65
# Test. Epoch 3. Iter 45/68, IoU = 0.66
# Test. Epoch 3. Iter 46/68, IoU = 0.66
# Test. Epoch 3. Iter 47/68, IoU = 0.66
# Test. Epoch 3. Iter 48/68, IoU = 0.67
# Test. Epoch 3. Iter 49/68, IoU = 0.66
# Test. Epoch 3. Iter 50/68, IoU = 0.66
# Test. Epoch 3. Iter 51/68, IoU = 0.66
# Test. Epoch 3. Iter 52/68, IoU = 0.67
# Test. Epoch 3. Iter 53/68, IoU = 0.67
# Test. Epoch 3. Iter 54/68, IoU = 0.67
# Test. Epoch 3. Iter 55/68, IoU = 0.67
# Test. Epoch 3. Iter 56/68, IoU = 0.67
# Test. Epoch 3. Iter 57/68, IoU = 0.67
# Test. Epoch 3. Iter 58/68, IoU = 0.66
# Test. Epoch 3. Iter 59/68, IoU = 0.67
# Test. Epoch 3. Iter 60/68, IoU = 0.67
# Test. Epoch 3. Iter 61/68, IoU = 0.67
# Test. Epoch 3. Iter 62/68, IoU = 0.67
# Test. Epoch 3. Iter 63/68, IoU = 0.67
# Test. Epoch 3. Iter 64/68, IoU = 0.67
# Test. Epoch 3. Iter 65/68, IoU = 0.67
# Test. Epoch 3. Iter 66/68, IoU = 0.67
# Test. Epoch 3. Iter 67/68, IoU = 0.67
# Test. Epoch 3. Iter 68/68, IoU = 0.66
# Train. Epoch 4. Iter 1/100, IoU = 0.44
# Train. Epoch 4. Iter 2/100, IoU = 0.59
# Train. Epoch 4. Iter 3/100, IoU = 0.56
# Train. Epoch 4. Iter 4/100, IoU = 0.46
# Train. Epoch 4. Iter 5/100, IoU = 0.40
# Train. Epoch 4. Iter 6/100, IoU = 0.36
# Train. Epoch 4. Iter 7/100, IoU = 0.35
# Train. Epoch 4. Iter 8/100, IoU = 0.35
# Train. Epoch 4. Iter 9/100, IoU = 0.34
# Train. Epoch 4. Iter 10/100, IoU = 0.38
# Train. Epoch 4. Iter 11/100, IoU = 0.36
# Train. Epoch 4. Iter 12/100, IoU = 0.35
# Train. Epoch 4. Iter 13/100, IoU = 0.34
# Train. Epoch 4. Iter 14/100, IoU = 0.33
# Train. Epoch 4. Iter 15/100, IoU = 0.33
# Train. Epoch 4. Iter 16/100, IoU = 0.35
# Train. Epoch 4. Iter 17/100, IoU = 0.35
# Train. Epoch 4. Iter 18/100, IoU = 0.35
# Train. Epoch 4. Iter 19/100, IoU = 0.36
# Train. Epoch 4. Iter 20/100, IoU = 0.36
# Train. Epoch 4. Iter 21/100, IoU = 0.36
# Train. Epoch 4. Iter 22/100, IoU = 0.36
# Train. Epoch 4. Iter 23/100, IoU = 0.37
# Train. Epoch 4. Iter 24/100, IoU = 0.38
# Train. Epoch 4. Iter 25/100, IoU = 0.38
# Train. Epoch 4. Iter 26/100, IoU = 0.38
# Train. Epoch 4. Iter 27/100, IoU = 0.38
# Train. Epoch 4. Iter 28/100, IoU = 0.39
# Train. Epoch 4. Iter 29/100, IoU = 0.39
# Train. Epoch 4. Iter 30/100, IoU = 0.40
# Train. Epoch 4. Iter 31/100, IoU = 0.39
# Train. Epoch 4. Iter 32/100, IoU = 0.40
# Train. Epoch 4. Iter 33/100, IoU = 0.39
# Train. Epoch 4. Iter 34/100, IoU = 0.39
# Train. Epoch 4. Iter 35/100, IoU = 0.39
# Train. Epoch 4. Iter 36/100, IoU = 0.40
# Train. Epoch 4. Iter 37/100, IoU = 0.40
# Train. Epoch 4. Iter 38/100, IoU = 0.40
# Train. Epoch 4. Iter 39/100, IoU = 0.40
# Train. Epoch 4. Iter 40/100, IoU = 0.41
# Train. Epoch 4. Iter 41/100, IoU = 0.40
# Train. Epoch 4. Iter 42/100, IoU = 0.40
# Train. Epoch 4. Iter 43/100, IoU = 0.40
# Train. Epoch 4. Iter 44/100, IoU = 0.40
# Train. Epoch 4. Iter 45/100, IoU = 0.40
# Train. Epoch 4. Iter 46/100, IoU = 0.39
# Train. Epoch 4. Iter 47/100, IoU = 0.40
# Train. Epoch 4. Iter 48/100, IoU = 0.40
# Train. Epoch 4. Iter 49/100, IoU = 0.40
# Train. Epoch 4. Iter 50/100, IoU = 0.41
# Train. Epoch 4. Iter 51/100, IoU = 0.40
# Train. Epoch 4. Iter 52/100, IoU = 0.40
# Train. Epoch 4. Iter 53/100, IoU = 0.40
# Train. Epoch 4. Iter 54/100, IoU = 0.39
# Train. Epoch 4. Iter 55/100, IoU = 0.39
# Train. Epoch 4. Iter 56/100, IoU = 0.39
# Train. Epoch 4. Iter 57/100, IoU = 0.39
# Train. Epoch 4. Iter 58/100, IoU = 0.39
# Train. Epoch 4. Iter 59/100, IoU = 0.39
# Train. Epoch 4. Iter 60/100, IoU = 0.39
# Train. Epoch 4. Iter 61/100, IoU = 0.39
# Train. Epoch 4. Iter 62/100, IoU = 0.39
# Train. Epoch 4. Iter 63/100, IoU = 0.39
# Train. Epoch 4. Iter 64/100, IoU = 0.39
# Train. Epoch 4. Iter 65/100, IoU = 0.39
# Train. Epoch 4. Iter 66/100, IoU = 0.39
# Train. Epoch 4. Iter 67/100, IoU = 0.39
# Train. Epoch 4. Iter 68/100, IoU = 0.39
# Train. Epoch 4. Iter 69/100, IoU = 0.38
# Train. Epoch 4. Iter 70/100, IoU = 0.39
# Train. Epoch 4. Iter 71/100, IoU = 0.38
# Train. Epoch 4. Iter 72/100, IoU = 0.38
# Train. Epoch 4. Iter 73/100, IoU = 0.39
# Train. Epoch 4. Iter 74/100, IoU = 0.39
# Train. Epoch 4. Iter 75/100, IoU = 0.39
# Train. Epoch 4. Iter 76/100, IoU = 0.39
# Train. Epoch 4. Iter 77/100, IoU = 0.39
# Train. Epoch 4. Iter 78/100, IoU = 0.39
# Train. Epoch 4. Iter 79/100, IoU = 0.39
# Train. Epoch 4. Iter 80/100, IoU = 0.38
# Train. Epoch 4. Iter 81/100, IoU = 0.38
# Train. Epoch 4. Iter 82/100, IoU = 0.38
# Train. Epoch 4. Iter 83/100, IoU = 0.38
# Train. Epoch 4. Iter 84/100, IoU = 0.38
# Train. Epoch 4. Iter 85/100, IoU = 0.38
# Train. Epoch 4. Iter 86/100, IoU = 0.37
# Train. Epoch 4. Iter 87/100, IoU = 0.37
# Train. Epoch 4. Iter 88/100, IoU = 0.37
# Train. Epoch 4. Iter 89/100, IoU = 0.37
# Train. Epoch 4. Iter 90/100, IoU = 0.37
# Train. Epoch 4. Iter 91/100, IoU = 0.38
# Train. Epoch 4. Iter 92/100, IoU = 0.38
# Train. Epoch 4. Iter 93/100, IoU = 0.38
# Train. Epoch 4. Iter 94/100, IoU = 0.37
# Train. Epoch 4. Iter 95/100, IoU = 0.37
# Train. Epoch 4. Iter 96/100, IoU = 0.37
# Train. Epoch 4. Iter 97/100, IoU = 0.37
# Train. Epoch 4. Iter 98/100, IoU = 0.38
# Train. Epoch 4. Iter 99/100, IoU = 0.37
# Train. Epoch 4. Iter 100/100, IoU = 0.37
# Test. Epoch 4. Iter 1/68, IoU = 0.52
# Test. Epoch 4. Iter 2/68, IoU = 0.58
# Test. Epoch 4. Iter 3/68, IoU = 0.62
# Test. Epoch 4. Iter 4/68, IoU = 0.61
# Test. Epoch 4. Iter 5/68, IoU = 0.62
# Test. Epoch 4. Iter 6/68, IoU = 0.62
# Test. Epoch 4. Iter 7/68, IoU = 0.63
# Test. Epoch 4. Iter 8/68, IoU = 0.63
# Test. Epoch 4. Iter 9/68, IoU = 0.63
# Test. Epoch 4. Iter 10/68, IoU = 0.62
# Test. Epoch 4. Iter 11/68, IoU = 0.60
# Test. Epoch 4. Iter 12/68, IoU = 0.61
# Test. Epoch 4. Iter 13/68, IoU = 0.62
# Test. Epoch 4. Iter 14/68, IoU = 0.62
# Test. Epoch 4. Iter 15/68, IoU = 0.61
# Test. Epoch 4. Iter 16/68, IoU = 0.63
# Test. Epoch 4. Iter 17/68, IoU = 0.64
# Test. Epoch 4. Iter 18/68, IoU = 0.61
# Test. Epoch 4. Iter 19/68, IoU = 0.59
# Test. Epoch 4. Iter 20/68, IoU = 0.59
# Test. Epoch 4. Iter 21/68, IoU = 0.60
# Test. Epoch 4. Iter 22/68, IoU = 0.61
# Test. Epoch 4. Iter 23/68, IoU = 0.62
# Test. Epoch 4. Iter 24/68, IoU = 0.63
# Test. Epoch 4. Iter 25/68, IoU = 0.62
# Test. Epoch 4. Iter 26/68, IoU = 0.61
# Test. Epoch 4. Iter 27/68, IoU = 0.61
# Test. Epoch 4. Iter 28/68, IoU = 0.61
# Test. Epoch 4. Iter 29/68, IoU = 0.62
# Test. Epoch 4. Iter 30/68, IoU = 0.61
# Test. Epoch 4. Iter 31/68, IoU = 0.61
# Test. Epoch 4. Iter 32/68, IoU = 0.61
# Test. Epoch 4. Iter 33/68, IoU = 0.60
# Test. Epoch 4. Iter 34/68, IoU = 0.60
# Test. Epoch 4. Iter 35/68, IoU = 0.59
# Test. Epoch 4. Iter 36/68, IoU = 0.59
# Test. Epoch 4. Iter 37/68, IoU = 0.59
# Test. Epoch 4. Iter 38/68, IoU = 0.58
# Test. Epoch 4. Iter 39/68, IoU = 0.58
# Test. Epoch 4. Iter 40/68, IoU = 0.58
# Test. Epoch 4. Iter 41/68, IoU = 0.59
# Test. Epoch 4. Iter 42/68, IoU = 0.59
# Test. Epoch 4. Iter 43/68, IoU = 0.59
# Test. Epoch 4. Iter 44/68, IoU = 0.60
# Test. Epoch 4. Iter 45/68, IoU = 0.61
# Test. Epoch 4. Iter 46/68, IoU = 0.61
# Test. Epoch 4. Iter 47/68, IoU = 0.62
# Test. Epoch 4. Iter 48/68, IoU = 0.62
# Test. Epoch 4. Iter 49/68, IoU = 0.62
# Test. Epoch 4. Iter 50/68, IoU = 0.62
# Test. Epoch 4. Iter 51/68, IoU = 0.62
# Test. Epoch 4. Iter 52/68, IoU = 0.62
# Test. Epoch 4. Iter 53/68, IoU = 0.63
# Test. Epoch 4. Iter 54/68, IoU = 0.63
# Test. Epoch 4. Iter 55/68, IoU = 0.63
# Test. Epoch 4. Iter 56/68, IoU = 0.63
# Test. Epoch 4. Iter 57/68, IoU = 0.63
# Test. Epoch 4. Iter 58/68, IoU = 0.63
# Test. Epoch 4. Iter 59/68, IoU = 0.63
# Test. Epoch 4. Iter 60/68, IoU = 0.63
# Test. Epoch 4. Iter 61/68, IoU = 0.63
# Test. Epoch 4. Iter 62/68, IoU = 0.63
# Test. Epoch 4. Iter 63/68, IoU = 0.63
# Test. Epoch 4. Iter 64/68, IoU = 0.63
# Test. Epoch 4. Iter 65/68, IoU = 0.63
# Test. Epoch 4. Iter 66/68, IoU = 0.63
# Test. Epoch 4. Iter 67/68, IoU = 0.63
# Test. Epoch 4. Iter 68/68, IoU = 0.63
# Train. Epoch 5. Iter 1/100, IoU = 0.59
# Train. Epoch 5. Iter 2/100, IoU = 0.54
# Train. Epoch 5. Iter 3/100, IoU = 0.51
# Train. Epoch 5. Iter 4/100, IoU = 0.52
# Train. Epoch 5. Iter 5/100, IoU = 0.49
# Train. Epoch 5. Iter 6/100, IoU = 0.43
# Train. Epoch 5. Iter 7/100, IoU = 0.41
# Train. Epoch 5. Iter 8/100, IoU = 0.40
# Train. Epoch 5. Iter 9/100, IoU = 0.39
# Train. Epoch 5. Iter 10/100, IoU = 0.42
# Train. Epoch 5. Iter 11/100, IoU = 0.40
# Train. Epoch 5. Iter 12/100, IoU = 0.39
# Train. Epoch 5. Iter 13/100, IoU = 0.37
# Train. Epoch 5. Iter 14/100, IoU = 0.38
# Train. Epoch 5. Iter 15/100, IoU = 0.38
# Train. Epoch 5. Iter 16/100, IoU = 0.39
# Train. Epoch 5. Iter 17/100, IoU = 0.38
# Train. Epoch 5. Iter 18/100, IoU = 0.38
# Train. Epoch 5. Iter 19/100, IoU = 0.38
# Train. Epoch 5. Iter 20/100, IoU = 0.39
# Train. Epoch 5. Iter 21/100, IoU = 0.38
# Train. Epoch 5. Iter 22/100, IoU = 0.38
# Train. Epoch 5. Iter 23/100, IoU = 0.38
# Train. Epoch 5. Iter 24/100, IoU = 0.38
# Train. Epoch 5. Iter 25/100, IoU = 0.39
# Train. Epoch 5. Iter 26/100, IoU = 0.39
# Train. Epoch 5. Iter 27/100, IoU = 0.40
# Train. Epoch 5. Iter 28/100, IoU = 0.40
# Train. Epoch 5. Iter 29/100, IoU = 0.41
# Train. Epoch 5. Iter 30/100, IoU = 0.42
# Train. Epoch 5. Iter 31/100, IoU = 0.41
# Train. Epoch 5. Iter 32/100, IoU = 0.40
# Train. Epoch 5. Iter 33/100, IoU = 0.40
# Train. Epoch 5. Iter 34/100, IoU = 0.39
# Train. Epoch 5. Iter 35/100, IoU = 0.39
# Train. Epoch 5. Iter 36/100, IoU = 0.40
# Train. Epoch 5. Iter 37/100, IoU = 0.40
# Train. Epoch 5. Iter 38/100, IoU = 0.40
# Train. Epoch 5. Iter 39/100, IoU = 0.40
# Train. Epoch 5. Iter 40/100, IoU = 0.41
# Train. Epoch 5. Iter 41/100, IoU = 0.40
# Train. Epoch 5. Iter 42/100, IoU = 0.40
# Train. Epoch 5. Iter 43/100, IoU = 0.40
# Train. Epoch 5. Iter 44/100, IoU = 0.41
# Train. Epoch 5. Iter 45/100, IoU = 0.40
# Train. Epoch 5. Iter 46/100, IoU = 0.40
# Train. Epoch 5. Iter 47/100, IoU = 0.41
# Train. Epoch 5. Iter 48/100, IoU = 0.41
# Train. Epoch 5. Iter 49/100, IoU = 0.42
# Train. Epoch 5. Iter 50/100, IoU = 0.42
# Train. Epoch 5. Iter 51/100, IoU = 0.42
# Train. Epoch 5. Iter 52/100, IoU = 0.42
# Train. Epoch 5. Iter 53/100, IoU = 0.42
# Train. Epoch 5. Iter 54/100, IoU = 0.41
# Train. Epoch 5. Iter 55/100, IoU = 0.41
# Train. Epoch 5. Iter 56/100, IoU = 0.41
# Train. Epoch 5. Iter 57/100, IoU = 0.41
# Train. Epoch 5. Iter 58/100, IoU = 0.41
# Train. Epoch 5. Iter 59/100, IoU = 0.41
# Train. Epoch 5. Iter 60/100, IoU = 0.41
# Train. Epoch 5. Iter 61/100, IoU = 0.41
# Train. Epoch 5. Iter 62/100, IoU = 0.41
# Train. Epoch 5. Iter 63/100, IoU = 0.41
# Train. Epoch 5. Iter 64/100, IoU = 0.41
# Train. Epoch 5. Iter 65/100, IoU = 0.41
# Train. Epoch 5. Iter 66/100, IoU = 0.41
# Train. Epoch 5. Iter 67/100, IoU = 0.42
# Train. Epoch 5. Iter 68/100, IoU = 0.42
# Train. Epoch 5. Iter 69/100, IoU = 0.41
# Train. Epoch 5. Iter 70/100, IoU = 0.41
# Train. Epoch 5. Iter 71/100, IoU = 0.41
# Train. Epoch 5. Iter 72/100, IoU = 0.41
# Train. Epoch 5. Iter 73/100, IoU = 0.41
# Train. Epoch 5. Iter 74/100, IoU = 0.41
# Train. Epoch 5. Iter 75/100, IoU = 0.41
# Train. Epoch 5. Iter 76/100, IoU = 0.41
# Train. Epoch 5. Iter 77/100, IoU = 0.40
# Train. Epoch 5. Iter 78/100, IoU = 0.40
# Train. Epoch 5. Iter 79/100, IoU = 0.40
# Train. Epoch 5. Iter 80/100, IoU = 0.40
# Train. Epoch 5. Iter 81/100, IoU = 0.40
# Train. Epoch 5. Iter 82/100, IoU = 0.40
# Train. Epoch 5. Iter 83/100, IoU = 0.39
# Train. Epoch 5. Iter 84/100, IoU = 0.39
# Train. Epoch 5. Iter 85/100, IoU = 0.39
# Train. Epoch 5. Iter 86/100, IoU = 0.39
# Train. Epoch 5. Iter 87/100, IoU = 0.39
# Train. Epoch 5. Iter 88/100, IoU = 0.39
# Train. Epoch 5. Iter 89/100, IoU = 0.39
# Train. Epoch 5. Iter 90/100, IoU = 0.39
# Train. Epoch 5. Iter 91/100, IoU = 0.39
# Train. Epoch 5. Iter 92/100, IoU = 0.39
# Train. Epoch 5. Iter 93/100, IoU = 0.39
# Train. Epoch 5. Iter 94/100, IoU = 0.39
# Train. Epoch 5. Iter 95/100, IoU = 0.39
# Train. Epoch 5. Iter 96/100, IoU = 0.39
# Train. Epoch 5. Iter 97/100, IoU = 0.39
# Train. Epoch 5. Iter 98/100, IoU = 0.39
# Train. Epoch 5. Iter 99/100, IoU = 0.39
# Train. Epoch 5. Iter 100/100, IoU = 0.39
# Test. Epoch 5. Iter 1/68, IoU = 0.45
# Test. Epoch 5. Iter 2/68, IoU = 0.60
# Test. Epoch 5. Iter 3/68, IoU = 0.64
# Test. Epoch 5. Iter 4/68, IoU = 0.62
# Test. Epoch 5. Iter 5/68, IoU = 0.62
# Test. Epoch 5. Iter 6/68, IoU = 0.61
# Test. Epoch 5. Iter 7/68, IoU = 0.62
# Test. Epoch 5. Iter 8/68, IoU = 0.63
# Test. Epoch 5. Iter 9/68, IoU = 0.64
# Test. Epoch 5. Iter 10/68, IoU = 0.63
# Test. Epoch 5. Iter 11/68, IoU = 0.61
# Test. Epoch 5. Iter 12/68, IoU = 0.62
# Test. Epoch 5. Iter 13/68, IoU = 0.62
# Test. Epoch 5. Iter 14/68, IoU = 0.62
# Test. Epoch 5. Iter 15/68, IoU = 0.61
# Test. Epoch 5. Iter 16/68, IoU = 0.62
# Test. Epoch 5. Iter 17/68, IoU = 0.64
# Test. Epoch 5. Iter 18/68, IoU = 0.61
# Test. Epoch 5. Iter 19/68, IoU = 0.59
# Test. Epoch 5. Iter 20/68, IoU = 0.59
# Test. Epoch 5. Iter 21/68, IoU = 0.59
# Test. Epoch 5. Iter 22/68, IoU = 0.61
# Test. Epoch 5. Iter 23/68, IoU = 0.62
# Test. Epoch 5. Iter 24/68, IoU = 0.63
# Test. Epoch 5. Iter 25/68, IoU = 0.62
# Test. Epoch 5. Iter 26/68, IoU = 0.61
# Test. Epoch 5. Iter 27/68, IoU = 0.61
# Test. Epoch 5. Iter 28/68, IoU = 0.61
# Test. Epoch 5. Iter 29/68, IoU = 0.61
# Test. Epoch 5. Iter 30/68, IoU = 0.60
# Test. Epoch 5. Iter 31/68, IoU = 0.60
# Test. Epoch 5. Iter 32/68, IoU = 0.60
# Test. Epoch 5. Iter 33/68, IoU = 0.60
# Test. Epoch 5. Iter 34/68, IoU = 0.60
# Test. Epoch 5. Iter 35/68, IoU = 0.58
# Test. Epoch 5. Iter 36/68, IoU = 0.59
# Test. Epoch 5. Iter 37/68, IoU = 0.59
# Test. Epoch 5. Iter 38/68, IoU = 0.58
# Test. Epoch 5. Iter 39/68, IoU = 0.58
# Test. Epoch 5. Iter 40/68, IoU = 0.59
# Test. Epoch 5. Iter 41/68, IoU = 0.59
# Test. Epoch 5. Iter 42/68, IoU = 0.59
# Test. Epoch 5. Iter 43/68, IoU = 0.60
# Test. Epoch 5. Iter 44/68, IoU = 0.60
# Test. Epoch 5. Iter 45/68, IoU = 0.61
# Test. Epoch 5. Iter 46/68, IoU = 0.61
# Test. Epoch 5. Iter 47/68, IoU = 0.62
# Test. Epoch 5. Iter 48/68, IoU = 0.62
# Test. Epoch 5. Iter 49/68, IoU = 0.62
# Test. Epoch 5. Iter 50/68, IoU = 0.62
# Test. Epoch 5. Iter 51/68, IoU = 0.62
# Test. Epoch 5. Iter 52/68, IoU = 0.62
# Test. Epoch 5. Iter 53/68, IoU = 0.63
# Test. Epoch 5. Iter 54/68, IoU = 0.63
# Test. Epoch 5. Iter 55/68, IoU = 0.63
# Test. Epoch 5. Iter 56/68, IoU = 0.63
# Test. Epoch 5. Iter 57/68, IoU = 0.63
# Test. Epoch 5. Iter 58/68, IoU = 0.63
# Test. Epoch 5. Iter 59/68, IoU = 0.63
# Test. Epoch 5. Iter 60/68, IoU = 0.63
# Test. Epoch 5. Iter 61/68, IoU = 0.63
# Test. Epoch 5. Iter 62/68, IoU = 0.63
# Test. Epoch 5. Iter 63/68, IoU = 0.63
# Test. Epoch 5. Iter 64/68, IoU = 0.63
# Test. Epoch 5. Iter 65/68, IoU = 0.63
# Test. Epoch 5. Iter 66/68, IoU = 0.63
# Test. Epoch 5. Iter 67/68, IoU = 0.63
# Test. Epoch 5. Iter 68/68, IoU = 0.63
# Train. Epoch 6. Iter 1/100, IoU = 0.54
# Train. Epoch 6. Iter 2/100, IoU = 0.54
# Train. Epoch 6. Iter 3/100, IoU = 0.56
# Train. Epoch 6. Iter 4/100, IoU = 0.49
# Train. Epoch 6. Iter 5/100, IoU = 0.45
# Train. Epoch 6. Iter 6/100, IoU = 0.40
# Train. Epoch 6. Iter 7/100, IoU = 0.42
# Train. Epoch 6. Iter 8/100, IoU = 0.41
# Train. Epoch 6. Iter 9/100, IoU = 0.41
# Train. Epoch 6. Iter 10/100, IoU = 0.44
# Train. Epoch 6. Iter 11/100, IoU = 0.42
# Train. Epoch 6. Iter 12/100, IoU = 0.41
# Train. Epoch 6. Iter 13/100, IoU = 0.40
# Train. Epoch 6. Iter 14/100, IoU = 0.42
# Train. Epoch 6. Iter 15/100, IoU = 0.43
# Train. Epoch 6. Iter 16/100, IoU = 0.45
# Train. Epoch 6. Iter 17/100, IoU = 0.47
# Train. Epoch 6. Iter 18/100, IoU = 0.47
# Train. Epoch 6. Iter 19/100, IoU = 0.48
# Train. Epoch 6. Iter 20/100, IoU = 0.48
# Train. Epoch 6. Iter 21/100, IoU = 0.48
# Train. Epoch 6. Iter 22/100, IoU = 0.48
# Train. Epoch 6. Iter 23/100, IoU = 0.48
# Train. Epoch 6. Iter 24/100, IoU = 0.47
# Train. Epoch 6. Iter 25/100, IoU = 0.46
# Train. Epoch 6. Iter 26/100, IoU = 0.47
# Train. Epoch 6. Iter 27/100, IoU = 0.46
# Train. Epoch 6. Iter 28/100, IoU = 0.47
# Train. Epoch 6. Iter 29/100, IoU = 0.48
# Train. Epoch 6. Iter 30/100, IoU = 0.48
# Train. Epoch 6. Iter 31/100, IoU = 0.47
# Train. Epoch 6. Iter 32/100, IoU = 0.46
# Train. Epoch 6. Iter 33/100, IoU = 0.46
# Train. Epoch 6. Iter 34/100, IoU = 0.45
# Train. Epoch 6. Iter 35/100, IoU = 0.45
# Train. Epoch 6. Iter 36/100, IoU = 0.45
# Train. Epoch 6. Iter 37/100, IoU = 0.45
# Train. Epoch 6. Iter 38/100, IoU = 0.44
# Train. Epoch 6. Iter 39/100, IoU = 0.45
# Train. Epoch 6. Iter 40/100, IoU = 0.45
# Train. Epoch 6. Iter 41/100, IoU = 0.44
# Train. Epoch 6. Iter 42/100, IoU = 0.44
# Train. Epoch 6. Iter 43/100, IoU = 0.43
# Train. Epoch 6. Iter 44/100, IoU = 0.43
# Train. Epoch 6. Iter 45/100, IoU = 0.43
# Train. Epoch 6. Iter 46/100, IoU = 0.43
# Train. Epoch 6. Iter 47/100, IoU = 0.43
# Train. Epoch 6. Iter 48/100, IoU = 0.44
# Train. Epoch 6. Iter 49/100, IoU = 0.44
# Train. Epoch 6. Iter 50/100, IoU = 0.44
# Train. Epoch 6. Iter 51/100, IoU = 0.44
# Train. Epoch 6. Iter 52/100, IoU = 0.44
# Train. Epoch 6. Iter 53/100, IoU = 0.43
# Train. Epoch 6. Iter 54/100, IoU = 0.43
# Train. Epoch 6. Iter 55/100, IoU = 0.43
# Train. Epoch 6. Iter 56/100, IoU = 0.43
# Train. Epoch 6. Iter 57/100, IoU = 0.43
# Train. Epoch 6. Iter 58/100, IoU = 0.43
# Train. Epoch 6. Iter 59/100, IoU = 0.43
# Train. Epoch 6. Iter 60/100, IoU = 0.43
# Train. Epoch 6. Iter 61/100, IoU = 0.44
# Train. Epoch 6. Iter 62/100, IoU = 0.43
# Train. Epoch 6. Iter 63/100, IoU = 0.43
# Train. Epoch 6. Iter 64/100, IoU = 0.43
# Train. Epoch 6. Iter 65/100, IoU = 0.44
# Train. Epoch 6. Iter 66/100, IoU = 0.44
# Train. Epoch 6. Iter 67/100, IoU = 0.44
# Train. Epoch 6. Iter 68/100, IoU = 0.44
# Train. Epoch 6. Iter 69/100, IoU = 0.44
# Train. Epoch 6. Iter 70/100, IoU = 0.44
# Train. Epoch 6. Iter 71/100, IoU = 0.43
# Train. Epoch 6. Iter 72/100, IoU = 0.43
# Train. Epoch 6. Iter 73/100, IoU = 0.43
# Train. Epoch 6. Iter 74/100, IoU = 0.44
# Train. Epoch 6. Iter 75/100, IoU = 0.44
# Train. Epoch 6. Iter 76/100, IoU = 0.44
# Train. Epoch 6. Iter 77/100, IoU = 0.44
# Train. Epoch 6. Iter 78/100, IoU = 0.44
# Train. Epoch 6. Iter 79/100, IoU = 0.43
# Train. Epoch 6. Iter 80/100, IoU = 0.43
# Train. Epoch 6. Iter 81/100, IoU = 0.43
# Train. Epoch 6. Iter 82/100, IoU = 0.43
# Train. Epoch 6. Iter 83/100, IoU = 0.43
# Train. Epoch 6. Iter 84/100, IoU = 0.43
# Train. Epoch 6. Iter 85/100, IoU = 0.43
# Train. Epoch 6. Iter 86/100, IoU = 0.43
# Train. Epoch 6. Iter 87/100, IoU = 0.42
# Train. Epoch 6. Iter 88/100, IoU = 0.42
# Train. Epoch 6. Iter 89/100, IoU = 0.42
# Train. Epoch 6. Iter 90/100, IoU = 0.42
# Train. Epoch 6. Iter 91/100, IoU = 0.43
# Train. Epoch 6. Iter 92/100, IoU = 0.43
# Train. Epoch 6. Iter 93/100, IoU = 0.42
# Train. Epoch 6. Iter 94/100, IoU = 0.42
# Train. Epoch 6. Iter 95/100, IoU = 0.42
# Train. Epoch 6. Iter 96/100, IoU = 0.42
# Train. Epoch 6. Iter 97/100, IoU = 0.42
# Train. Epoch 6. Iter 98/100, IoU = 0.43
# Train. Epoch 6. Iter 99/100, IoU = 0.43
# Train. Epoch 6. Iter 100/100, IoU = 0.42
# Test. Epoch 6. Iter 1/68, IoU = 0.34
# Test. Epoch 6. Iter 2/68, IoU = 0.56
# Test. Epoch 6. Iter 3/68, IoU = 0.63
# Test. Epoch 6. Iter 4/68, IoU = 0.62
# Test. Epoch 6. Iter 5/68, IoU = 0.62
# Test. Epoch 6. Iter 6/68, IoU = 0.60
# Test. Epoch 6. Iter 7/68, IoU = 0.62
# Test. Epoch 6. Iter 8/68, IoU = 0.64
# Test. Epoch 6. Iter 9/68, IoU = 0.65
# Test. Epoch 6. Iter 10/68, IoU = 0.66
# Test. Epoch 6. Iter 11/68, IoU = 0.65
# Test. Epoch 6. Iter 12/68, IoU = 0.65
# Test. Epoch 6. Iter 13/68, IoU = 0.66
# Test. Epoch 6. Iter 14/68, IoU = 0.65
# Test. Epoch 6. Iter 15/68, IoU = 0.64
# Test. Epoch 6. Iter 16/68, IoU = 0.65
# Test. Epoch 6. Iter 17/68, IoU = 0.67
# Test. Epoch 6. Iter 18/68, IoU = 0.64
# Test. Epoch 6. Iter 19/68, IoU = 0.62
# Test. Epoch 6. Iter 20/68, IoU = 0.62
# Test. Epoch 6. Iter 21/68, IoU = 0.62
# Test. Epoch 6. Iter 22/68, IoU = 0.63
# Test. Epoch 6. Iter 23/68, IoU = 0.64
# Test. Epoch 6. Iter 24/68, IoU = 0.65
# Test. Epoch 6. Iter 25/68, IoU = 0.64
# Test. Epoch 6. Iter 26/68, IoU = 0.64
# Test. Epoch 6. Iter 27/68, IoU = 0.64
# Test. Epoch 6. Iter 28/68, IoU = 0.64
# Test. Epoch 6. Iter 29/68, IoU = 0.64
# Test. Epoch 6. Iter 30/68, IoU = 0.63
# Test. Epoch 6. Iter 31/68, IoU = 0.63
# Test. Epoch 6. Iter 32/68, IoU = 0.63
# Test. Epoch 6. Iter 33/68, IoU = 0.63
# Test. Epoch 6. Iter 34/68, IoU = 0.63
# Test. Epoch 6. Iter 35/68, IoU = 0.61
# Test. Epoch 6. Iter 36/68, IoU = 0.62
# Test. Epoch 6. Iter 37/68, IoU = 0.62
# Test. Epoch 6. Iter 38/68, IoU = 0.61
# Test. Epoch 6. Iter 39/68, IoU = 0.61
# Test. Epoch 6. Iter 40/68, IoU = 0.62
# Test. Epoch 6. Iter 41/68, IoU = 0.62
# Test. Epoch 6. Iter 42/68, IoU = 0.62
# Test. Epoch 6. Iter 43/68, IoU = 0.62
# Test. Epoch 6. Iter 44/68, IoU = 0.63
# Test. Epoch 6. Iter 45/68, IoU = 0.64
# Test. Epoch 6. Iter 46/68, IoU = 0.64
# Test. Epoch 6. Iter 47/68, IoU = 0.64
# Test. Epoch 6. Iter 48/68, IoU = 0.65
# Test. Epoch 6. Iter 49/68, IoU = 0.64
# Test. Epoch 6. Iter 50/68, IoU = 0.65
# Test. Epoch 6. Iter 51/68, IoU = 0.64
# Test. Epoch 6. Iter 52/68, IoU = 0.65
# Test. Epoch 6. Iter 53/68, IoU = 0.65
# Test. Epoch 6. Iter 54/68, IoU = 0.65
# Test. Epoch 6. Iter 55/68, IoU = 0.65
# Test. Epoch 6. Iter 56/68, IoU = 0.65
# Test. Epoch 6. Iter 57/68, IoU = 0.65
# Test. Epoch 6. Iter 58/68, IoU = 0.65
# Test. Epoch 6. Iter 59/68, IoU = 0.65
# Test. Epoch 6. Iter 60/68, IoU = 0.66
# Test. Epoch 6. Iter 61/68, IoU = 0.65
# Test. Epoch 6. Iter 62/68, IoU = 0.66
# Test. Epoch 6. Iter 63/68, IoU = 0.65
# Test. Epoch 6. Iter 64/68, IoU = 0.65
# Test. Epoch 6. Iter 65/68, IoU = 0.65
# Test. Epoch 6. Iter 66/68, IoU = 0.65
# Test. Epoch 6. Iter 67/68, IoU = 0.65
# Test. Epoch 6. Iter 68/68, IoU = 0.65
# Train. Epoch 7. Iter 1/100, IoU = 0.59
# Train. Epoch 7. Iter 2/100, IoU = 0.59
# Train. Epoch 7. Iter 3/100, IoU = 0.56
# Train. Epoch 7. Iter 4/100, IoU = 0.49
# Train. Epoch 7. Iter 5/100, IoU = 0.44
# Train. Epoch 7. Iter 6/100, IoU = 0.40
# Train. Epoch 7. Iter 7/100, IoU = 0.42
# Train. Epoch 7. Iter 8/100, IoU = 0.41
# Train. Epoch 7. Iter 9/100, IoU = 0.41
# Train. Epoch 7. Iter 10/100, IoU = 0.44
# Train. Epoch 7. Iter 11/100, IoU = 0.42
# Train. Epoch 7. Iter 12/100, IoU = 0.41
# Train. Epoch 7. Iter 13/100, IoU = 0.41
# Train. Epoch 7. Iter 14/100, IoU = 0.44
# Train. Epoch 7. Iter 15/100, IoU = 0.44
# Train. Epoch 7. Iter 16/100, IoU = 0.45
# Train. Epoch 7. Iter 17/100, IoU = 0.45
# Train. Epoch 7. Iter 18/100, IoU = 0.45
# Train. Epoch 7. Iter 19/100, IoU = 0.45
# Train. Epoch 7. Iter 20/100, IoU = 0.46
# Train. Epoch 7. Iter 21/100, IoU = 0.44
# Train. Epoch 7. Iter 22/100, IoU = 0.45
# Train. Epoch 7. Iter 23/100, IoU = 0.45
# Train. Epoch 7. Iter 24/100, IoU = 0.46
# Train. Epoch 7. Iter 25/100, IoU = 0.46
# Train. Epoch 7. Iter 26/100, IoU = 0.47
# Train. Epoch 7. Iter 27/100, IoU = 0.47
# Train. Epoch 7. Iter 28/100, IoU = 0.48
# Train. Epoch 7. Iter 29/100, IoU = 0.49
# Train. Epoch 7. Iter 30/100, IoU = 0.49
# Train. Epoch 7. Iter 31/100, IoU = 0.48
# Train. Epoch 7. Iter 32/100, IoU = 0.47
# Train. Epoch 7. Iter 33/100, IoU = 0.47
# Train. Epoch 7. Iter 34/100, IoU = 0.47
# Train. Epoch 7. Iter 35/100, IoU = 0.46
# Train. Epoch 7. Iter 36/100, IoU = 0.47
# Train. Epoch 7. Iter 37/100, IoU = 0.46
# Train. Epoch 7. Iter 38/100, IoU = 0.46
# Train. Epoch 7. Iter 39/100, IoU = 0.46
# Train. Epoch 7. Iter 40/100, IoU = 0.46
# Train. Epoch 7. Iter 41/100, IoU = 0.45
# Train. Epoch 7. Iter 42/100, IoU = 0.45
# Train. Epoch 7. Iter 43/100, IoU = 0.45
# Train. Epoch 7. Iter 44/100, IoU = 0.45
# Train. Epoch 7. Iter 45/100, IoU = 0.44
# Train. Epoch 7. Iter 46/100, IoU = 0.44
# Train. Epoch 7. Iter 47/100, IoU = 0.44
# Train. Epoch 7. Iter 48/100, IoU = 0.45
# Train. Epoch 7. Iter 49/100, IoU = 0.45
# Train. Epoch 7. Iter 50/100, IoU = 0.45
# Train. Epoch 7. Iter 51/100, IoU = 0.45
# ...
# Test. Epoch 97. Iter 4/68, IoU = 0.74
# Test. Epoch 97. Iter 5/68, IoU = 0.76
# Test. Epoch 97. Iter 6/68, IoU = 0.71
# Test. Epoch 97. Iter 7/68, IoU = 0.73
# Test. Epoch 97. Iter 8/68, IoU = 0.75
# Test. Epoch 97. Iter 9/68, IoU = 0.75
# Test. Epoch 97. Iter 10/68, IoU = 0.77
# Test. Epoch 97. Iter 11/68, IoU = 0.75
# Test. Epoch 97. Iter 12/68, IoU = 0.77
# Test. Epoch 97. Iter 13/68, IoU = 0.78
# Test. Epoch 97. Iter 14/68, IoU = 0.78
# Test. Epoch 97. Iter 15/68, IoU = 0.78
# Test. Epoch 97. Iter 16/68, IoU = 0.79
# Test. Epoch 97. Iter 17/68, IoU = 0.80
# Test. Epoch 97. Iter 18/68, IoU = 0.80
# Test. Epoch 97. Iter 19/68, IoU = 0.79
# Test. Epoch 97. Iter 20/68, IoU = 0.79
# Test. Epoch 97. Iter 21/68, IoU = 0.79
# Test. Epoch 97. Iter 22/68, IoU = 0.79
# Test. Epoch 97. Iter 23/68, IoU = 0.80
# Test. Epoch 97. Iter 24/68, IoU = 0.80
# Test. Epoch 97. Iter 25/68, IoU = 0.80
# Test. Epoch 97. Iter 26/68, IoU = 0.81
# Test. Epoch 97. Iter 27/68, IoU = 0.81
# Test. Epoch 97. Iter 28/68, IoU = 0.81
# Test. Epoch 97. Iter 29/68, IoU = 0.82
# Test. Epoch 97. Iter 30/68, IoU = 0.82
# Test. Epoch 97. Iter 31/68, IoU = 0.82
# Test. Epoch 97. Iter 32/68, IoU = 0.82
# Test. Epoch 97. Iter 33/68, IoU = 0.82
# Test. Epoch 97. Iter 34/68, IoU = 0.82
# Test. Epoch 97. Iter 35/68, IoU = 0.83
# Test. Epoch 97. Iter 36/68, IoU = 0.83
# Test. Epoch 97. Iter 37/68, IoU = 0.83
# Test. Epoch 97. Iter 38/68, IoU = 0.83
# Test. Epoch 97. Iter 39/68, IoU = 0.83
# Test. Epoch 97. Iter 40/68, IoU = 0.83
# Test. Epoch 97. Iter 41/68, IoU = 0.83
# Test. Epoch 97. Iter 42/68, IoU = 0.83
# Test. Epoch 97. Iter 43/68, IoU = 0.84
# Test. Epoch 97. Iter 44/68, IoU = 0.84
# Test. Epoch 97. Iter 45/68, IoU = 0.84
# Test. Epoch 97. Iter 46/68, IoU = 0.84
# Test. Epoch 97. Iter 47/68, IoU = 0.84
# Test. Epoch 97. Iter 48/68, IoU = 0.84
# Test. Epoch 97. Iter 49/68, IoU = 0.84
# Test. Epoch 97. Iter 50/68, IoU = 0.84
# Test. Epoch 97. Iter 51/68, IoU = 0.84
# Test. Epoch 97. Iter 52/68, IoU = 0.84
# Test. Epoch 97. Iter 53/68, IoU = 0.84
# Test. Epoch 97. Iter 54/68, IoU = 0.84
# Test. Epoch 97. Iter 55/68, IoU = 0.84
# Test. Epoch 97. Iter 56/68, IoU = 0.84
# Test. Epoch 97. Iter 57/68, IoU = 0.84
# Test. Epoch 97. Iter 58/68, IoU = 0.84
# Test. Epoch 97. Iter 59/68, IoU = 0.84
# Test. Epoch 97. Iter 60/68, IoU = 0.84
# Test. Epoch 97. Iter 61/68, IoU = 0.84
# Test. Epoch 97. Iter 62/68, IoU = 0.84
# Test. Epoch 97. Iter 63/68, IoU = 0.84
# Test. Epoch 97. Iter 64/68, IoU = 0.84
# Test. Epoch 97. Iter 65/68, IoU = 0.84
# Test. Epoch 97. Iter 66/68, IoU = 0.84
# Test. Epoch 97. Iter 67/68, IoU = 0.84
# Test. Epoch 97. Iter 68/68, IoU = 0.83
# Train. Epoch 98. Iter 1/100, IoU = 0.77
# Train. Epoch 98. Iter 2/100, IoU = 0.67
# Train. Epoch 98. Iter 3/100, IoU = 0.69
# Train. Epoch 98. Iter 4/100, IoU = 0.63
# Train. Epoch 98. Iter 5/100, IoU = 0.64
# Train. Epoch 98. Iter 6/100, IoU = 0.65
# Train. Epoch 98. Iter 7/100, IoU = 0.67
# Train. Epoch 98. Iter 8/100, IoU = 0.64
# Train. Epoch 98. Iter 9/100, IoU = 0.63
# Train. Epoch 98. Iter 10/100, IoU = 0.64
# Train. Epoch 98. Iter 11/100, IoU = 0.64
# Train. Epoch 98. Iter 12/100, IoU = 0.62
# Train. Epoch 98. Iter 13/100, IoU = 0.61
# Train. Epoch 98. Iter 14/100, IoU = 0.62
# Train. Epoch 98. Iter 15/100, IoU = 0.63
# Train. Epoch 98. Iter 16/100, IoU = 0.64
# Train. Epoch 98. Iter 17/100, IoU = 0.65
# Train. Epoch 98. Iter 18/100, IoU = 0.64
# Train. Epoch 98. Iter 19/100, IoU = 0.63
# Train. Epoch 98. Iter 20/100, IoU = 0.62
# Train. Epoch 98. Iter 21/100, IoU = 0.63
# Train. Epoch 98. Iter 22/100, IoU = 0.63
# Train. Epoch 98. Iter 23/100, IoU = 0.63
# Train. Epoch 98. Iter 24/100, IoU = 0.63
# Train. Epoch 98. Iter 25/100, IoU = 0.64
# Train. Epoch 98. Iter 26/100, IoU = 0.63
# Train. Epoch 98. Iter 27/100, IoU = 0.64
# Train. Epoch 98. Iter 28/100, IoU = 0.64
# Train. Epoch 98. Iter 29/100, IoU = 0.65
# Train. Epoch 98. Iter 30/100, IoU = 0.65
# Train. Epoch 98. Iter 31/100, IoU = 0.65
# Train. Epoch 98. Iter 32/100, IoU = 0.66
# Train. Epoch 98. Iter 33/100, IoU = 0.65
# Train. Epoch 98. Iter 34/100, IoU = 0.66
# Train. Epoch 98. Iter 35/100, IoU = 0.65
# Train. Epoch 98. Iter 36/100, IoU = 0.66
# Train. Epoch 98. Iter 37/100, IoU = 0.66
# Train. Epoch 98. Iter 38/100, IoU = 0.66
# Train. Epoch 98. Iter 39/100, IoU = 0.66
# Train. Epoch 98. Iter 40/100, IoU = 0.66
# Train. Epoch 98. Iter 41/100, IoU = 0.66
# Train. Epoch 98. Iter 42/100, IoU = 0.66
# Train. Epoch 98. Iter 43/100, IoU = 0.66
# Train. Epoch 98. Iter 44/100, IoU = 0.67
# Train. Epoch 98. Iter 45/100, IoU = 0.66
# Train. Epoch 98. Iter 46/100, IoU = 0.66
# Train. Epoch 98. Iter 47/100, IoU = 0.66
# Train. Epoch 98. Iter 48/100, IoU = 0.66
# Train. Epoch 98. Iter 49/100, IoU = 0.67
# Train. Epoch 98. Iter 50/100, IoU = 0.67
# Train. Epoch 98. Iter 51/100, IoU = 0.66
# Train. Epoch 98. Iter 52/100, IoU = 0.67
# Train. Epoch 98. Iter 53/100, IoU = 0.67
# Train. Epoch 98. Iter 54/100, IoU = 0.67
# Train. Epoch 98. Iter 55/100, IoU = 0.67
# Train. Epoch 98. Iter 56/100, IoU = 0.67
# Train. Epoch 98. Iter 57/100, IoU = 0.67
# Train. Epoch 98. Iter 58/100, IoU = 0.67
# Train. Epoch 98. Iter 59/100, IoU = 0.67
# Train. Epoch 98. Iter 60/100, IoU = 0.68
# Train. Epoch 98. Iter 61/100, IoU = 0.68
# Train. Epoch 98. Iter 62/100, IoU = 0.68
# Train. Epoch 98. Iter 63/100, IoU = 0.68
# Train. Epoch 98. Iter 64/100, IoU = 0.68
# Train. Epoch 98. Iter 65/100, IoU = 0.69
# Train. Epoch 98. Iter 66/100, IoU = 0.69
# Train. Epoch 98. Iter 67/100, IoU = 0.69
# Train. Epoch 98. Iter 68/100, IoU = 0.69
# Train. Epoch 98. Iter 69/100, IoU = 0.69
# Train. Epoch 98. Iter 70/100, IoU = 0.69
# Train. Epoch 98. Iter 71/100, IoU = 0.69
# Train. Epoch 98. Iter 72/100, IoU = 0.68
# Train. Epoch 98. Iter 73/100, IoU = 0.69
# Train. Epoch 98. Iter 74/100, IoU = 0.69
# Train. Epoch 98. Iter 75/100, IoU = 0.68
# Train. Epoch 98. Iter 76/100, IoU = 0.69
# Train. Epoch 98. Iter 77/100, IoU = 0.68
# Train. Epoch 98. Iter 78/100, IoU = 0.68
# Train. Epoch 98. Iter 79/100, IoU = 0.68
# Train. Epoch 98. Iter 80/100, IoU = 0.69
# Train. Epoch 98. Iter 81/100, IoU = 0.69
# Train. Epoch 98. Iter 82/100, IoU = 0.69
# Train. Epoch 98. Iter 83/100, IoU = 0.68
# Train. Epoch 98. Iter 84/100, IoU = 0.68
# Train. Epoch 98. Iter 85/100, IoU = 0.68
# Train. Epoch 98. Iter 86/100, IoU = 0.68
# Train. Epoch 98. Iter 87/100, IoU = 0.68
# Train. Epoch 98. Iter 88/100, IoU = 0.68
# Train. Epoch 98. Iter 89/100, IoU = 0.68
# Train. Epoch 98. Iter 90/100, IoU = 0.68
# Train. Epoch 98. Iter 91/100, IoU = 0.68
# Train. Epoch 98. Iter 92/100, IoU = 0.68
# Train. Epoch 98. Iter 93/100, IoU = 0.68
# Train. Epoch 98. Iter 94/100, IoU = 0.68
# Train. Epoch 98. Iter 95/100, IoU = 0.68
# Train. Epoch 98. Iter 96/100, IoU = 0.68
# Train. Epoch 98. Iter 97/100, IoU = 0.68
# Train. Epoch 98. Iter 98/100, IoU = 0.68
# Train. Epoch 98. Iter 99/100, IoU = 0.68
# Train. Epoch 98. Iter 100/100, IoU = 0.68
# Test. Epoch 98. Iter 1/68, IoU = 0.49
# Test. Epoch 98. Iter 2/68, IoU = 0.68
# Test. Epoch 98. Iter 3/68, IoU = 0.76
# Test. Epoch 98. Iter 4/68, IoU = 0.77
# Test. Epoch 98. Iter 5/68, IoU = 0.78
# Test. Epoch 98. Iter 6/68, IoU = 0.78
# Test. Epoch 98. Iter 7/68, IoU = 0.79
# Test. Epoch 98. Iter 8/68, IoU = 0.81
# Test. Epoch 98. Iter 9/68, IoU = 0.81
# Test. Epoch 98. Iter 10/68, IoU = 0.82
# Test. Epoch 98. Iter 11/68, IoU = 0.81
# Test. Epoch 98. Iter 12/68, IoU = 0.81
# Test. Epoch 98. Iter 13/68, IoU = 0.82
# Test. Epoch 98. Iter 14/68, IoU = 0.83
# Test. Epoch 98. Iter 15/68, IoU = 0.83
# Test. Epoch 98. Iter 16/68, IoU = 0.83
# Test. Epoch 98. Iter 17/68, IoU = 0.84
# Test. Epoch 98. Iter 18/68, IoU = 0.84
# Test. Epoch 98. Iter 19/68, IoU = 0.82
# Test. Epoch 98. Iter 20/68, IoU = 0.82
# Test. Epoch 98. Iter 21/68, IoU = 0.82
# Test. Epoch 98. Iter 22/68, IoU = 0.82
# Test. Epoch 98. Iter 23/68, IoU = 0.82
# Test. Epoch 98. Iter 24/68, IoU = 0.83
# Test. Epoch 98. Iter 25/68, IoU = 0.83
# Test. Epoch 98. Iter 26/68, IoU = 0.83
# Test. Epoch 98. Iter 27/68, IoU = 0.84
# Test. Epoch 98. Iter 28/68, IoU = 0.84
# Test. Epoch 98. Iter 29/68, IoU = 0.84
# Test. Epoch 98. Iter 30/68, IoU = 0.84
# Test. Epoch 98. Iter 31/68, IoU = 0.84
# Test. Epoch 98. Iter 32/68, IoU = 0.84
# Test. Epoch 98. Iter 33/68, IoU = 0.84
# Test. Epoch 98. Iter 34/68, IoU = 0.84
# Test. Epoch 98. Iter 35/68, IoU = 0.84
# Test. Epoch 98. Iter 36/68, IoU = 0.85
# Test. Epoch 98. Iter 37/68, IoU = 0.85
# Test. Epoch 98. Iter 38/68, IoU = 0.85
# Test. Epoch 98. Iter 39/68, IoU = 0.84
# Test. Epoch 98. Iter 40/68, IoU = 0.84
# Test. Epoch 98. Iter 41/68, IoU = 0.84
# Test. Epoch 98. Iter 42/68, IoU = 0.84
# Test. Epoch 98. Iter 43/68, IoU = 0.84
# Test. Epoch 98. Iter 44/68, IoU = 0.84
# Test. Epoch 98. Iter 45/68, IoU = 0.84
# Test. Epoch 98. Iter 46/68, IoU = 0.84
# Test. Epoch 98. Iter 47/68, IoU = 0.84
# Test. Epoch 98. Iter 48/68, IoU = 0.84
# Test. Epoch 98. Iter 49/68, IoU = 0.85
# Test. Epoch 98. Iter 50/68, IoU = 0.85
# Test. Epoch 98. Iter 51/68, IoU = 0.84
# Test. Epoch 98. Iter 52/68, IoU = 0.84
# Test. Epoch 98. Iter 53/68, IoU = 0.84
# Test. Epoch 98. Iter 54/68, IoU = 0.84
# Test. Epoch 98. Iter 55/68, IoU = 0.84
# Test. Epoch 98. Iter 56/68, IoU = 0.84
# Test. Epoch 98. Iter 57/68, IoU = 0.84
# Test. Epoch 98. Iter 58/68, IoU = 0.84
# Test. Epoch 98. Iter 59/68, IoU = 0.84
# Test. Epoch 98. Iter 60/68, IoU = 0.84
# Test. Epoch 98. Iter 61/68, IoU = 0.84
# Test. Epoch 98. Iter 62/68, IoU = 0.84
# Test. Epoch 98. Iter 63/68, IoU = 0.84
# Test. Epoch 98. Iter 64/68, IoU = 0.84
# Test. Epoch 98. Iter 65/68, IoU = 0.84
# Test. Epoch 98. Iter 66/68, IoU = 0.84
# Test. Epoch 98. Iter 67/68, IoU = 0.84
# Test. Epoch 98. Iter 68/68, IoU = 0.83
# Train. Epoch 99. Iter 1/100, IoU = 0.61
# Train. Epoch 99. Iter 2/100, IoU = 0.60
# Train. Epoch 99. Iter 3/100, IoU = 0.65
# Train. Epoch 99. Iter 4/100, IoU = 0.58
# Train. Epoch 99. Iter 5/100, IoU = 0.60
# Train. Epoch 99. Iter 6/100, IoU = 0.62
# Train. Epoch 99. Iter 7/100, IoU = 0.64
# Train. Epoch 99. Iter 8/100, IoU = 0.63
# Train. Epoch 99. Iter 9/100, IoU = 0.62
# Train. Epoch 99. Iter 10/100, IoU = 0.64
# Train. Epoch 99. Iter 11/100, IoU = 0.63
# Train. Epoch 99. Iter 12/100, IoU = 0.61
# Train. Epoch 99. Iter 13/100, IoU = 0.62
# Train. Epoch 99. Iter 14/100, IoU = 0.62
# Train. Epoch 99. Iter 15/100, IoU = 0.62
# Train. Epoch 99. Iter 16/100, IoU = 0.63
# Train. Epoch 99. Iter 17/100, IoU = 0.65
# Train. Epoch 99. Iter 18/100, IoU = 0.64
# Train. Epoch 99. Iter 19/100, IoU = 0.65
# Train. Epoch 99. Iter 20/100, IoU = 0.64
# Train. Epoch 99. Iter 21/100, IoU = 0.64
# Train. Epoch 99. Iter 22/100, IoU = 0.63
# Train. Epoch 99. Iter 23/100, IoU = 0.64
# Train. Epoch 99. Iter 24/100, IoU = 0.64
# Train. Epoch 99. Iter 25/100, IoU = 0.64
# Train. Epoch 99. Iter 26/100, IoU = 0.64
# Train. Epoch 99. Iter 27/100, IoU = 0.65
# Train. Epoch 99. Iter 28/100, IoU = 0.65
# Train. Epoch 99. Iter 29/100, IoU = 0.65
# Train. Epoch 99. Iter 30/100, IoU = 0.66
# Train. Epoch 99. Iter 31/100, IoU = 0.65
# Train. Epoch 99. Iter 32/100, IoU = 0.65
# Train. Epoch 99. Iter 33/100, IoU = 0.66
# Train. Epoch 99. Iter 34/100, IoU = 0.66
# Train. Epoch 99. Iter 35/100, IoU = 0.65
# Train. Epoch 99. Iter 36/100, IoU = 0.66
# Train. Epoch 99. Iter 37/100, IoU = 0.66
# Train. Epoch 99. Iter 38/100, IoU = 0.66
# Train. Epoch 99. Iter 39/100, IoU = 0.65
# Train. Epoch 99. Iter 40/100, IoU = 0.65
# Train. Epoch 99. Iter 41/100, IoU = 0.65
# Train. Epoch 99. Iter 42/100, IoU = 0.65
# Train. Epoch 99. Iter 43/100, IoU = 0.66
# Train. Epoch 99. Iter 44/100, IoU = 0.66
# Train. Epoch 99. Iter 45/100, IoU = 0.66
# Train. Epoch 99. Iter 46/100, IoU = 0.66
# Train. Epoch 99. Iter 47/100, IoU = 0.66
# Train. Epoch 99. Iter 48/100, IoU = 0.67
# Train. Epoch 99. Iter 49/100, IoU = 0.66
# Train. Epoch 99. Iter 50/100, IoU = 0.66
# Train. Epoch 99. Iter 51/100, IoU = 0.66
# Train. Epoch 99. Iter 52/100, IoU = 0.66
# Train. Epoch 99. Iter 53/100, IoU = 0.66
# Train. Epoch 99. Iter 54/100, IoU = 0.67
# Train. Epoch 99. Iter 55/100, IoU = 0.67
# Train. Epoch 99. Iter 56/100, IoU = 0.67
# Train. Epoch 99. Iter 57/100, IoU = 0.67
# Train. Epoch 99. Iter 58/100, IoU = 0.67
# Train. Epoch 99. Iter 59/100, IoU = 0.67
# Train. Epoch 99. Iter 60/100, IoU = 0.67
# Train. Epoch 99. Iter 61/100, IoU = 0.67
# Train. Epoch 99. Iter 62/100, IoU = 0.67
# Train. Epoch 99. Iter 63/100, IoU = 0.68
# Train. Epoch 99. Iter 64/100, IoU = 0.68
# Train. Epoch 99. Iter 65/100, IoU = 0.68
# Train. Epoch 99. Iter 66/100, IoU = 0.68
# Train. Epoch 99. Iter 67/100, IoU = 0.68
# Train. Epoch 99. Iter 68/100, IoU = 0.68
# Train. Epoch 99. Iter 69/100, IoU = 0.68
# Train. Epoch 99. Iter 70/100, IoU = 0.68
# Train. Epoch 99. Iter 71/100, IoU = 0.68
# Train. Epoch 99. Iter 72/100, IoU = 0.68
# Train. Epoch 99. Iter 73/100, IoU = 0.68
# Train. Epoch 99. Iter 74/100, IoU = 0.68
# Train. Epoch 99. Iter 75/100, IoU = 0.68
# Train. Epoch 99. Iter 76/100, IoU = 0.67
# Train. Epoch 99. Iter 77/100, IoU = 0.67
# Train. Epoch 99. Iter 78/100, IoU = 0.68
# Train. Epoch 99. Iter 79/100, IoU = 0.68
# Train. Epoch 99. Iter 80/100, IoU = 0.68
# Train. Epoch 99. Iter 81/100, IoU = 0.68
# Train. Epoch 99. Iter 82/100, IoU = 0.68
# Train. Epoch 99. Iter 83/100, IoU = 0.68
# Train. Epoch 99. Iter 84/100, IoU = 0.68
# Train. Epoch 99. Iter 85/100, IoU = 0.68
# Train. Epoch 99. Iter 86/100, IoU = 0.68
# Train. Epoch 99. Iter 87/100, IoU = 0.68
# Train. Epoch 99. Iter 88/100, IoU = 0.68
# Train. Epoch 99. Iter 89/100, IoU = 0.68
# Train. Epoch 99. Iter 90/100, IoU = 0.68
# Train. Epoch 99. Iter 91/100, IoU = 0.68
# Train. Epoch 99. Iter 92/100, IoU = 0.68
# Train. Epoch 99. Iter 93/100, IoU = 0.68
# Train. Epoch 99. Iter 94/100, IoU = 0.68
# Train. Epoch 99. Iter 95/100, IoU = 0.68
# Train. Epoch 99. Iter 96/100, IoU = 0.69
# Train. Epoch 99. Iter 97/100, IoU = 0.69
# Train. Epoch 99. Iter 98/100, IoU = 0.69
# Train. Epoch 99. Iter 99/100, IoU = 0.69
# Train. Epoch 99. Iter 100/100, IoU = 0.69
# Test. Epoch 99. Iter 1/68, IoU = 0.51
# Test. Epoch 99. Iter 2/68, IoU = 0.69
# Test. Epoch 99. Iter 3/68, IoU = 0.76
# Test. Epoch 99. Iter 4/68, IoU = 0.76
# Test. Epoch 99. Iter 5/68, IoU = 0.77
# Test. Epoch 99. Iter 6/68, IoU = 0.74
# Test. Epoch 99. Iter 7/68, IoU = 0.75
# Test. Epoch 99. Iter 8/68, IoU = 0.77
# Test. Epoch 99. Iter 9/68, IoU = 0.77
# Test. Epoch 99. Iter 10/68, IoU = 0.78
# Test. Epoch 99. Iter 11/68, IoU = 0.77
# Test. Epoch 99. Iter 12/68, IoU = 0.78
# Test. Epoch 99. Iter 13/68, IoU = 0.79
# Test. Epoch 99. Iter 14/68, IoU = 0.80
# Test. Epoch 99. Iter 15/68, IoU = 0.80
# Test. Epoch 99. Iter 16/68, IoU = 0.81
# Test. Epoch 99. Iter 17/68, IoU = 0.81
# Test. Epoch 99. Iter 18/68, IoU = 0.81
# Test. Epoch 99. Iter 19/68, IoU = 0.79
# Test. Epoch 99. Iter 20/68, IoU = 0.79
# Test. Epoch 99. Iter 21/68, IoU = 0.80
# Test. Epoch 99. Iter 22/68, IoU = 0.80
# Test. Epoch 99. Iter 23/68, IoU = 0.80
# Test. Epoch 99. Iter 24/68, IoU = 0.81
# Test. Epoch 99. Iter 25/68, IoU = 0.81
# Test. Epoch 99. Iter 26/68, IoU = 0.81
# Test. Epoch 99. Iter 27/68, IoU = 0.82
# Test. Epoch 99. Iter 28/68, IoU = 0.82
# Test. Epoch 99. Iter 29/68, IoU = 0.82
# Test. Epoch 99. Iter 30/68, IoU = 0.83
# Test. Epoch 99. Iter 31/68, IoU = 0.83
# Test. Epoch 99. Iter 32/68, IoU = 0.83
# Test. Epoch 99. Iter 33/68, IoU = 0.83
# Test. Epoch 99. Iter 34/68, IoU = 0.83
# Test. Epoch 99. Iter 35/68, IoU = 0.83
# Test. Epoch 99. Iter 36/68, IoU = 0.83
# Test. Epoch 99. Iter 37/68, IoU = 0.83
# Test. Epoch 99. Iter 38/68, IoU = 0.83
# Test. Epoch 99. Iter 39/68, IoU = 0.84
# Test. Epoch 99. Iter 40/68, IoU = 0.84
# Test. Epoch 99. Iter 41/68, IoU = 0.84
# Test. Epoch 99. Iter 42/68, IoU = 0.84
# Test. Epoch 99. Iter 43/68, IoU = 0.84
# Test. Epoch 99. Iter 44/68, IoU = 0.84
# Test. Epoch 99. Iter 45/68, IoU = 0.84
# Test. Epoch 99. Iter 46/68, IoU = 0.84
# Test. Epoch 99. Iter 47/68, IoU = 0.84
# Test. Epoch 99. Iter 48/68, IoU = 0.84
# Test. Epoch 99. Iter 49/68, IoU = 0.84
# Test. Epoch 99. Iter 50/68, IoU = 0.85
# Test. Epoch 99. Iter 51/68, IoU = 0.84
# Test. Epoch 99. Iter 52/68, IoU = 0.84
# Test. Epoch 99. Iter 53/68, IoU = 0.84
# Test. Epoch 99. Iter 54/68, IoU = 0.84
# Test. Epoch 99. Iter 55/68, IoU = 0.84
# Test. Epoch 99. Iter 56/68, IoU = 0.84
# Test. Epoch 99. Iter 57/68, IoU = 0.84
# Test. Epoch 99. Iter 58/68, IoU = 0.84
# Test. Epoch 99. Iter 59/68, IoU = 0.84
# Test. Epoch 99. Iter 60/68, IoU = 0.84
# Test. Epoch 99. Iter 61/68, IoU = 0.84
# Test. Epoch 99. Iter 62/68, IoU = 0.84
# Test. Epoch 99. Iter 63/68, IoU = 0.84
# Test. Epoch 99. Iter 64/68, IoU = 0.84
# Test. Epoch 99. Iter 65/68, IoU = 0.84
# Test. Epoch 99. Iter 66/68, IoU = 0.84
# Test. Epoch 99. Iter 67/68, IoU = 0.84
# Test. Epoch 99. Iter 68/68, IoU = 0.84

# %%
import h5py

# %%
with h5py.File('./models/vaihingen/model.hdf5', 'w') as f:
    for var in tf.trainable_variables():
        key = var.name.replace('/', ' ')
        value = sess2.run(var)
        f.create_dataset(key, data=value)
# Out:
# ---------------------------------------------------------------------------
# FailedPreconditionError                   Traceback (most recent call last)
# /opt/conda/envs/tensorflow_1_4/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#
# /opt/conda/envs/tensorflow_1_4/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#
# /opt/conda/envs/tensorflow_1_4/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#
# FailedPreconditionError: Attempting to use uninitialized value Variable
# 	 [[Node: _retval_Variable_0_0 = _Retval[T=DT_FLOAT, index=0, _device="/job:localhost/replica:0/task:0/device:CPU:0"](Variable)]]
#
# During handling of the above exception, another exception occurred:
#
# FailedPreconditionError                   Traceback (most recent call last)
# <ipython-input-12-294097fee224> in <module>
#       2     for var in tf.trainable_variables():
#       3         key = var.name.replace('/', ' ')
# ----> 4         value = sess2.run(var)
#       5         f.create_dataset(key, data=value)
#
# /opt/conda/envs/tensorflow_1_4/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#
# /opt/conda/envs/tensorflow_1_4/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#
# /opt/conda/envs/tensorflow_1_4/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#
# /opt/conda/envs/tensorflow_1_4/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#
# FailedPreconditionError: Attempting to use uninitialized value Variable
# 	 [[Node: _retval_Variable_0_0 = _Retval[T=DT_FLOAT, index=0, _device="/job:localhost/replica:0/task:0/device:CPU:0"](Variable)]]

# %%
tf.trainable_variables()
# Out:
# [<tf.Variable 'Variable:0' shape=(7, 7, 3, 32) dtype=float32_ref>,
#  <tf.Variable 'Variable_1:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'Variable_2:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'Variable_3:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'Variable_4:0' shape=(5, 5, 32, 64) dtype=float32_ref>,
#  <tf.Variable 'Variable_5:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'Variable_6:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'Variable_7:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'Variable_8:0' shape=(3, 3, 64, 128) dtype=float32_ref>,
#  <tf.Variable 'Variable_9:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'Variable_10:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'Variable_11:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'Variable_12:0' shape=(3, 3, 128, 128) dtype=float32_ref>,
#  <tf.Variable 'Variable_13:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'Variable_14:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'Variable_15:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'Variable_16:0' shape=(3, 3, 128, 256) dtype=float32_ref>,
#  <tf.Variable 'Variable_17:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'Variable_18:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'Variable_19:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'Variable_20:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'Variable_21:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'Variable_22:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'Variable_23:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'Variable_24:0' shape=(1, 1, 768, 256) dtype=float32_ref>,
#  <tf.Variable 'Variable_25:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'Variable_26:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'Variable_27:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'Variable_28:0' shape=(1, 1, 256, 64) dtype=float32_ref>,
#  <tf.Variable 'Variable_29:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'Variable_30:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'Variable_31:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'Variable_32:0' shape=(1, 1, 64, 1) dtype=float32_ref>,
#  <tf.Variable 'Variable_33:0' shape=(1,) dtype=float32_ref>,
#  <tf.Variable 'Variable_34:0' shape=(1, 1, 64, 1) dtype=float32_ref>,
#  <tf.Variable 'Variable_35:0' shape=(1,) dtype=float32_ref>,
#  <tf.Variable 'Variable_36:0' shape=(1, 1, 64, 1) dtype=float32_ref>,
#  <tf.Variable 'Variable_37:0' shape=(1,) dtype=float32_ref>,
#  <tf.Variable 'Variable_38:0' shape=(1, 1, 64, 1) dtype=float32_ref>,
#  <tf.Variable 'Variable_39:0' shape=(1,) dtype=float32_ref>]
