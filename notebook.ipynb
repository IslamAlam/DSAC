# %% [markdown]
# <a href="https://colab.research.google.com/github/IslamAlam/DSAC/blob/master/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install Required Library

# %%
! pip install googledrivedownloader
! pip install Pillow
! pip install scipy==1.2.2 # Needed for imread issue 
# https://github.com/lengstrom/fast-style-transfer/issues/106

! sudo apt-get install git-lfs
! git lfs install
! sudo apt-get install nano
# Out:
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.6/dist-packages (0.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (4.3.0)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from Pillow) (0.46)
# Requirement already satisfied: scipy==1.2.2 in /usr/local/lib/python3.6/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.6/dist-packages (from scipy==1.2.2) (1.16.5)

# %% [markdown]
# # Github SSH Key

# %%
# !ssh-keygen -t rsa -b 2048 -C "access@github"
# Out:
# Generating public/private rsa key pair.
# Enter file in which to save the key (/root/.ssh/id_rsa):
# Enter passphrase (empty for no passphrase): Qazwsx123
# Enter same passphrase again: Qazwsx123
# Your identification has been saved in /root/.ssh/id_rsa.
# Your public key has been saved in /root/.ssh/id_rsa.pub.
# The key fingerprint is:
# SHA256:dpXUIO4xBmvD04ptG/EFNW3ifQ6mUZvqkbt48YfHWlA access@github
# The key's randomart image is:
# +---[RSA 2048]----+
# |        . o.=+   |
# |       . = +.o=  |
# |        B *.+= oE|
# |       + O =o *..|
# |      . S +  *.+ |
# |       o +  *  ..|
# |        .  . = o.|
# |           .+ o.+|
# |          .....+ |
# +----[SHA256]-----+

# %%
! rm -rf /root/.ssh/*

import os
if not os.path.exists('/root/.ssh/'):
    os.makedirs('/root/.ssh/')

ssh_key = \
'''
-----BEGIN RSA PRIVATE KEY-----

zOjjTaMcETSBvj3OFw9rJFD4GiitgOp2YfWjzr4EwrUcOp6R0wes
-----END RSA PRIVATE KEY-----
'''

with open(r"/root/.ssh/github_rsa", "w",  encoding='utf8') as f:   # Opens file and casts as f 
  f.write(ssh_key)                  # Writing
  f.close()                         # Close file
   

ssh_config = 'Host github.com\n   HostName github.com\n   IdentityFile /root/.ssh/github_rsa'

with open(r"/root/.ssh/config", "w",  encoding='utf8') as f:   # Opens file and casts as f 
  f.write(ssh_config)                  # Writing
  f.close()                              # Close file


! chmod 700 /root/.ssh
! chmod 700 /root/.ssh/github_rsa
! ls /root/.ssh
! ssh-keygen -y -f /root/.ssh/github_rsa > /root/.ssh/github_rsa.pub
! ssh-keyscan github.com >> /root/.ssh/known_hosts
! chmod 644 /root/.ssh/known_hosts
! git config --global user.email "is3mansour@gmail.com"
! git config --global user.name "Islam Mansour"
! git config --global core.editor nano
! ssh git@github.com
# Out:
# config	github_rsa
# # github.com:22 SSH-2.0-babeld-6c2374e6
# # github.com:22 SSH-2.0-babeld-6c2374e6
# # github.com:22 SSH-2.0-babeld-6c2374e6
# Warning: Permanently added the RSA host key for IP address '140.82.118.3' to the list of known hosts.
# PTY allocation request failed on channel 0
# Hi IslamAlam/DSAC! You've successfully authenticated, but GitHub does not provide shell access.
# Connection to github.com closed.

# %% [markdown]
# ## Clone Repo

# %%
! git clone git@github.com:IslamAlam/DSAC.git
# Out:
# fatal: destination path 'DSAC' already exists and is not an empty directory.

# %%
# !cd DSAC

import os
os.chdir('DSAC')

# %%
# !pwd
# Out:
# /content/DSAC

# %%
if not os.path.exists('./dataset'):
    os.makedirs('./dataset')
! ls
# Out:
# active_contours_fast.py  DSAC	       main_vaihingen.py  README.md
# dataset			 main_bing.py  __pycache__	  snake_utils.py

# %% [markdown]
# ## Download datasets from Google drive

# %%
from google_drive_downloader import GoogleDriveDownloader as gdd
file_id = '1nenpWH4BdplSiHdfXs0oYfiA5qL42plB'
destination = './dataset/buildings_vaihingen.zip'
gdd.download_file_from_google_drive(file_id=file_id,
                                dest_path=destination,
                                unzip=True)
    
  
file_id='1Ta21c3jucWFoe5jwiVXXiAgozvdmnQKP'
destination = './dataset/buildings_bing.zip'
gdd.download_file_from_google_drive(file_id=file_id,
                                    dest_path=destination,
                                    unzip=True)
# Out:
# Downloading 1Ta21c3jucWFoe5jwiVXXiAgozvdmnQKP into ./dataset/buildings_bing.zip... Done.
# Unzipping...Done.

# %%
# !ls ./dataset

# %% [markdown]
# Pull Github if needed to have the latest

# %%
! git pull
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 2), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.
# From github.com:IslamAlam/DSAC
#    93cac6c..d198aeb  master     -> origin/master
# Updating 93cac6c..d198aeb
# Fast-forward
#  main_bing.py | 2 ++
#  1 file changed, 2 insertions(+)

# %% [markdown]
# # Vaihingen buildings Dataset Training

# %%
# %run main_vaihingen.py -i "./dataset/buildings/"
# Out:
# Namespace(inputdatapath='./dataset/buildings/', outputfilename=None, verbose=True)
# ./dataset/buildings/
# /content/DSAC/main_vaihingen.py:101: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   this_im  = scipy.misc.imread(data_path+'building_'+str(i+1).zfill(3)+'.tif')
# /content/DSAC/main_vaihingen.py:103: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img_mask = scipy.misc.imread(data_path+'building_mask_' + str(i+1).zfill(3) + '.tif')/255
# /content/DSAC/main_vaihingen.py:104: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
# Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.
#   masks[:,:,0,i] = scipy.misc.imresize(img_mask,[out_size,out_size])/255
# /usr/local/lib/python3.6/dist-packages/scipy/interpolate/_fitpack_impl.py:299: RuntimeWarning: The maximal number of iterations (20) allowed for finding smoothing
# spline with fp=s has been reached. Probable cause: s too small.
# (abs(fp-s)/s>0.001)
#   warnings.warn(RuntimeWarning(_iermess[ier][0]))
# WARNING:tensorflow:From /content/DSAC/snake_utils.py:382: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/DSAC/snake_utils.py:268: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /content/DSAC/snake_utils.py:271: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# WARNING:tensorflow:From /content/DSAC/snake_utils.py:293: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /content/DSAC/snake_utils.py:405: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# WARNING:tensorflow:From /content/DSAC/snake_utils.py:451: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /content/DSAC/snake_utils.py:453: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From /content/DSAC/main_vaihingen.py:124: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From /content/DSAC/main_vaihingen.py:127: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# Train. Epoch 0. Iter 1/100, IoU = 0.33
# Train. Epoch 0. Iter 2/100, IoU = 0.27
# Train. Epoch 0. Iter 3/100, IoU = 0.27
# Train. Epoch 0. Iter 4/100, IoU = 0.27
# Train. Epoch 0. Iter 5/100, IoU = 0.27
# Train. Epoch 0. Iter 6/100, IoU = 0.28
# Train. Epoch 0. Iter 7/100, IoU = 0.30
# Train. Epoch 0. Iter 8/100, IoU = 0.30
# Train. Epoch 0. Iter 9/100, IoU = 0.29
# Train. Epoch 0. Iter 10/100, IoU = 0.28
# Train. Epoch 0. Iter 11/100, IoU = 0.28
# Train. Epoch 0. Iter 12/100, IoU = 0.28
# Train. Epoch 0. Iter 13/100, IoU = 0.27
# Train. Epoch 0. Iter 14/100, IoU = 0.27
# Train. Epoch 0. Iter 15/100, IoU = 0.26
# Train. Epoch 0. Iter 16/100, IoU = 0.28
# Train. Epoch 0. Iter 17/100, IoU = 0.27
# Train. Epoch 0. Iter 18/100, IoU = 0.28
# Train. Epoch 0. Iter 19/100, IoU = 0.28
# Train. Epoch 0. Iter 20/100, IoU = 0.29
# Train. Epoch 0. Iter 21/100, IoU = 0.28
# Train. Epoch 0. Iter 22/100, IoU = 0.28
# Train. Epoch 0. Iter 23/100, IoU = 0.27
# Train. Epoch 0. Iter 24/100, IoU = 0.28
# Train. Epoch 0. Iter 25/100, IoU = 0.27
# Train. Epoch 0. Iter 26/100, IoU = 0.28
# Train. Epoch 0. Iter 27/100, IoU = 0.28
# Train. Epoch 0. Iter 28/100, IoU = 0.27
# Train. Epoch 0. Iter 29/100, IoU = 0.27
# Train. Epoch 0. Iter 30/100, IoU = 0.27
# Train. Epoch 0. Iter 31/100, IoU = 0.27
# Train. Epoch 0. Iter 32/100, IoU = 0.27
# Train. Epoch 0. Iter 33/100, IoU = 0.27
# Train. Epoch 0. Iter 34/100, IoU = 0.27
# Train. Epoch 0. Iter 35/100, IoU = 0.27
# Train. Epoch 0. Iter 36/100, IoU = 0.27
# Train. Epoch 0. Iter 37/100, IoU = 0.27
# Train. Epoch 0. Iter 38/100, IoU = 0.27
# Train. Epoch 0. Iter 39/100, IoU = 0.27
# Train. Epoch 0. Iter 40/100, IoU = 0.27
# Train. Epoch 0. Iter 41/100, IoU = 0.27
# Train. Epoch 0. Iter 42/100, IoU = 0.27
# Train. Epoch 0. Iter 43/100, IoU = 0.27
# Train. Epoch 0. Iter 44/100, IoU = 0.27
# Train. Epoch 0. Iter 45/100, IoU = 0.27
# Train. Epoch 0. Iter 46/100, IoU = 0.27
# Train. Epoch 0. Iter 47/100, IoU = 0.27
# Train. Epoch 0. Iter 48/100, IoU = 0.27
# Train. Epoch 0. Iter 49/100, IoU = 0.27
# Train. Epoch 0. Iter 50/100, IoU = 0.27
# Train. Epoch 0. Iter 51/100, IoU = 0.27
# Train. Epoch 0. Iter 52/100, IoU = 0.27
# Train. Epoch 0. Iter 53/100, IoU = 0.27
# Train. Epoch 0. Iter 54/100, IoU = 0.27
# Train. Epoch 0. Iter 55/100, IoU = 0.27
# Train. Epoch 0. Iter 56/100, IoU = 0.27
# Train. Epoch 0. Iter 57/100, IoU = 0.27
# Train. Epoch 0. Iter 58/100, IoU = 0.27
# Train. Epoch 0. Iter 59/100, IoU = 0.27
# Train. Epoch 0. Iter 60/100, IoU = 0.27
# Train. Epoch 0. Iter 61/100, IoU = 0.27
# Train. Epoch 0. Iter 62/100, IoU = 0.26
# Train. Epoch 0. Iter 63/100, IoU = 0.26
# Train. Epoch 0. Iter 64/100, IoU = 0.26
# Train. Epoch 0. Iter 65/100, IoU = 0.26
# Train. Epoch 0. Iter 66/100, IoU = 0.26
# Train. Epoch 0. Iter 67/100, IoU = 0.26
# Train. Epoch 0. Iter 68/100, IoU = 0.26
# Train. Epoch 0. Iter 69/100, IoU = 0.26
# Train. Epoch 0. Iter 70/100, IoU = 0.26
# Train. Epoch 0. Iter 71/100, IoU = 0.26
# Train. Epoch 0. Iter 72/100, IoU = 0.26
# Train. Epoch 0. Iter 73/100, IoU = 0.26
# Train. Epoch 0. Iter 74/100, IoU = 0.26
# Train. Epoch 0. Iter 75/100, IoU = 0.26
# Train. Epoch 0. Iter 76/100, IoU = 0.26
# Train. Epoch 0. Iter 77/100, IoU = 0.26
# Train. Epoch 0. Iter 78/100, IoU = 0.26
# Train. Epoch 0. Iter 79/100, IoU = 0.26
# Train. Epoch 0. Iter 80/100, IoU = 0.26
# Train. Epoch 0. Iter 81/100, IoU = 0.26
# Train. Epoch 0. Iter 82/100, IoU = 0.25
# Train. Epoch 0. Iter 83/100, IoU = 0.25
# Train. Epoch 0. Iter 84/100, IoU = 0.26
# Train. Epoch 0. Iter 85/100, IoU = 0.26
# Train. Epoch 0. Iter 86/100, IoU = 0.26
# Train. Epoch 0. Iter 87/100, IoU = 0.25
# Train. Epoch 0. Iter 88/100, IoU = 0.25
# Train. Epoch 0. Iter 89/100, IoU = 0.25
# Train. Epoch 0. Iter 90/100, IoU = 0.25
# Train. Epoch 0. Iter 91/100, IoU = 0.26
# Train. Epoch 0. Iter 92/100, IoU = 0.25
# Train. Epoch 0. Iter 93/100, IoU = 0.25
# Train. Epoch 0. Iter 94/100, IoU = 0.25
# Train. Epoch 0. Iter 95/100, IoU = 0.25
# Train. Epoch 0. Iter 96/100, IoU = 0.25
# Train. Epoch 0. Iter 97/100, IoU = 0.25
# Train. Epoch 0. Iter 98/100, IoU = 0.25
# Train. Epoch 0. Iter 99/100, IoU = 0.25
# Train. Epoch 0. Iter 100/100, IoU = 0.25
# Test. Epoch 0. Iter 1/68, IoU = 0.43
# Test. Epoch 0. Iter 2/68, IoU = 0.38
# Test. Epoch 0. Iter 3/68, IoU = 0.37
# Test. Epoch 0. Iter 4/68, IoU = 0.37
# Test. Epoch 0. Iter 5/68, IoU = 0.40
# Test. Epoch 0. Iter 6/68, IoU = 0.41
# Test. Epoch 0. Iter 7/68, IoU = 0.39
# Test. Epoch 0. Iter 8/68, IoU = 0.40
# Test. Epoch 0. Iter 9/68, IoU = 0.40
# Test. Epoch 0. Iter 10/68, IoU = 0.39
# Test. Epoch 0. Iter 11/68, IoU = 0.41
# Test. Epoch 0. Iter 12/68, IoU = 0.40
# Test. Epoch 0. Iter 13/68, IoU = 0.39
# Test. Epoch 0. Iter 14/68, IoU = 0.41
# Test. Epoch 0. Iter 15/68, IoU = 0.42
# Test. Epoch 0. Iter 16/68, IoU = 0.43
# Test. Epoch 0. Iter 17/68, IoU = 0.44
# Test. Epoch 0. Iter 18/68, IoU = 0.45
# Test. Epoch 0. Iter 19/68, IoU = 0.45
# Test. Epoch 0. Iter 20/68, IoU = 0.46
# Test. Epoch 0. Iter 21/68, IoU = 0.46
# Test. Epoch 0. Iter 22/68, IoU = 0.46
# Test. Epoch 0. Iter 23/68, IoU = 0.47
# Test. Epoch 0. Iter 24/68, IoU = 0.46
# Test. Epoch 0. Iter 25/68, IoU = 0.47
# Test. Epoch 0. Iter 26/68, IoU = 0.46
# Test. Epoch 0. Iter 27/68, IoU = 0.47
# Test. Epoch 0. Iter 28/68, IoU = 0.47
# Test. Epoch 0. Iter 29/68, IoU = 0.47
# Test. Epoch 0. Iter 30/68, IoU = 0.48
# Test. Epoch 0. Iter 31/68, IoU = 0.48
# Test. Epoch 0. Iter 32/68, IoU = 0.48
# Test. Epoch 0. Iter 33/68, IoU = 0.48
# Test. Epoch 0. Iter 34/68, IoU = 0.48
# Test. Epoch 0. Iter 35/68, IoU = 0.48
# Test. Epoch 0. Iter 36/68, IoU = 0.48
# Test. Epoch 0. Iter 37/68, IoU = 0.48
# Test. Epoch 0. Iter 38/68, IoU = 0.48
# Test. Epoch 0. Iter 39/68, IoU = 0.48
# Test. Epoch 0. Iter 40/68, IoU = 0.48
# Test. Epoch 0. Iter 41/68, IoU = 0.48
# Test. Epoch 0. Iter 42/68, IoU = 0.49
# Test. Epoch 0. Iter 43/68, IoU = 0.49
# Test. Epoch 0. Iter 44/68, IoU = 0.49
# Test. Epoch 0. Iter 45/68, IoU = 0.49
# Test. Epoch 0. Iter 46/68, IoU = 0.49
# Test. Epoch 0. Iter 47/68, IoU = 0.49
# Test. Epoch 0. Iter 48/68, IoU = 0.49
# Test. Epoch 0. Iter 49/68, IoU = 0.48
# Test. Epoch 0. Iter 50/68, IoU = 0.48
# Test. Epoch 0. Iter 51/68, IoU = 0.48
# Test. Epoch 0. Iter 52/68, IoU = 0.48
# Test. Epoch 0. Iter 53/68, IoU = 0.48
# Test. Epoch 0. Iter 54/68, IoU = 0.47
# Test. Epoch 0. Iter 55/68, IoU = 0.47
# Test. Epoch 0. Iter 56/68, IoU = 0.47
# Test. Epoch 0. Iter 57/68, IoU = 0.47
# Test. Epoch 0. Iter 58/68, IoU = 0.47
# Test. Epoch 0. Iter 59/68, IoU = 0.46
# Test. Epoch 0. Iter 60/68, IoU = 0.46
# Test. Epoch 0. Iter 61/68, IoU = 0.47
# Test. Epoch 0. Iter 62/68, IoU = 0.46
# Test. Epoch 0. Iter 63/68, IoU = 0.46
# Test. Epoch 0. Iter 64/68, IoU = 0.46
# Test. Epoch 0. Iter 65/68, IoU = 0.46
# Test. Epoch 0. Iter 66/68, IoU = 0.46
# Test. Epoch 0. Iter 67/68, IoU = 0.45
# Test. Epoch 0. Iter 68/68, IoU = 0.45
# Train. Epoch 1. Iter 1/100, IoU = 0.52
# Train. Epoch 1. Iter 2/100, IoU = 0.58
# Train. Epoch 1. Iter 3/100, IoU = 0.47
# Train. Epoch 1. Iter 4/100, IoU = 0.45
# Train. Epoch 1. Iter 5/100, IoU = 0.38
# Train. Epoch 1. Iter 6/100, IoU = 0.34
# Train. Epoch 1. Iter 7/100, IoU = 0.32
# Train. Epoch 1. Iter 8/100, IoU = 0.31
# Train. Epoch 1. Iter 9/100, IoU = 0.32
# Train. Epoch 1. Iter 10/100, IoU = 0.33
# Train. Epoch 1. Iter 11/100, IoU = 0.32
# Train. Epoch 1. Iter 12/100, IoU = 0.30
# Train. Epoch 1. Iter 13/100, IoU = 0.29
# Train. Epoch 1. Iter 14/100, IoU = 0.28
# Train. Epoch 1. Iter 15/100, IoU = 0.30
# Train. Epoch 1. Iter 16/100, IoU = 0.30
# Train. Epoch 1. Iter 17/100, IoU = 0.29
# Train. Epoch 1. Iter 18/100, IoU = 0.29
# Train. Epoch 1. Iter 19/100, IoU = 0.29
# Train. Epoch 1. Iter 20/100, IoU = 0.29
# Train. Epoch 1. Iter 21/100, IoU = 0.28
# Train. Epoch 1. Iter 22/100, IoU = 0.28
# Train. Epoch 1. Iter 23/100, IoU = 0.28
# Train. Epoch 1. Iter 24/100, IoU = 0.28
# Train. Epoch 1. Iter 25/100, IoU = 0.28
# Train. Epoch 1. Iter 26/100, IoU = 0.28
# Train. Epoch 1. Iter 27/100, IoU = 0.27
# Train. Epoch 1. Iter 28/100, IoU = 0.27
# Train. Epoch 1. Iter 29/100, IoU = 0.27
# Train. Epoch 1. Iter 30/100, IoU = 0.27
# Train. Epoch 1. Iter 31/100, IoU = 0.26
# Train. Epoch 1. Iter 32/100, IoU = 0.26
# Train. Epoch 1. Iter 33/100, IoU = 0.26
# Train. Epoch 1. Iter 34/100, IoU = 0.26
# Train. Epoch 1. Iter 35/100, IoU = 0.26
# Train. Epoch 1. Iter 36/100, IoU = 0.26
# Train. Epoch 1. Iter 37/100, IoU = 0.26
# Train. Epoch 1. Iter 38/100, IoU = 0.26
# Train. Epoch 1. Iter 39/100, IoU = 0.26
# Train. Epoch 1. Iter 40/100, IoU = 0.26
# Train. Epoch 1. Iter 41/100, IoU = 0.26
# Train. Epoch 1. Iter 42/100, IoU = 0.26
# Train. Epoch 1. Iter 43/100, IoU = 0.25
# Train. Epoch 1. Iter 44/100, IoU = 0.25
# Train. Epoch 1. Iter 45/100, IoU = 0.25
# Train. Epoch 1. Iter 46/100, IoU = 0.25
# Train. Epoch 1. Iter 47/100, IoU = 0.25
# Train. Epoch 1. Iter 48/100, IoU = 0.26
# Train. Epoch 1. Iter 49/100, IoU = 0.26
# Train. Epoch 1. Iter 50/100, IoU = 0.26
# Train. Epoch 1. Iter 51/100, IoU = 0.26
# Train. Epoch 1. Iter 52/100, IoU = 0.26
# Train. Epoch 1. Iter 53/100, IoU = 0.26
# Train. Epoch 1. Iter 54/100, IoU = 0.26
# Train. Epoch 1. Iter 55/100, IoU = 0.26
# Train. Epoch 1. Iter 56/100, IoU = 0.26
# Train. Epoch 1. Iter 57/100, IoU = 0.26
# Train. Epoch 1. Iter 58/100, IoU = 0.26
# Train. Epoch 1. Iter 59/100, IoU = 0.26
# Train. Epoch 1. Iter 60/100, IoU = 0.26
# Train. Epoch 1. Iter 61/100, IoU = 0.26
# Train. Epoch 1. Iter 62/100, IoU = 0.26
# Train. Epoch 1. Iter 63/100, IoU = 0.26
# Train. Epoch 1. Iter 64/100, IoU = 0.26
# Train. Epoch 1. Iter 65/100, IoU = 0.26
# Train. Epoch 1. Iter 66/100, IoU = 0.26
# Train. Epoch 1. Iter 67/100, IoU = 0.26
# Train. Epoch 1. Iter 68/100, IoU = 0.27
# Train. Epoch 1. Iter 69/100, IoU = 0.26
# Train. Epoch 1. Iter 70/100, IoU = 0.26
# Train. Epoch 1. Iter 71/100, IoU = 0.26
# Train. Epoch 1. Iter 72/100, IoU = 0.26
# Train. Epoch 1. Iter 73/100, IoU = 0.26
# Train. Epoch 1. Iter 74/100, IoU = 0.26
# Train. Epoch 1. Iter 75/100, IoU = 0.26
# Train. Epoch 1. Iter 76/100, IoU = 0.26
# Train. Epoch 1. Iter 77/100, IoU = 0.26
# Train. Epoch 1. Iter 78/100, IoU = 0.26
# Train. Epoch 1. Iter 79/100, IoU = 0.26
# Train. Epoch 1. Iter 80/100, IoU = 0.26
# Train. Epoch 1. Iter 81/100, IoU = 0.26
# Train. Epoch 1. Iter 82/100, IoU = 0.26
# Train. Epoch 1. Iter 83/100, IoU = 0.26
# Train. Epoch 1. Iter 84/100, IoU = 0.26
# Train. Epoch 1. Iter 85/100, IoU = 0.26
# Train. Epoch 1. Iter 86/100, IoU = 0.26
# Train. Epoch 1. Iter 87/100, IoU = 0.26
# Train. Epoch 1. Iter 88/100, IoU = 0.26
# Train. Epoch 1. Iter 89/100, IoU = 0.26
# Train. Epoch 1. Iter 90/100, IoU = 0.26
# Train. Epoch 1. Iter 91/100, IoU = 0.26
# Train. Epoch 1. Iter 92/100, IoU = 0.26
# Train. Epoch 1. Iter 93/100, IoU = 0.26
# Train. Epoch 1. Iter 94/100, IoU = 0.26
# Train. Epoch 1. Iter 95/100, IoU = 0.25
# Train. Epoch 1. Iter 96/100, IoU = 0.25
# Train. Epoch 1. Iter 97/100, IoU = 0.26
# Train. Epoch 1. Iter 98/100, IoU = 0.26
# Train. Epoch 1. Iter 99/100, IoU = 0.26
# Train. Epoch 1. Iter 100/100, IoU = 0.26
# Test. Epoch 1. Iter 1/68, IoU = 0.41
# Test. Epoch 1. Iter 2/68, IoU = 0.39
# Test. Epoch 1. Iter 3/68, IoU = 0.36
# Test. Epoch 1. Iter 4/68, IoU = 0.38
# Test. Epoch 1. Iter 5/68, IoU = 0.42
# Test. Epoch 1. Iter 6/68, IoU = 0.43
# Test. Epoch 1. Iter 7/68, IoU = 0.44
# Test. Epoch 1. Iter 8/68, IoU = 0.45
# Test. Epoch 1. Iter 9/68, IoU = 0.46
# Test. Epoch 1. Iter 10/68, IoU = 0.45
# Test. Epoch 1. Iter 11/68, IoU = 0.45
# Test. Epoch 1. Iter 12/68, IoU = 0.46
# Test. Epoch 1. Iter 13/68, IoU = 0.46
# Test. Epoch 1. Iter 14/68, IoU = 0.46
# Test. Epoch 1. Iter 15/68, IoU = 0.47
# Test. Epoch 1. Iter 16/68, IoU = 0.49
# Test. Epoch 1. Iter 17/68, IoU = 0.50
# Test. Epoch 1. Iter 18/68, IoU = 0.50
# Test. Epoch 1. Iter 19/68, IoU = 0.50
# Test. Epoch 1. Iter 20/68, IoU = 0.50
# Test. Epoch 1. Iter 21/68, IoU = 0.50
# Test. Epoch 1. Iter 22/68, IoU = 0.51
# Test. Epoch 1. Iter 23/68, IoU = 0.52
# Test. Epoch 1. Iter 24/68, IoU = 0.51
# Test. Epoch 1. Iter 25/68, IoU = 0.51
# Test. Epoch 1. Iter 26/68, IoU = 0.50
# Test. Epoch 1. Iter 27/68, IoU = 0.50
# Test. Epoch 1. Iter 28/68, IoU = 0.51
# Test. Epoch 1. Iter 29/68, IoU = 0.50
# Test. Epoch 1. Iter 30/68, IoU = 0.51
# Test. Epoch 1. Iter 31/68, IoU = 0.51
# Test. Epoch 1. Iter 32/68, IoU = 0.51
# Test. Epoch 1. Iter 33/68, IoU = 0.51
# Test. Epoch 1. Iter 34/68, IoU = 0.51
# Test. Epoch 1. Iter 35/68, IoU = 0.51
# Test. Epoch 1. Iter 36/68, IoU = 0.50
# Test. Epoch 1. Iter 37/68, IoU = 0.49
# Test. Epoch 1. Iter 38/68, IoU = 0.49
# Test. Epoch 1. Iter 39/68, IoU = 0.50
# Test. Epoch 1. Iter 40/68, IoU = 0.50
# Test. Epoch 1. Iter 41/68, IoU = 0.51
# Test. Epoch 1. Iter 42/68, IoU = 0.50
# Test. Epoch 1. Iter 43/68, IoU = 0.51
# Test. Epoch 1. Iter 44/68, IoU = 0.51
# Test. Epoch 1. Iter 45/68, IoU = 0.52
# Test. Epoch 1. Iter 46/68, IoU = 0.52
# Test. Epoch 1. Iter 47/68, IoU = 0.51
# Test. Epoch 1. Iter 48/68, IoU = 0.51
# Test. Epoch 1. Iter 49/68, IoU = 0.51
# Test. Epoch 1. Iter 50/68, IoU = 0.51
# Test. Epoch 1. Iter 51/68, IoU = 0.51
# Test. Epoch 1. Iter 52/68, IoU = 0.51
# Test. Epoch 1. Iter 53/68, IoU = 0.50
# Test. Epoch 1. Iter 54/68, IoU = 0.50
# Test. Epoch 1. Iter 55/68, IoU = 0.50
# Test. Epoch 1. Iter 56/68, IoU = 0.50
# Test. Epoch 1. Iter 57/68, IoU = 0.50
# Test. Epoch 1. Iter 58/68, IoU = 0.50
# Test. Epoch 1. Iter 59/68, IoU = 0.50
# Test. Epoch 1. Iter 60/68, IoU = 0.50
# Test. Epoch 1. Iter 61/68, IoU = 0.51
# Test. Epoch 1. Iter 62/68, IoU = 0.50
# Test. Epoch 1. Iter 63/68, IoU = 0.50
# Test. Epoch 1. Iter 64/68, IoU = 0.51
# Test. Epoch 1. Iter 65/68, IoU = 0.51
# Test. Epoch 1. Iter 66/68, IoU = 0.50
# Test. Epoch 1. Iter 67/68, IoU = 0.50
# Test. Epoch 1. Iter 68/68, IoU = 0.50
# Train. Epoch 2. Iter 1/100, IoU = 0.36
# Train. Epoch 2. Iter 2/100, IoU = 0.45
# Train. Epoch 2. Iter 3/100, IoU = 0.40
# Train. Epoch 2. Iter 4/100, IoU = 0.41
# Train. Epoch 2. Iter 5/100, IoU = 0.36
# Train. Epoch 2. Iter 6/100, IoU = 0.32
# Train. Epoch 2. Iter 7/100, IoU = 0.33
# Train. Epoch 2. Iter 8/100, IoU = 0.32
# Train. Epoch 2. Iter 9/100, IoU = 0.34
# Train. Epoch 2. Iter 10/100, IoU = 0.35
# Train. Epoch 2. Iter 11/100, IoU = 0.33
# Train. Epoch 2. Iter 12/100, IoU = 0.33
# Train. Epoch 2. Iter 13/100, IoU = 0.31
# Train. Epoch 2. Iter 14/100, IoU = 0.33
# Train. Epoch 2. Iter 15/100, IoU = 0.34
# Train. Epoch 2. Iter 16/100, IoU = 0.33
# Train. Epoch 2. Iter 17/100, IoU = 0.33
# Train. Epoch 2. Iter 18/100, IoU = 0.32
# Train. Epoch 2. Iter 19/100, IoU = 0.31
# Train. Epoch 2. Iter 20/100, IoU = 0.32
# Train. Epoch 2. Iter 21/100, IoU = 0.31
# Train. Epoch 2. Iter 22/100, IoU = 0.31
# Train. Epoch 2. Iter 23/100, IoU = 0.31
# Train. Epoch 2. Iter 24/100, IoU = 0.31
# Train. Epoch 2. Iter 25/100, IoU = 0.32
# Train. Epoch 2. Iter 26/100, IoU = 0.31
# Train. Epoch 2. Iter 27/100, IoU = 0.31
# Train. Epoch 2. Iter 28/100, IoU = 0.31
# Train. Epoch 2. Iter 29/100, IoU = 0.31
# Train. Epoch 2. Iter 30/100, IoU = 0.31
# Train. Epoch 2. Iter 31/100, IoU = 0.30
# Train. Epoch 2. Iter 32/100, IoU = 0.30
# Train. Epoch 2. Iter 33/100, IoU = 0.29
# Train. Epoch 2. Iter 34/100, IoU = 0.29
# Train. Epoch 2. Iter 35/100, IoU = 0.29
# Train. Epoch 2. Iter 36/100, IoU = 0.30
# Train. Epoch 2. Iter 37/100, IoU = 0.30
# Train. Epoch 2. Iter 38/100, IoU = 0.30
# Train. Epoch 2. Iter 39/100, IoU = 0.30
# Train. Epoch 2. Iter 40/100, IoU = 0.31
# Train. Epoch 2. Iter 41/100, IoU = 0.31
# Train. Epoch 2. Iter 42/100, IoU = 0.30
# Train. Epoch 2. Iter 43/100, IoU = 0.30
# Train. Epoch 2. Iter 44/100, IoU = 0.30
# Train. Epoch 2. Iter 45/100, IoU = 0.30
# Train. Epoch 2. Iter 46/100, IoU = 0.30
# Train. Epoch 2. Iter 47/100, IoU = 0.31
# Train. Epoch 2. Iter 48/100, IoU = 0.31
# Train. Epoch 2. Iter 49/100, IoU = 0.31
# Train. Epoch 2. Iter 50/100, IoU = 0.32
# Train. Epoch 2. Iter 51/100, IoU = 0.31
# Train. Epoch 2. Iter 52/100, IoU = 0.31
# Train. Epoch 2. Iter 53/100, IoU = 0.31
# Train. Epoch 2. Iter 54/100, IoU = 0.31
# Train. Epoch 2. Iter 55/100, IoU = 0.31
# Train. Epoch 2. Iter 56/100, IoU = 0.31
# Train. Epoch 2. Iter 57/100, IoU = 0.31
# Train. Epoch 2. Iter 58/100, IoU = 0.31
# Train. Epoch 2. Iter 59/100, IoU = 0.31
# Train. Epoch 2. Iter 60/100, IoU = 0.31
# Train. Epoch 2. Iter 61/100, IoU = 0.31
# Train. Epoch 2. Iter 62/100, IoU = 0.30
# Train. Epoch 2. Iter 63/100, IoU = 0.30
# Train. Epoch 2. Iter 64/100, IoU = 0.30
# Train. Epoch 2. Iter 65/100, IoU = 0.30
# Train. Epoch 2. Iter 66/100, IoU = 0.30
# Train. Epoch 2. Iter 67/100, IoU = 0.31
# Train. Epoch 2. Iter 68/100, IoU = 0.31
# Train. Epoch 2. Iter 69/100, IoU = 0.30
# Train. Epoch 2. Iter 70/100, IoU = 0.30
# Train. Epoch 2. Iter 71/100, IoU = 0.30
# Train. Epoch 2. Iter 72/100, IoU = 0.30
# Train. Epoch 2. Iter 73/100, IoU = 0.30
# Train. Epoch 2. Iter 74/100, IoU = 0.30
# Train. Epoch 2. Iter 75/100, IoU = 0.30
# Train. Epoch 2. Iter 76/100, IoU = 0.30
# Train. Epoch 2. Iter 77/100, IoU = 0.30
# Train. Epoch 2. Iter 78/100, IoU = 0.30
# Train. Epoch 2. Iter 79/100, IoU = 0.30
# Train. Epoch 2. Iter 80/100, IoU = 0.30
# Train. Epoch 2. Iter 81/100, IoU = 0.30
# Train. Epoch 2. Iter 82/100, IoU = 0.30
# Train. Epoch 2. Iter 83/100, IoU = 0.29
# Train. Epoch 2. Iter 84/100, IoU = 0.29
# Train. Epoch 2. Iter 85/100, IoU = 0.29
# Train. Epoch 2. Iter 86/100, IoU = 0.29
# Train. Epoch 2. Iter 87/100, IoU = 0.29
# Train. Epoch 2. Iter 88/100, IoU = 0.29
# Train. Epoch 2. Iter 89/100, IoU = 0.29
# Train. Epoch 2. Iter 90/100, IoU = 0.29
# Train. Epoch 2. Iter 91/100, IoU = 0.29
# Train. Epoch 2. Iter 92/100, IoU = 0.29
# Train. Epoch 2. Iter 93/100, IoU = 0.29
# Train. Epoch 2. Iter 94/100, IoU = 0.29
# Train. Epoch 2. Iter 95/100, IoU = 0.29
# Train. Epoch 2. Iter 96/100, IoU = 0.29
# Train. Epoch 2. Iter 97/100, IoU = 0.29
# Train. Epoch 2. Iter 98/100, IoU = 0.29
# Train. Epoch 2. Iter 99/100, IoU = 0.29
# Train. Epoch 2. Iter 100/100, IoU = 0.29
# Test. Epoch 2. Iter 1/68, IoU = 0.50
# Test. Epoch 2. Iter 2/68, IoU = 0.55
# Test. Epoch 2. Iter 3/68, IoU = 0.56
# Test. Epoch 2. Iter 4/68, IoU = 0.54
# Test. Epoch 2. Iter 5/68, IoU = 0.55
# Test. Epoch 2. Iter 6/68, IoU = 0.57
# Test. Epoch 2. Iter 7/68, IoU = 0.56
# Test. Epoch 2. Iter 8/68, IoU = 0.57
# Test. Epoch 2. Iter 9/68, IoU = 0.58
# Test. Epoch 2. Iter 10/68, IoU = 0.58
# Test. Epoch 2. Iter 11/68, IoU = 0.56
# Test. Epoch 2. Iter 12/68, IoU = 0.58
# Test. Epoch 2. Iter 13/68, IoU = 0.57
# Test. Epoch 2. Iter 14/68, IoU = 0.57
# Test. Epoch 2. Iter 15/68, IoU = 0.58
# Test. Epoch 2. Iter 16/68, IoU = 0.60
# Test. Epoch 2. Iter 17/68, IoU = 0.60
# Test. Epoch 2. Iter 18/68, IoU = 0.60
# Test. Epoch 2. Iter 19/68, IoU = 0.59
# Test. Epoch 2. Iter 20/68, IoU = 0.58
# Test. Epoch 2. Iter 21/68, IoU = 0.59
# Test. Epoch 2. Iter 22/68, IoU = 0.59
# Test. Epoch 2. Iter 23/68, IoU = 0.60
# Test. Epoch 2. Iter 24/68, IoU = 0.60
# Test. Epoch 2. Iter 25/68, IoU = 0.60
# Test. Epoch 2. Iter 26/68, IoU = 0.59
# Test. Epoch 2. Iter 27/68, IoU = 0.59
# Test. Epoch 2. Iter 28/68, IoU = 0.60
# Test. Epoch 2. Iter 29/68, IoU = 0.60
# Test. Epoch 2. Iter 30/68, IoU = 0.60
# Test. Epoch 2. Iter 31/68, IoU = 0.60
# Test. Epoch 2. Iter 32/68, IoU = 0.60
# Test. Epoch 2. Iter 33/68, IoU = 0.59
# Test. Epoch 2. Iter 34/68, IoU = 0.60
# Test. Epoch 2. Iter 35/68, IoU = 0.59
# Test. Epoch 2. Iter 36/68, IoU = 0.58
# Test. Epoch 2. Iter 37/68, IoU = 0.58
# Test. Epoch 2. Iter 38/68, IoU = 0.58
# Test. Epoch 2. Iter 39/68, IoU = 0.58
# Test. Epoch 2. Iter 40/68, IoU = 0.59
# Test. Epoch 2. Iter 41/68, IoU = 0.59
# Test. Epoch 2. Iter 42/68, IoU = 0.59
# Test. Epoch 2. Iter 43/68, IoU = 0.59
# Test. Epoch 2. Iter 44/68, IoU = 0.60
# Test. Epoch 2. Iter 45/68, IoU = 0.60
# Test. Epoch 2. Iter 46/68, IoU = 0.60
# Test. Epoch 2. Iter 47/68, IoU = 0.60
# Test. Epoch 2. Iter 48/68, IoU = 0.60
# Test. Epoch 2. Iter 49/68, IoU = 0.60
# Test. Epoch 2. Iter 50/68, IoU = 0.60
# Test. Epoch 2. Iter 51/68, IoU = 0.60
# Test. Epoch 2. Iter 52/68, IoU = 0.60
# Test. Epoch 2. Iter 53/68, IoU = 0.60
# Test. Epoch 2. Iter 54/68, IoU = 0.59
# Test. Epoch 2. Iter 55/68, IoU = 0.60
# Test. Epoch 2. Iter 56/68, IoU = 0.60
# Test. Epoch 2. Iter 57/68, IoU = 0.60
# Test. Epoch 2. Iter 58/68, IoU = 0.60
# Test. Epoch 2. Iter 59/68, IoU = 0.60
# Test. Epoch 2. Iter 60/68, IoU = 0.60
# Test. Epoch 2. Iter 61/68, IoU = 0.60
# Test. Epoch 2. Iter 62/68, IoU = 0.60
# Test. Epoch 2. Iter 63/68, IoU = 0.60
# Test. Epoch 2. Iter 64/68, IoU = 0.60
# Test. Epoch 2. Iter 65/68, IoU = 0.60
# Test. Epoch 2. Iter 66/68, IoU = 0.60
# Test. Epoch 2. Iter 67/68, IoU = 0.60
# Test. Epoch 2. Iter 68/68, IoU = 0.59
# Train. Epoch 3. Iter 1/100, IoU = 0.67
# Train. Epoch 3. Iter 2/100, IoU = 0.61
# Train. Epoch 3. Iter 3/100, IoU = 0.49
# Train. Epoch 3. Iter 4/100, IoU = 0.41
# Train. Epoch 3. Iter 5/100, IoU = 0.37
# Train. Epoch 3. Iter 6/100, IoU = 0.33
# Train. Epoch 3. Iter 7/100, IoU = 0.32
# Train. Epoch 3. Iter 8/100, IoU = 0.30
# Train. Epoch 3. Iter 9/100, IoU = 0.30
# Train. Epoch 3. Iter 10/100, IoU = 0.31
# Train. Epoch 3. Iter 11/100, IoU = 0.30
# Train. Epoch 3. Iter 12/100, IoU = 0.29
# Train. Epoch 3. Iter 13/100, IoU = 0.30
# Train. Epoch 3. Iter 14/100, IoU = 0.31
# Train. Epoch 3. Iter 15/100, IoU = 0.32
# Train. Epoch 3. Iter 16/100, IoU = 0.32
# Train. Epoch 3. Iter 17/100, IoU = 0.33
# Train. Epoch 3. Iter 18/100, IoU = 0.33
# Train. Epoch 3. Iter 19/100, IoU = 0.32
# Train. Epoch 3. Iter 20/100, IoU = 0.34
# Train. Epoch 3. Iter 21/100, IoU = 0.33
# Train. Epoch 3. Iter 22/100, IoU = 0.33
# Train. Epoch 3. Iter 23/100, IoU = 0.34
# Train. Epoch 3. Iter 24/100, IoU = 0.35
# Train. Epoch 3. Iter 25/100, IoU = 0.35
# Train. Epoch 3. Iter 26/100, IoU = 0.35
# Train. Epoch 3. Iter 27/100, IoU = 0.35
# Train. Epoch 3. Iter 28/100, IoU = 0.35
# Train. Epoch 3. Iter 29/100, IoU = 0.35
# Train. Epoch 3. Iter 30/100, IoU = 0.35
# Train. Epoch 3. Iter 31/100, IoU = 0.34
# Train. Epoch 3. Iter 32/100, IoU = 0.34
# Train. Epoch 3. Iter 33/100, IoU = 0.34
# Train. Epoch 3. Iter 34/100, IoU = 0.34
# Train. Epoch 3. Iter 35/100, IoU = 0.34
# Train. Epoch 3. Iter 36/100, IoU = 0.34
# Train. Epoch 3. Iter 37/100, IoU = 0.35
# Train. Epoch 3. Iter 38/100, IoU = 0.34
# Train. Epoch 3. Iter 39/100, IoU = 0.34
# Train. Epoch 3. Iter 40/100, IoU = 0.35
# Train. Epoch 3. Iter 41/100, IoU = 0.34
# Train. Epoch 3. Iter 42/100, IoU = 0.34
# Train. Epoch 3. Iter 43/100, IoU = 0.34
# Train. Epoch 3. Iter 44/100, IoU = 0.34
# Train. Epoch 3. Iter 45/100, IoU = 0.34
# Train. Epoch 3. Iter 46/100, IoU = 0.34
# Train. Epoch 3. Iter 47/100, IoU = 0.35
# Train. Epoch 3. Iter 48/100, IoU = 0.35
# Train. Epoch 3. Iter 49/100, IoU = 0.35
# Train. Epoch 3. Iter 50/100, IoU = 0.35
# Train. Epoch 3. Iter 51/100, IoU = 0.35
# Train. Epoch 3. Iter 52/100, IoU = 0.35
# Train. Epoch 3. Iter 53/100, IoU = 0.34
# Train. Epoch 3. Iter 54/100, IoU = 0.34
# Train. Epoch 3. Iter 55/100, IoU = 0.34
# Train. Epoch 3. Iter 56/100, IoU = 0.34
# Train. Epoch 3. Iter 57/100, IoU = 0.34
# Train. Epoch 3. Iter 58/100, IoU = 0.34
# Train. Epoch 3. Iter 59/100, IoU = 0.34
# Train. Epoch 3. Iter 60/100, IoU = 0.34
# Train. Epoch 3. Iter 61/100, IoU = 0.34
# Train. Epoch 3. Iter 62/100, IoU = 0.34
# Train. Epoch 3. Iter 63/100, IoU = 0.33
# Train. Epoch 3. Iter 64/100, IoU = 0.33
# Train. Epoch 3. Iter 65/100, IoU = 0.33
# Train. Epoch 3. Iter 66/100, IoU = 0.34
# Train. Epoch 3. Iter 67/100, IoU = 0.34
# Train. Epoch 3. Iter 68/100, IoU = 0.34
# Train. Epoch 3. Iter 69/100, IoU = 0.33
# Train. Epoch 3. Iter 70/100, IoU = 0.33
# Train. Epoch 3. Iter 71/100, IoU = 0.33
# Train. Epoch 3. Iter 72/100, IoU = 0.33
# Train. Epoch 3. Iter 73/100, IoU = 0.33
# Train. Epoch 3. Iter 74/100, IoU = 0.33
# Train. Epoch 3. Iter 75/100, IoU = 0.33
# Train. Epoch 3. Iter 76/100, IoU = 0.33
# Train. Epoch 3. Iter 77/100, IoU = 0.33
# Train. Epoch 3. Iter 78/100, IoU = 0.33
# Train. Epoch 3. Iter 79/100, IoU = 0.33
# Train. Epoch 3. Iter 80/100, IoU = 0.32
# Train. Epoch 3. Iter 81/100, IoU = 0.32
# Train. Epoch 3. Iter 82/100, IoU = 0.32
# Train. Epoch 3. Iter 83/100, IoU = 0.32
# Train. Epoch 3. Iter 84/100, IoU = 0.32
# Train. Epoch 3. Iter 85/100, IoU = 0.32
# Train. Epoch 3. Iter 86/100, IoU = 0.32
# Train. Epoch 3. Iter 87/100, IoU = 0.32
# Train. Epoch 3. Iter 88/100, IoU = 0.31
# Train. Epoch 3. Iter 89/100, IoU = 0.31
# Train. Epoch 3. Iter 90/100, IoU = 0.31
# Train. Epoch 3. Iter 91/100, IoU = 0.32
# Train. Epoch 3. Iter 92/100, IoU = 0.31
# Train. Epoch 3. Iter 93/100, IoU = 0.31
# Train. Epoch 3. Iter 94/100, IoU = 0.31
# Train. Epoch 3. Iter 95/100, IoU = 0.31
# Train. Epoch 3. Iter 96/100, IoU = 0.31
# Train. Epoch 3. Iter 97/100, IoU = 0.31
# Train. Epoch 3. Iter 98/100, IoU = 0.32
# Train. Epoch 3. Iter 99/100, IoU = 0.32
# Train. Epoch 3. Iter 100/100, IoU = 0.32
# Test. Epoch 3. Iter 1/68, IoU = 0.51
# Test. Epoch 3. Iter 2/68, IoU = 0.56
# Test. Epoch 3. Iter 3/68, IoU = 0.62
# Test. Epoch 3. Iter 4/68, IoU = 0.58
# Test. Epoch 3. Iter 5/68, IoU = 0.58
# Test. Epoch 3. Iter 6/68, IoU = 0.59
# Test. Epoch 3. Iter 7/68, IoU = 0.60
# Test. Epoch 3. Iter 8/68, IoU = 0.61
# Test. Epoch 3. Iter 9/68, IoU = 0.61
# Test. Epoch 3. Iter 10/68, IoU = 0.61
# Test. Epoch 3. Iter 11/68, IoU = 0.60
# Test. Epoch 3. Iter 12/68, IoU = 0.60
# Test. Epoch 3. Iter 13/68, IoU = 0.59
# Test. Epoch 3. Iter 14/68, IoU = 0.59
# Test. Epoch 3. Iter 15/68, IoU = 0.59
# Test. Epoch 3. Iter 16/68, IoU = 0.61
# Test. Epoch 3. Iter 17/68, IoU = 0.62
# Test. Epoch 3. Iter 18/68, IoU = 0.60
# Test. Epoch 3. Iter 19/68, IoU = 0.58
# Test. Epoch 3. Iter 20/68, IoU = 0.58
# Test. Epoch 3. Iter 21/68, IoU = 0.59
# Test. Epoch 3. Iter 22/68, IoU = 0.60
# Test. Epoch 3. Iter 23/68, IoU = 0.61
# Test. Epoch 3. Iter 24/68, IoU = 0.60
# Test. Epoch 3. Iter 25/68, IoU = 0.60
# Test. Epoch 3. Iter 26/68, IoU = 0.59
# Test. Epoch 3. Iter 27/68, IoU = 0.59
# Test. Epoch 3. Iter 28/68, IoU = 0.59
# Test. Epoch 3. Iter 29/68, IoU = 0.59
# Test. Epoch 3. Iter 30/68, IoU = 0.59
# Test. Epoch 3. Iter 31/68, IoU = 0.59
# Test. Epoch 3. Iter 32/68, IoU = 0.59
# Test. Epoch 3. Iter 33/68, IoU = 0.58
# Test. Epoch 3. Iter 34/68, IoU = 0.58
# Test. Epoch 3. Iter 35/68, IoU = 0.57
# Test. Epoch 3. Iter 36/68, IoU = 0.58
# Test. Epoch 3. Iter 37/68, IoU = 0.58
# Test. Epoch 3. Iter 38/68, IoU = 0.58
# Test. Epoch 3. Iter 39/68, IoU = 0.58
# Test. Epoch 3. Iter 40/68, IoU = 0.58
# Test. Epoch 3. Iter 41/68, IoU = 0.59
# Test. Epoch 3. Iter 42/68, IoU = 0.59
# Test. Epoch 3. Iter 43/68, IoU = 0.59
# Test. Epoch 3. Iter 44/68, IoU = 0.60
# Test. Epoch 3. Iter 45/68, IoU = 0.61
# Test. Epoch 3. Iter 46/68, IoU = 0.61
# Test. Epoch 3. Iter 47/68, IoU = 0.61
# Test. Epoch 3. Iter 48/68, IoU = 0.62
# Test. Epoch 3. Iter 49/68, IoU = 0.62
# Test. Epoch 3. Iter 50/68, IoU = 0.62
# Test. Epoch 3. Iter 51/68, IoU = 0.62
# Test. Epoch 3. Iter 52/68, IoU = 0.62
# Test. Epoch 3. Iter 53/68, IoU = 0.62
# Test. Epoch 3. Iter 54/68, IoU = 0.62
# Test. Epoch 3. Iter 55/68, IoU = 0.63
# Test. Epoch 3. Iter 56/68, IoU = 0.63
# Test. Epoch 3. Iter 57/68, IoU = 0.63
# Test. Epoch 3. Iter 58/68, IoU = 0.63
# Test. Epoch 3. Iter 59/68, IoU = 0.63
# Test. Epoch 3. Iter 60/68, IoU = 0.63
# Test. Epoch 3. Iter 61/68, IoU = 0.63
# Test. Epoch 3. Iter 62/68, IoU = 0.63
# Test. Epoch 3. Iter 63/68, IoU = 0.63
# Test. Epoch 3. Iter 64/68, IoU = 0.63
# Test. Epoch 3. Iter 65/68, IoU = 0.63
# Test. Epoch 3. Iter 66/68, IoU = 0.63
# Test. Epoch 3. Iter 67/68, IoU = 0.63
# Test. Epoch 3. Iter 68/68, IoU = 0.62
# Train. Epoch 4. Iter 1/100, IoU = 0.73
# Train. Epoch 4. Iter 2/100, IoU = 0.67
# Train. Epoch 4. Iter 3/100, IoU = 0.54
# Train. Epoch 4. Iter 4/100, IoU = 0.49
# Train. Epoch 4. Iter 5/100, IoU = 0.46
# Train. Epoch 4. Iter 6/100, IoU = 0.41
# Train. Epoch 4. Iter 7/100, IoU = 0.41
# Train. Epoch 4. Iter 8/100, IoU = 0.41
# Train. Epoch 4. Iter 9/100, IoU = 0.40
# Train. Epoch 4. Iter 10/100, IoU = 0.42
# Train. Epoch 4. Iter 11/100, IoU = 0.40
# Train. Epoch 4. Iter 12/100, IoU = 0.38
# Train. Epoch 4. Iter 13/100, IoU = 0.37
# Train. Epoch 4. Iter 14/100, IoU = 0.40
# Train. Epoch 4. Iter 15/100, IoU = 0.39
# Train. Epoch 4. Iter 16/100, IoU = 0.39
# Train. Epoch 4. Iter 17/100, IoU = 0.38
# Train. Epoch 4. Iter 18/100, IoU = 0.39
# Train. Epoch 4. Iter 19/100, IoU = 0.39
# Train. Epoch 4. Iter 20/100, IoU = 0.40
# Train. Epoch 4. Iter 21/100, IoU = 0.38
# Train. Epoch 4. Iter 22/100, IoU = 0.38
# Train. Epoch 4. Iter 23/100, IoU = 0.37
# Train. Epoch 4. Iter 24/100, IoU = 0.38
# Train. Epoch 4. Iter 25/100, IoU = 0.37
# Train. Epoch 4. Iter 26/100, IoU = 0.37
# Train. Epoch 4. Iter 27/100, IoU = 0.37
# Train. Epoch 4. Iter 28/100, IoU = 0.37
# Train. Epoch 4. Iter 29/100, IoU = 0.37
# Train. Epoch 4. Iter 30/100, IoU = 0.38
# Train. Epoch 4. Iter 31/100, IoU = 0.37
# Train. Epoch 4. Iter 32/100, IoU = 0.36
# Train. Epoch 4. Iter 33/100, IoU = 0.36
# Train. Epoch 4. Iter 34/100, IoU = 0.36
# Train. Epoch 4. Iter 35/100, IoU = 0.36
# Train. Epoch 4. Iter 36/100, IoU = 0.37
# Train. Epoch 4. Iter 37/100, IoU = 0.36
# Train. Epoch 4. Iter 38/100, IoU = 0.36
# Train. Epoch 4. Iter 39/100, IoU = 0.36
# Train. Epoch 4. Iter 40/100, IoU = 0.37
# Train. Epoch 4. Iter 41/100, IoU = 0.36
# Train. Epoch 4. Iter 42/100, IoU = 0.36
# Train. Epoch 4. Iter 43/100, IoU = 0.36
# Train. Epoch 4. Iter 44/100, IoU = 0.35
# Train. Epoch 4. Iter 45/100, IoU = 0.35
# Train. Epoch 4. Iter 46/100, IoU = 0.34
# Train. Epoch 4. Iter 47/100, IoU = 0.35
# Train. Epoch 4. Iter 48/100, IoU = 0.35
# Train. Epoch 4. Iter 49/100, IoU = 0.35
# Train. Epoch 4. Iter 50/100, IoU = 0.35
# Train. Epoch 4. Iter 51/100, IoU = 0.35
# Train. Epoch 4. Iter 52/100, IoU = 0.35
# Train. Epoch 4. Iter 53/100, IoU = 0.35
# Train. Epoch 4. Iter 54/100, IoU = 0.35
# Train. Epoch 4. Iter 55/100, IoU = 0.35
# Train. Epoch 4. Iter 56/100, IoU = 0.35
# Train. Epoch 4. Iter 57/100, IoU = 0.35
# Train. Epoch 4. Iter 58/100, IoU = 0.35
# Train. Epoch 4. Iter 59/100, IoU = 0.35
# Train. Epoch 4. Iter 60/100, IoU = 0.35
# Train. Epoch 4. Iter 61/100, IoU = 0.35
# Train. Epoch 4. Iter 62/100, IoU = 0.35
# Train. Epoch 4. Iter 63/100, IoU = 0.35
# Train. Epoch 4. Iter 64/100, IoU = 0.35
# Train. Epoch 4. Iter 65/100, IoU = 0.35
# Train. Epoch 4. Iter 66/100, IoU = 0.36
# Train. Epoch 4. Iter 67/100, IoU = 0.36
# Train. Epoch 4. Iter 68/100, IoU = 0.36
# Train. Epoch 4. Iter 69/100, IoU = 0.36
# Train. Epoch 4. Iter 70/100, IoU = 0.36
# Train. Epoch 4. Iter 71/100, IoU = 0.36
# Train. Epoch 4. Iter 72/100, IoU = 0.36
# Train. Epoch 4. Iter 73/100, IoU = 0.36
# Train. Epoch 4. Iter 74/100, IoU = 0.36
# Train. Epoch 4. Iter 75/100, IoU = 0.36
# Train. Epoch 4. Iter 76/100, IoU = 0.36
# Train. Epoch 4. Iter 77/100, IoU = 0.36
# Train. Epoch 4. Iter 78/100, IoU = 0.36
# Train. Epoch 4. Iter 79/100, IoU = 0.36
# Train. Epoch 4. Iter 80/100, IoU = 0.36
# Train. Epoch 4. Iter 81/100, IoU = 0.36
# Train. Epoch 4. Iter 82/100, IoU = 0.36
# Train. Epoch 4. Iter 83/100, IoU = 0.36
# Train. Epoch 4. Iter 84/100, IoU = 0.36
# Train. Epoch 4. Iter 85/100, IoU = 0.36
# Train. Epoch 4. Iter 86/100, IoU = 0.36
# Train. Epoch 4. Iter 87/100, IoU = 0.36
# Train. Epoch 4. Iter 88/100, IoU = 0.36
# Train. Epoch 4. Iter 89/100, IoU = 0.36
# Train. Epoch 4. Iter 90/100, IoU = 0.36
# Train. Epoch 4. Iter 91/100, IoU = 0.36
# Train. Epoch 4. Iter 92/100, IoU = 0.36
# Train. Epoch 4. Iter 93/100, IoU = 0.36
# Train. Epoch 4. Iter 94/100, IoU = 0.36
# Train. Epoch 4. Iter 95/100, IoU = 0.36
# Train. Epoch 4. Iter 96/100, IoU = 0.35
# Train. Epoch 4. Iter 97/100, IoU = 0.36
# Train. Epoch 4. Iter 98/100, IoU = 0.36
# Train. Epoch 4. Iter 99/100, IoU = 0.36
# Train. Epoch 4. Iter 100/100, IoU = 0.36
# Test. Epoch 4. Iter 1/68, IoU = 0.48
# Test. Epoch 4. Iter 2/68, IoU = 0.64
# Test. Epoch 4. Iter 3/68, IoU = 0.70
# Test. Epoch 4. Iter 4/68, IoU = 0.67
# Test. Epoch 4. Iter 5/68, IoU = 0.63
# Test. Epoch 4. Iter 6/68, IoU = 0.63
# Test. Epoch 4. Iter 7/68, IoU = 0.64
# Test. Epoch 4. Iter 8/68, IoU = 0.65
# Test. Epoch 4. Iter 9/68, IoU = 0.64
# Test. Epoch 4. Iter 10/68, IoU = 0.65
# Test. Epoch 4. Iter 11/68, IoU = 0.64
# Test. Epoch 4. Iter 12/68, IoU = 0.64
# Test. Epoch 4. Iter 13/68, IoU = 0.63
# Test. Epoch 4. Iter 14/68, IoU = 0.64
# Test. Epoch 4. Iter 15/68, IoU = 0.64
# Test. Epoch 4. Iter 16/68, IoU = 0.65
# Test. Epoch 4. Iter 17/68, IoU = 0.67
# Test. Epoch 4. Iter 18/68, IoU = 0.65
# Test. Epoch 4. Iter 19/68, IoU = 0.64
# Test. Epoch 4. Iter 20/68, IoU = 0.63
# Test. Epoch 4. Iter 21/68, IoU = 0.63
# Test. Epoch 4. Iter 22/68, IoU = 0.64
# Test. Epoch 4. Iter 23/68, IoU = 0.65
# Test. Epoch 4. Iter 24/68, IoU = 0.65
# Test. Epoch 4. Iter 25/68, IoU = 0.65
# Test. Epoch 4. Iter 26/68, IoU = 0.65
# Test. Epoch 4. Iter 27/68, IoU = 0.65
# Test. Epoch 4. Iter 28/68, IoU = 0.66
# Test. Epoch 4. Iter 29/68, IoU = 0.66
# Test. Epoch 4. Iter 30/68, IoU = 0.66
# Test. Epoch 4. Iter 31/68, IoU = 0.66
# Test. Epoch 4. Iter 32/68, IoU = 0.66
# Test. Epoch 4. Iter 33/68, IoU = 0.66
# Test. Epoch 4. Iter 34/68, IoU = 0.66
# Test. Epoch 4. Iter 35/68, IoU = 0.65
# Test. Epoch 4. Iter 36/68, IoU = 0.66
# Test. Epoch 4. Iter 37/68, IoU = 0.66
# Test. Epoch 4. Iter 38/68, IoU = 0.66
# Test. Epoch 4. Iter 39/68, IoU = 0.66
# Test. Epoch 4. Iter 40/68, IoU = 0.67
# Test. Epoch 4. Iter 41/68, IoU = 0.67
# Test. Epoch 4. Iter 42/68, IoU = 0.67
# Test. Epoch 4. Iter 43/68, IoU = 0.67
# Test. Epoch 4. Iter 44/68, IoU = 0.68
# Test. Epoch 4. Iter 45/68, IoU = 0.68
# Test. Epoch 4. Iter 46/68, IoU = 0.69
# Test. Epoch 4. Iter 47/68, IoU = 0.69
# Test. Epoch 4. Iter 48/68, IoU = 0.69
# Test. Epoch 4. Iter 49/68, IoU = 0.69
# Test. Epoch 4. Iter 50/68, IoU = 0.69
# Test. Epoch 4. Iter 51/68, IoU = 0.69
# Test. Epoch 4. Iter 52/68, IoU = 0.69
# Test. Epoch 4. Iter 53/68, IoU = 0.69
# Test. Epoch 4. Iter 54/68, IoU = 0.69
# Test. Epoch 4. Iter 55/68, IoU = 0.70
# Test. Epoch 4. Iter 56/68, IoU = 0.69
# Test. Epoch 4. Iter 57/68, IoU = 0.70
# Test. Epoch 4. Iter 58/68, IoU = 0.69
# Test. Epoch 4. Iter 59/68, IoU = 0.70
# Test. Epoch 4. Iter 60/68, IoU = 0.70
# Test. Epoch 4. Iter 61/68, IoU = 0.70
# Test. Epoch 4. Iter 62/68, IoU = 0.70
# Test. Epoch 4. Iter 63/68, IoU = 0.70
# Test. Epoch 4. Iter 64/68, IoU = 0.70
# Test. Epoch 4. Iter 65/68, IoU = 0.70
# Test. Epoch 4. Iter 66/68, IoU = 0.70
# Test. Epoch 4. Iter 67/68, IoU = 0.69
# Test. Epoch 4. Iter 68/68, IoU = 0.69
# Train. Epoch 5. Iter 1/100, IoU = 0.72
# Train. Epoch 5. Iter 2/100, IoU = 0.66
# Train. Epoch 5. Iter 3/100, IoU = 0.55
# Train. Epoch 5. Iter 4/100, IoU = 0.48
# Train. Epoch 5. Iter 5/100, IoU = 0.44
# Train. Epoch 5. Iter 6/100, IoU = 0.40
# Train. Epoch 5. Iter 7/100, IoU = 0.42
# Train. Epoch 5. Iter 8/100, IoU = 0.41
# Train. Epoch 5. Iter 9/100, IoU = 0.41
# Train. Epoch 5. Iter 10/100, IoU = 0.44
# Train. Epoch 5. Iter 11/100, IoU = 0.42
# Train. Epoch 5. Iter 12/100, IoU = 0.40
# Train. Epoch 5. Iter 13/100, IoU = 0.40
# Train. Epoch 5. Iter 14/100, IoU = 0.42
# Train. Epoch 5. Iter 15/100, IoU = 0.42
# Train. Epoch 5. Iter 16/100, IoU = 0.43
# Train. Epoch 5. Iter 17/100, IoU = 0.45
# Train. Epoch 5. Iter 18/100, IoU = 0.45
# Train. Epoch 5. Iter 19/100, IoU = 0.45
# Train. Epoch 5. Iter 20/100, IoU = 0.46
# Train. Epoch 5. Iter 21/100, IoU = 0.44
# Train. Epoch 5. Iter 22/100, IoU = 0.45
# Train. Epoch 5. Iter 23/100, IoU = 0.46
# Train. Epoch 5. Iter 24/100, IoU = 0.46
# Train. Epoch 5. Iter 25/100, IoU = 0.46
# Train. Epoch 5. Iter 26/100, IoU = 0.47
# Train. Epoch 5. Iter 27/100, IoU = 0.46
# Train. Epoch 5. Iter 28/100, IoU = 0.47
# Train. Epoch 5. Iter 29/100, IoU = 0.48
# Train. Epoch 5. Iter 30/100, IoU = 0.48
# Train. Epoch 5. Iter 31/100, IoU = 0.47
# Train. Epoch 5. Iter 32/100, IoU = 0.47
# Train. Epoch 5. Iter 33/100, IoU = 0.46
# Train. Epoch 5. Iter 34/100, IoU = 0.45
# Train. Epoch 5. Iter 35/100, IoU = 0.45
# Train. Epoch 5. Iter 36/100, IoU = 0.45
# Train. Epoch 5. Iter 37/100, IoU = 0.44
# Train. Epoch 5. Iter 38/100, IoU = 0.44
# Train. Epoch 5. Iter 39/100, IoU = 0.44
# Train. Epoch 5. Iter 40/100, IoU = 0.44
# Train. Epoch 5. Iter 41/100, IoU = 0.43
# Train. Epoch 5. Iter 42/100, IoU = 0.43
# Train. Epoch 5. Iter 43/100, IoU = 0.43
# Train. Epoch 5. Iter 44/100, IoU = 0.43
# Train. Epoch 5. Iter 45/100, IoU = 0.42
# Train. Epoch 5. Iter 46/100, IoU = 0.41
# Train. Epoch 5. Iter 47/100, IoU = 0.42
# Train. Epoch 5. Iter 48/100, IoU = 0.42
# Train. Epoch 5. Iter 49/100, IoU = 0.42
# Train. Epoch 5. Iter 50/100, IoU = 0.42
# Train. Epoch 5. Iter 51/100, IoU = 0.42
# Train. Epoch 5. Iter 52/100, IoU = 0.42
# Train. Epoch 5. Iter 53/100, IoU = 0.42
# Train. Epoch 5. Iter 54/100, IoU = 0.42
# Train. Epoch 5. Iter 55/100, IoU = 0.41
# Train. Epoch 5. Iter 56/100, IoU = 0.41
# Train. Epoch 5. Iter 57/100, IoU = 0.41
# Train. Epoch 5. Iter 58/100, IoU = 0.41
# Train. Epoch 5. Iter 59/100, IoU = 0.41
# Train. Epoch 5. Iter 60/100, IoU = 0.41
# Train. Epoch 5. Iter 61/100, IoU = 0.41
# Train. Epoch 5. Iter 62/100, IoU = 0.41
# Train. Epoch 5. Iter 63/100, IoU = 0.41
# Train. Epoch 5. Iter 64/100, IoU = 0.41
# Train. Epoch 5. Iter 65/100, IoU = 0.41
# Train. Epoch 5. Iter 66/100, IoU = 0.41
# Train. Epoch 5. Iter 67/100, IoU = 0.41
# Train. Epoch 5. Iter 68/100, IoU = 0.41
# Train. Epoch 5. Iter 69/100, IoU = 0.41
# Train. Epoch 5. Iter 70/100, IoU = 0.40
# Train. Epoch 5. Iter 71/100, IoU = 0.40
# Train. Epoch 5. Iter 72/100, IoU = 0.40
# Train. Epoch 5. Iter 73/100, IoU = 0.40
# Train. Epoch 5. Iter 74/100, IoU = 0.40
# Train. Epoch 5. Iter 75/100, IoU = 0.40
# Train. Epoch 5. Iter 76/100, IoU = 0.40
# Train. Epoch 5. Iter 77/100, IoU = 0.40
# Train. Epoch 5. Iter 78/100, IoU = 0.40
# Train. Epoch 5. Iter 79/100, IoU = 0.40
# Train. Epoch 5. Iter 80/100, IoU = 0.40
# Train. Epoch 5. Iter 81/100, IoU = 0.40
# Train. Epoch 5. Iter 82/100, IoU = 0.39
# Train. Epoch 5. Iter 83/100, IoU = 0.39
# Train. Epoch 5. Iter 84/100, IoU = 0.39
# Train. Epoch 5. Iter 85/100, IoU = 0.39
# Train. Epoch 5. Iter 86/100, IoU = 0.39
# Train. Epoch 5. Iter 87/100, IoU = 0.39
# Train. Epoch 5. Iter 88/100, IoU = 0.39
# Train. Epoch 5. Iter 89/100, IoU = 0.39
# Train. Epoch 5. Iter 90/100, IoU = 0.39
# Train. Epoch 5. Iter 91/100, IoU = 0.39
# Train. Epoch 5. Iter 92/100, IoU = 0.39
# Train. Epoch 5. Iter 93/100, IoU = 0.39
# Train. Epoch 5. Iter 94/100, IoU = 0.39
# Train. Epoch 5. Iter 95/100, IoU = 0.39
# Train. Epoch 5. Iter 96/100, IoU = 0.39
# Train. Epoch 5. Iter 97/100, IoU = 0.39
# Train. Epoch 5. Iter 98/100, IoU = 0.39
# Train. Epoch 5. Iter 99/100, IoU = 0.39
# Train. Epoch 5. Iter 100/100, IoU = 0.39
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:960: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# Test. Epoch 5. Iter 1/68, IoU = 0.49
# Test. Epoch 5. Iter 2/68, IoU = 0.63
# Test. Epoch 5. Iter 3/68, IoU = 0.70
# Test. Epoch 5. Iter 4/68, IoU = 0.67
# Test. Epoch 5. Iter 5/68, IoU = 0.65
# Test. Epoch 5. Iter 6/68, IoU = 0.62
# Test. Epoch 5. Iter 7/68, IoU = 0.63
# Test. Epoch 5. Iter 8/68, IoU = 0.64
# Test. Epoch 5. Iter 9/68, IoU = 0.64
# Test. Epoch 5. Iter 10/68, IoU = 0.66
# Test. Epoch 5. Iter 11/68, IoU = 0.65
# Test. Epoch 5. Iter 12/68, IoU = 0.64
# Test. Epoch 5. Iter 13/68, IoU = 0.64
# Test. Epoch 5. Iter 14/68, IoU = 0.64
# Test. Epoch 5. Iter 15/68, IoU = 0.64
# Test. Epoch 5. Iter 16/68, IoU = 0.66
# Test. Epoch 5. Iter 17/68, IoU = 0.68
# Test. Epoch 5. Iter 18/68, IoU = 0.65
# Test. Epoch 5. Iter 19/68, IoU = 0.63
# Test. Epoch 5. Iter 20/68, IoU = 0.63
# Test. Epoch 5. Iter 21/68, IoU = 0.63
# Test. Epoch 5. Iter 22/68, IoU = 0.64
# Test. Epoch 5. Iter 23/68, IoU = 0.65
# Test. Epoch 5. Iter 24/68, IoU = 0.65
# Test. Epoch 5. Iter 25/68, IoU = 0.65
# Test. Epoch 5. Iter 26/68, IoU = 0.65
# Test. Epoch 5. Iter 27/68, IoU = 0.65
# Test. Epoch 5. Iter 28/68, IoU = 0.65
# Test. Epoch 5. Iter 29/68, IoU = 0.66
# Test. Epoch 5. Iter 30/68, IoU = 0.66
# Test. Epoch 5. Iter 31/68, IoU = 0.66
# Test. Epoch 5. Iter 32/68, IoU = 0.66
# Test. Epoch 5. Iter 33/68, IoU = 0.65
# Test. Epoch 5. Iter 34/68, IoU = 0.66
# Test. Epoch 5. Iter 35/68, IoU = 0.65
# Test. Epoch 5. Iter 36/68, IoU = 0.65
# Test. Epoch 5. Iter 37/68, IoU = 0.66
# Test. Epoch 5. Iter 38/68, IoU = 0.66
# Test. Epoch 5. Iter 39/68, IoU = 0.67
# Test. Epoch 5. Iter 40/68, IoU = 0.67
# Test. Epoch 5. Iter 41/68, IoU = 0.68
# Test. Epoch 5. Iter 42/68, IoU = 0.67
# Test. Epoch 5. Iter 43/68, IoU = 0.68
# Test. Epoch 5. Iter 44/68, IoU = 0.68
# Test. Epoch 5. Iter 45/68, IoU = 0.68
# Test. Epoch 5. Iter 46/68, IoU = 0.69
# Test. Epoch 5. Iter 47/68, IoU = 0.69
# Test. Epoch 5. Iter 48/68, IoU = 0.69
# Test. Epoch 5. Iter 49/68, IoU = 0.69
# Test. Epoch 5. Iter 50/68, IoU = 0.69
# Test. Epoch 5. Iter 51/68, IoU = 0.69
# Test. Epoch 5. Iter 52/68, IoU = 0.69
# Test. Epoch 5. Iter 53/68, IoU = 0.70
# Test. Epoch 5. Iter 54/68, IoU = 0.70
# Test. Epoch 5. Iter 55/68, IoU = 0.70
# Test. Epoch 5. Iter 56/68, IoU = 0.70
# Test. Epoch 5. Iter 57/68, IoU = 0.70
# Test. Epoch 5. Iter 58/68, IoU = 0.70
# Test. Epoch 5. Iter 59/68, IoU = 0.70
# Test. Epoch 5. Iter 60/68, IoU = 0.70
# Test. Epoch 5. Iter 61/68, IoU = 0.70
# Test. Epoch 5. Iter 62/68, IoU = 0.70
# Test. Epoch 5. Iter 63/68, IoU = 0.70
# Test. Epoch 5. Iter 64/68, IoU = 0.70
# Test. Epoch 5. Iter 65/68, IoU = 0.70
# Test. Epoch 5. Iter 66/68, IoU = 0.70
# Test. Epoch 5. Iter 67/68, IoU = 0.70
# Test. Epoch 5. Iter 68/68, IoU = 0.69
# Train. Epoch 6. Iter 1/100, IoU = 0.78
# Train. Epoch 6. Iter 2/100, IoU = 0.68
# Train. Epoch 6. Iter 3/100, IoU = 0.60
# Train. Epoch 6. Iter 4/100, IoU = 0.50
# Train. Epoch 6. Iter 5/100, IoU = 0.44
# Train. Epoch 6. Iter 6/100, IoU = 0.40
# Train. Epoch 6. Iter 7/100, IoU = 0.39
# Train. Epoch 6. Iter 8/100, IoU = 0.40
# Train. Epoch 6. Iter 9/100, IoU = 0.39
# Train. Epoch 6. Iter 10/100, IoU = 0.42
# Train. Epoch 6. Iter 11/100, IoU = 0.40
# Train. Epoch 6. Iter 12/100, IoU = 0.39
# Train. Epoch 6. Iter 13/100, IoU = 0.40
# Train. Epoch 6. Iter 14/100, IoU = 0.40
# Train. Epoch 6. Iter 15/100, IoU = 0.39
# Train. Epoch 6. Iter 16/100, IoU = 0.39
# Train. Epoch 6. Iter 17/100, IoU = 0.38
# Train. Epoch 6. Iter 18/100, IoU = 0.37
# Train. Epoch 6. Iter 19/100, IoU = 0.38
# Train. Epoch 6. Iter 20/100, IoU = 0.39
# Train. Epoch 6. Iter 21/100, IoU = 0.38
# Train. Epoch 6. Iter 22/100, IoU = 0.39
# Train. Epoch 6. Iter 23/100, IoU = 0.39
# Train. Epoch 6. Iter 24/100, IoU = 0.39
# Train. Epoch 6. Iter 25/100, IoU = 0.40
# Train. Epoch 6. Iter 26/100, IoU = 0.41
# Train. Epoch 6. Iter 27/100, IoU = 0.41
# Train. Epoch 6. Iter 28/100, IoU = 0.42
# Train. Epoch 6. Iter 29/100, IoU = 0.42
# Train. Epoch 6. Iter 30/100, IoU = 0.43
# Train. Epoch 6. Iter 31/100, IoU = 0.42
# Train. Epoch 6. Iter 32/100, IoU = 0.42
# Train. Epoch 6. Iter 33/100, IoU = 0.42
# Train. Epoch 6. Iter 34/100, IoU = 0.42
# Train. Epoch 6. Iter 35/100, IoU = 0.41
# Train. Epoch 6. Iter 36/100, IoU = 0.42
# Train. Epoch 6. Iter 37/100, IoU = 0.42
# Train. Epoch 6. Iter 38/100, IoU = 0.42
# Train. Epoch 6. Iter 39/100, IoU = 0.42
# Train. Epoch 6. Iter 40/100, IoU = 0.42
# Train. Epoch 6. Iter 41/100, IoU = 0.42
# Train. Epoch 6. Iter 42/100, IoU = 0.42
# Train. Epoch 6. Iter 43/100, IoU = 0.42
# Train. Epoch 6. Iter 44/100, IoU = 0.43
# Train. Epoch 6. Iter 45/100, IoU = 0.42
# Train. Epoch 6. Iter 46/100, IoU = 0.42
# Train. Epoch 6. Iter 47/100, IoU = 0.42
# Train. Epoch 6. Iter 48/100, IoU = 0.43
# Train. Epoch 6. Iter 49/100, IoU = 0.43
# Train. Epoch 6. Iter 50/100, IoU = 0.43
# Train. Epoch 6. Iter 51/100, IoU = 0.44
# Train. Epoch 6. Iter 52/100, IoU = 0.44
# Train. Epoch 6. Iter 53/100, IoU = 0.43
# Train. Epoch 6. Iter 54/100, IoU = 0.43
# Train. Epoch 6. Iter 55/100, IoU = 0.43
# Train. Epoch 6. Iter 56/100, IoU = 0.43
# Train. Epoch 6. Iter 57/100, IoU = 0.43
# Train. Epoch 6. Iter 58/100, IoU = 0.43
# Train. Epoch 6. Iter 59/100, IoU = 0.43
# Train. Epoch 6. Iter 60/100, IoU = 0.44
# Train. Epoch 6. Iter 61/100, IoU = 0.43
# Train. Epoch 6. Iter 62/100, IoU = 0.43
# Train. Epoch 6. Iter 63/100, IoU = 0.43
# Train. Epoch 6. Iter 64/100, IoU = 0.43
# Train. Epoch 6. Iter 65/100, IoU = 0.43
# Train. Epoch 6. Iter 66/100, IoU = 0.43
# Train. Epoch 6. Iter 67/100, IoU = 0.43
# Train. Epoch 6. Iter 68/100, IoU = 0.43
# Train. Epoch 6. Iter 69/100, IoU = 0.43
# Train. Epoch 6. Iter 70/100, IoU = 0.43
# Train. Epoch 6. Iter 71/100, IoU = 0.43
# Train. Epoch 6. Iter 72/100, IoU = 0.42
# Train. Epoch 6. Iter 73/100, IoU = 0.42
# Train. Epoch 6. Iter 74/100, IoU = 0.42
# Train. Epoch 6. Iter 75/100, IoU = 0.42
# Train. Epoch 6. Iter 76/100, IoU = 0.42
# Train. Epoch 6. Iter 77/100, IoU = 0.42
# Train. Epoch 6. Iter 78/100, IoU = 0.42
# Train. Epoch 6. Iter 79/100, IoU = 0.42
# Train. Epoch 6. Iter 80/100, IoU = 0.42
# Train. Epoch 6. Iter 81/100, IoU = 0.42
# Train. Epoch 6. Iter 82/100, IoU = 0.41
# Train. Epoch 6. Iter 83/100, IoU = 0.41
# Train. Epoch 6. Iter 84/100, IoU = 0.41
# Train. Epoch 6. Iter 85/100, IoU = 0.41
# Train. Epoch 6. Iter 86/100, IoU = 0.41
# Train. Epoch 6. Iter 87/100, IoU = 0.41
# Train. Epoch 6. Iter 88/100, IoU = 0.41
# Train. Epoch 6. Iter 89/100, IoU = 0.41
# Train. Epoch 6. Iter 90/100, IoU = 0.41
# Train. Epoch 6. Iter 91/100, IoU = 0.41
# Train. Epoch 6. Iter 92/100, IoU = 0.41
# Train. Epoch 6. Iter 93/100, IoU = 0.41
# Train. Epoch 6. Iter 94/100, IoU = 0.41
# Train. Epoch 6. Iter 95/100, IoU = 0.41
# Train. Epoch 6. Iter 96/100, IoU = 0.40
# Train. Epoch 6. Iter 97/100, IoU = 0.41
# Train. Epoch 6. Iter 98/100, IoU = 0.41
# Train. Epoch 6. Iter 99/100, IoU = 0.41
# Train. Epoch 6. Iter 100/100, IoU = 0.41
# Test. Epoch 6. Iter 1/68, IoU = 0.45
# Test. Epoch 6. Iter 2/68, IoU = 0.58
# Test. Epoch 6. Iter 3/68, IoU = 0.65
# Test. Epoch 6. Iter 4/68, IoU = 0.63
# Test. Epoch 6. Iter 5/68, IoU = 0.63
# Test. Epoch 6. Iter 6/68, IoU = 0.60
# Test. Epoch 6. Iter 7/68, IoU = 0.61
# Test. Epoch 6. Iter 8/68, IoU = 0.63
# Test. Epoch 6. Iter 9/68, IoU = 0.63
# Test. Epoch 6. Iter 10/68, IoU = 0.64
# Test. Epoch 6. Iter 11/68, IoU = 0.63
# Test. Epoch 6. Iter 12/68, IoU = 0.64
# Test. Epoch 6. Iter 13/68, IoU = 0.64
# Test. Epoch 6. Iter 14/68, IoU = 0.65
# Test. Epoch 6. Iter 15/68, IoU = 0.64
# Test. Epoch 6. Iter 16/68, IoU = 0.66
# Test. Epoch 6. Iter 17/68, IoU = 0.67
# Test. Epoch 6. Iter 18/68, IoU = 0.64
# Test. Epoch 6. Iter 19/68, IoU = 0.62
# Test. Epoch 6. Iter 20/68, IoU = 0.62
# Test. Epoch 6. Iter 21/68, IoU = 0.62
# Test. Epoch 6. Iter 22/68, IoU = 0.63
# Test. Epoch 6. Iter 23/68, IoU = 0.64
# Test. Epoch 6. Iter 24/68, IoU = 0.65
# Test. Epoch 6. Iter 25/68, IoU = 0.64
# Test. Epoch 6. Iter 26/68, IoU = 0.64
# Test. Epoch 6. Iter 27/68, IoU = 0.63
# Test. Epoch 6. Iter 28/68, IoU = 0.64
# Test. Epoch 6. Iter 29/68, IoU = 0.64
# Test. Epoch 6. Iter 30/68, IoU = 0.64
# Test. Epoch 6. Iter 31/68, IoU = 0.64
# Test. Epoch 6. Iter 32/68, IoU = 0.63
# Test. Epoch 6. Iter 33/68, IoU = 0.63
# Test. Epoch 6. Iter 34/68, IoU = 0.63
# Test. Epoch 6. Iter 35/68, IoU = 0.62
# Test. Epoch 6. Iter 36/68, IoU = 0.63
# Test. Epoch 6. Iter 37/68, IoU = 0.63
# Test. Epoch 6. Iter 38/68, IoU = 0.63
# Test. Epoch 6. Iter 39/68, IoU = 0.64
# Test. Epoch 6. Iter 40/68, IoU = 0.65
# Test. Epoch 6. Iter 41/68, IoU = 0.65
# Test. Epoch 6. Iter 42/68, IoU = 0.65
# Test. Epoch 6. Iter 43/68, IoU = 0.65
# Test. Epoch 6. Iter 44/68, IoU = 0.66
# Test. Epoch 6. Iter 45/68, IoU = 0.66
# ...
# Test. Epoch 97. Iter 4/68, IoU = 0.77
# Test. Epoch 97. Iter 5/68, IoU = 0.78
# Test. Epoch 97. Iter 6/68, IoU = 0.74
# Test. Epoch 97. Iter 7/68, IoU = 0.75
# Test. Epoch 97. Iter 8/68, IoU = 0.77
# Test. Epoch 97. Iter 9/68, IoU = 0.77
# Test. Epoch 97. Iter 10/68, IoU = 0.79
# Test. Epoch 97. Iter 11/68, IoU = 0.77
# Test. Epoch 97. Iter 12/68, IoU = 0.79
# Test. Epoch 97. Iter 13/68, IoU = 0.79
# Test. Epoch 97. Iter 14/68, IoU = 0.80
# Test. Epoch 97. Iter 15/68, IoU = 0.79
# Test. Epoch 97. Iter 16/68, IoU = 0.80
# Test. Epoch 97. Iter 17/68, IoU = 0.81
# Test. Epoch 97. Iter 18/68, IoU = 0.81
# Test. Epoch 97. Iter 19/68, IoU = 0.81
# Test. Epoch 97. Iter 20/68, IoU = 0.81
# Test. Epoch 97. Iter 21/68, IoU = 0.81
# Test. Epoch 97. Iter 22/68, IoU = 0.81
# Test. Epoch 97. Iter 23/68, IoU = 0.81
# Test. Epoch 97. Iter 24/68, IoU = 0.82
# Test. Epoch 97. Iter 25/68, IoU = 0.82
# Test. Epoch 97. Iter 26/68, IoU = 0.82
# Test. Epoch 97. Iter 27/68, IoU = 0.83
# Test. Epoch 97. Iter 28/68, IoU = 0.83
# Test. Epoch 97. Iter 29/68, IoU = 0.83
# Test. Epoch 97. Iter 30/68, IoU = 0.83
# Test. Epoch 97. Iter 31/68, IoU = 0.83
# Test. Epoch 97. Iter 32/68, IoU = 0.83
# Test. Epoch 97. Iter 33/68, IoU = 0.83
# Test. Epoch 97. Iter 34/68, IoU = 0.83
# Test. Epoch 97. Iter 35/68, IoU = 0.83
# Test. Epoch 97. Iter 36/68, IoU = 0.83
# Test. Epoch 97. Iter 37/68, IoU = 0.83
# Test. Epoch 97. Iter 38/68, IoU = 0.83
# Test. Epoch 97. Iter 39/68, IoU = 0.83
# Test. Epoch 97. Iter 40/68, IoU = 0.83
# Test. Epoch 97. Iter 41/68, IoU = 0.83
# Test. Epoch 97. Iter 42/68, IoU = 0.84
# Test. Epoch 97. Iter 43/68, IoU = 0.84
# Test. Epoch 97. Iter 44/68, IoU = 0.84
# Test. Epoch 97. Iter 45/68, IoU = 0.84
# Test. Epoch 97. Iter 46/68, IoU = 0.84
# Test. Epoch 97. Iter 47/68, IoU = 0.84
# Test. Epoch 97. Iter 48/68, IoU = 0.84
# Test. Epoch 97. Iter 49/68, IoU = 0.84
# Test. Epoch 97. Iter 50/68, IoU = 0.84
# Test. Epoch 97. Iter 51/68, IoU = 0.84
# Test. Epoch 97. Iter 52/68, IoU = 0.84
# Test. Epoch 97. Iter 53/68, IoU = 0.84
# Test. Epoch 97. Iter 54/68, IoU = 0.84
# Test. Epoch 97. Iter 55/68, IoU = 0.84
# Test. Epoch 97. Iter 56/68, IoU = 0.84
# Test. Epoch 97. Iter 57/68, IoU = 0.84
# Test. Epoch 97. Iter 58/68, IoU = 0.84
# Test. Epoch 97. Iter 59/68, IoU = 0.84
# Test. Epoch 97. Iter 60/68, IoU = 0.84
# Test. Epoch 97. Iter 61/68, IoU = 0.84
# Test. Epoch 97. Iter 62/68, IoU = 0.84
# Test. Epoch 97. Iter 63/68, IoU = 0.84
# Test. Epoch 97. Iter 64/68, IoU = 0.84
# Test. Epoch 97. Iter 65/68, IoU = 0.84
# Test. Epoch 97. Iter 66/68, IoU = 0.84
# Test. Epoch 97. Iter 67/68, IoU = 0.83
# Test. Epoch 97. Iter 68/68, IoU = 0.83
# Train. Epoch 98. Iter 1/100, IoU = 0.72
# Train. Epoch 98. Iter 2/100, IoU = 0.67
# Train. Epoch 98. Iter 3/100, IoU = 0.71
# Train. Epoch 98. Iter 4/100, IoU = 0.63
# Train. Epoch 98. Iter 5/100, IoU = 0.61
# Train. Epoch 98. Iter 6/100, IoU = 0.62
# Train. Epoch 98. Iter 7/100, IoU = 0.64
# Train. Epoch 98. Iter 8/100, IoU = 0.63
# Train. Epoch 98. Iter 9/100, IoU = 0.62
# Train. Epoch 98. Iter 10/100, IoU = 0.65
# Train. Epoch 98. Iter 11/100, IoU = 0.63
# Train. Epoch 98. Iter 12/100, IoU = 0.63
# Train. Epoch 98. Iter 13/100, IoU = 0.63
# Train. Epoch 98. Iter 14/100, IoU = 0.63
# Train. Epoch 98. Iter 15/100, IoU = 0.62
# Train. Epoch 98. Iter 16/100, IoU = 0.62
# Train. Epoch 98. Iter 17/100, IoU = 0.63
# Train. Epoch 98. Iter 18/100, IoU = 0.62
# Train. Epoch 98. Iter 19/100, IoU = 0.62
# Train. Epoch 98. Iter 20/100, IoU = 0.61
# Train. Epoch 98. Iter 21/100, IoU = 0.61
# Train. Epoch 98. Iter 22/100, IoU = 0.61
# Train. Epoch 98. Iter 23/100, IoU = 0.62
# Train. Epoch 98. Iter 24/100, IoU = 0.63
# Train. Epoch 98. Iter 25/100, IoU = 0.64
# Train. Epoch 98. Iter 26/100, IoU = 0.64
# Train. Epoch 98. Iter 27/100, IoU = 0.65
# Train. Epoch 98. Iter 28/100, IoU = 0.65
# Train. Epoch 98. Iter 29/100, IoU = 0.66
# Train. Epoch 98. Iter 30/100, IoU = 0.66
# Train. Epoch 98. Iter 31/100, IoU = 0.66
# Train. Epoch 98. Iter 32/100, IoU = 0.67
# Train. Epoch 98. Iter 33/100, IoU = 0.66
# Train. Epoch 98. Iter 34/100, IoU = 0.66
# Train. Epoch 98. Iter 35/100, IoU = 0.66
# Train. Epoch 98. Iter 36/100, IoU = 0.66
# Train. Epoch 98. Iter 37/100, IoU = 0.66
# Train. Epoch 98. Iter 38/100, IoU = 0.66
# Train. Epoch 98. Iter 39/100, IoU = 0.66
# Train. Epoch 98. Iter 40/100, IoU = 0.67
# Train. Epoch 98. Iter 41/100, IoU = 0.66
# Train. Epoch 98. Iter 42/100, IoU = 0.67
# Train. Epoch 98. Iter 43/100, IoU = 0.67
# Train. Epoch 98. Iter 44/100, IoU = 0.67
# Train. Epoch 98. Iter 45/100, IoU = 0.67
# Train. Epoch 98. Iter 46/100, IoU = 0.67
# Train. Epoch 98. Iter 47/100, IoU = 0.67
# Train. Epoch 98. Iter 48/100, IoU = 0.67
# Train. Epoch 98. Iter 49/100, IoU = 0.67
# Train. Epoch 98. Iter 50/100, IoU = 0.67
# Train. Epoch 98. Iter 51/100, IoU = 0.66
# Train. Epoch 98. Iter 52/100, IoU = 0.67
# Train. Epoch 98. Iter 53/100, IoU = 0.66
# Train. Epoch 98. Iter 54/100, IoU = 0.67
# Train. Epoch 98. Iter 55/100, IoU = 0.66
# Train. Epoch 98. Iter 56/100, IoU = 0.66
# Train. Epoch 98. Iter 57/100, IoU = 0.66
# Train. Epoch 98. Iter 58/100, IoU = 0.66
# Train. Epoch 98. Iter 59/100, IoU = 0.66
# Train. Epoch 98. Iter 60/100, IoU = 0.66
# Train. Epoch 98. Iter 61/100, IoU = 0.66
# Train. Epoch 98. Iter 62/100, IoU = 0.66
# Train. Epoch 98. Iter 63/100, IoU = 0.66
# Train. Epoch 98. Iter 64/100, IoU = 0.67
# Train. Epoch 98. Iter 65/100, IoU = 0.67
# Train. Epoch 98. Iter 66/100, IoU = 0.67
# Train. Epoch 98. Iter 67/100, IoU = 0.67
# Train. Epoch 98. Iter 68/100, IoU = 0.67
# Train. Epoch 98. Iter 69/100, IoU = 0.67
# Train. Epoch 98. Iter 70/100, IoU = 0.67
# Train. Epoch 98. Iter 71/100, IoU = 0.67
# Train. Epoch 98. Iter 72/100, IoU = 0.67
# Train. Epoch 98. Iter 73/100, IoU = 0.67
# Train. Epoch 98. Iter 74/100, IoU = 0.67
# Train. Epoch 98. Iter 75/100, IoU = 0.67
# Train. Epoch 98. Iter 76/100, IoU = 0.67
# Train. Epoch 98. Iter 77/100, IoU = 0.67
# Train. Epoch 98. Iter 78/100, IoU = 0.67
# Train. Epoch 98. Iter 79/100, IoU = 0.67
# Train. Epoch 98. Iter 80/100, IoU = 0.67
# Train. Epoch 98. Iter 81/100, IoU = 0.67
# Train. Epoch 98. Iter 82/100, IoU = 0.67
# Train. Epoch 98. Iter 83/100, IoU = 0.66
# Train. Epoch 98. Iter 84/100, IoU = 0.67
# Train. Epoch 98. Iter 85/100, IoU = 0.67
# Train. Epoch 98. Iter 86/100, IoU = 0.67
# Train. Epoch 98. Iter 87/100, IoU = 0.67
# Train. Epoch 98. Iter 88/100, IoU = 0.67
# Train. Epoch 98. Iter 89/100, IoU = 0.67
# Train. Epoch 98. Iter 90/100, IoU = 0.67
# Train. Epoch 98. Iter 91/100, IoU = 0.67
# Train. Epoch 98. Iter 92/100, IoU = 0.67
# Train. Epoch 98. Iter 93/100, IoU = 0.67
# Train. Epoch 98. Iter 94/100, IoU = 0.67
# Train. Epoch 98. Iter 95/100, IoU = 0.67
# Train. Epoch 98. Iter 96/100, IoU = 0.67
# Train. Epoch 98. Iter 97/100, IoU = 0.67
# Train. Epoch 98. Iter 98/100, IoU = 0.67
# Train. Epoch 98. Iter 99/100, IoU = 0.67
# Train. Epoch 98. Iter 100/100, IoU = 0.67
# Test. Epoch 98. Iter 1/68, IoU = 0.64
# Test. Epoch 98. Iter 2/68, IoU = 0.76
# Test. Epoch 98. Iter 3/68, IoU = 0.81
# Test. Epoch 98. Iter 4/68, IoU = 0.79
# Test. Epoch 98. Iter 5/68, IoU = 0.80
# Test. Epoch 98. Iter 6/68, IoU = 0.75
# Test. Epoch 98. Iter 7/68, IoU = 0.76
# Test. Epoch 98. Iter 8/68, IoU = 0.78
# Test. Epoch 98. Iter 9/68, IoU = 0.78
# Test. Epoch 98. Iter 10/68, IoU = 0.80
# Test. Epoch 98. Iter 11/68, IoU = 0.78
# Test. Epoch 98. Iter 12/68, IoU = 0.79
# Test. Epoch 98. Iter 13/68, IoU = 0.80
# Test. Epoch 98. Iter 14/68, IoU = 0.81
# Test. Epoch 98. Iter 15/68, IoU = 0.80
# Test. Epoch 98. Iter 16/68, IoU = 0.81
# Test. Epoch 98. Iter 17/68, IoU = 0.82
# Test. Epoch 98. Iter 18/68, IoU = 0.81
# Test. Epoch 98. Iter 19/68, IoU = 0.81
# Test. Epoch 98. Iter 20/68, IoU = 0.81
# Test. Epoch 98. Iter 21/68, IoU = 0.81
# Test. Epoch 98. Iter 22/68, IoU = 0.82
# Test. Epoch 98. Iter 23/68, IoU = 0.82
# Test. Epoch 98. Iter 24/68, IoU = 0.82
# Test. Epoch 98. Iter 25/68, IoU = 0.82
# Test. Epoch 98. Iter 26/68, IoU = 0.82
# Test. Epoch 98. Iter 27/68, IoU = 0.83
# Test. Epoch 98. Iter 28/68, IoU = 0.83
# Test. Epoch 98. Iter 29/68, IoU = 0.83
# Test. Epoch 98. Iter 30/68, IoU = 0.84
# Test. Epoch 98. Iter 31/68, IoU = 0.84
# Test. Epoch 98. Iter 32/68, IoU = 0.84
# Test. Epoch 98. Iter 33/68, IoU = 0.83
# Test. Epoch 98. Iter 34/68, IoU = 0.83
# Test. Epoch 98. Iter 35/68, IoU = 0.83
# Test. Epoch 98. Iter 36/68, IoU = 0.83
# Test. Epoch 98. Iter 37/68, IoU = 0.83
# Test. Epoch 98. Iter 38/68, IoU = 0.83
# Test. Epoch 98. Iter 39/68, IoU = 0.83
# Test. Epoch 98. Iter 40/68, IoU = 0.83
# Test. Epoch 98. Iter 41/68, IoU = 0.83
# Test. Epoch 98. Iter 42/68, IoU = 0.83
# Test. Epoch 98. Iter 43/68, IoU = 0.84
# Test. Epoch 98. Iter 44/68, IoU = 0.84
# Test. Epoch 98. Iter 45/68, IoU = 0.84
# Test. Epoch 98. Iter 46/68, IoU = 0.84
# Test. Epoch 98. Iter 47/68, IoU = 0.84
# Test. Epoch 98. Iter 48/68, IoU = 0.84
# Test. Epoch 98. Iter 49/68, IoU = 0.84
# Test. Epoch 98. Iter 50/68, IoU = 0.84
# Test. Epoch 98. Iter 51/68, IoU = 0.84
# Test. Epoch 98. Iter 52/68, IoU = 0.84
# Test. Epoch 98. Iter 53/68, IoU = 0.84
# Test. Epoch 98. Iter 54/68, IoU = 0.84
# Test. Epoch 98. Iter 55/68, IoU = 0.84
# Test. Epoch 98. Iter 56/68, IoU = 0.84
# Test. Epoch 98. Iter 57/68, IoU = 0.84
# Test. Epoch 98. Iter 58/68, IoU = 0.84
# Test. Epoch 98. Iter 59/68, IoU = 0.84
# Test. Epoch 98. Iter 60/68, IoU = 0.84
# Test. Epoch 98. Iter 61/68, IoU = 0.84
# Test. Epoch 98. Iter 62/68, IoU = 0.84
# Test. Epoch 98. Iter 63/68, IoU = 0.84
# Test. Epoch 98. Iter 64/68, IoU = 0.84
# Test. Epoch 98. Iter 65/68, IoU = 0.84
# Test. Epoch 98. Iter 66/68, IoU = 0.84
# Test. Epoch 98. Iter 67/68, IoU = 0.84
# Test. Epoch 98. Iter 68/68, IoU = 0.84
# Train. Epoch 99. Iter 1/100, IoU = 0.65
# Train. Epoch 99. Iter 2/100, IoU = 0.61
# Train. Epoch 99. Iter 3/100, IoU = 0.67
# Train. Epoch 99. Iter 4/100, IoU = 0.66
# Train. Epoch 99. Iter 5/100, IoU = 0.61
# Train. Epoch 99. Iter 6/100, IoU = 0.64
# Train. Epoch 99. Iter 7/100, IoU = 0.66
# Train. Epoch 99. Iter 8/100, IoU = 0.64
# Train. Epoch 99. Iter 9/100, IoU = 0.63
# Train. Epoch 99. Iter 10/100, IoU = 0.65
# Train. Epoch 99. Iter 11/100, IoU = 0.63
# Train. Epoch 99. Iter 12/100, IoU = 0.63
# Train. Epoch 99. Iter 13/100, IoU = 0.62
# Train. Epoch 99. Iter 14/100, IoU = 0.63
# Train. Epoch 99. Iter 15/100, IoU = 0.64
# Train. Epoch 99. Iter 16/100, IoU = 0.64
# Train. Epoch 99. Iter 17/100, IoU = 0.65
# Train. Epoch 99. Iter 18/100, IoU = 0.64
# Train. Epoch 99. Iter 19/100, IoU = 0.65
# Train. Epoch 99. Iter 20/100, IoU = 0.65
# Train. Epoch 99. Iter 21/100, IoU = 0.65
# Train. Epoch 99. Iter 22/100, IoU = 0.64
# Train. Epoch 99. Iter 23/100, IoU = 0.64
# Train. Epoch 99. Iter 24/100, IoU = 0.65
# Train. Epoch 99. Iter 25/100, IoU = 0.65
# Train. Epoch 99. Iter 26/100, IoU = 0.65
# Train. Epoch 99. Iter 27/100, IoU = 0.64
# Train. Epoch 99. Iter 28/100, IoU = 0.64
# Train. Epoch 99. Iter 29/100, IoU = 0.65
# Train. Epoch 99. Iter 30/100, IoU = 0.65
# Train. Epoch 99. Iter 31/100, IoU = 0.65
# Train. Epoch 99. Iter 32/100, IoU = 0.65
# Train. Epoch 99. Iter 33/100, IoU = 0.65
# Train. Epoch 99. Iter 34/100, IoU = 0.65
# Train. Epoch 99. Iter 35/100, IoU = 0.64
# Train. Epoch 99. Iter 36/100, IoU = 0.65
# Train. Epoch 99. Iter 37/100, IoU = 0.64
# Train. Epoch 99. Iter 38/100, IoU = 0.64
# Train. Epoch 99. Iter 39/100, IoU = 0.64
# Train. Epoch 99. Iter 40/100, IoU = 0.64
# Train. Epoch 99. Iter 41/100, IoU = 0.63
# Train. Epoch 99. Iter 42/100, IoU = 0.63
# Train. Epoch 99. Iter 43/100, IoU = 0.64
# Train. Epoch 99. Iter 44/100, IoU = 0.64
# Train. Epoch 99. Iter 45/100, IoU = 0.64
# Train. Epoch 99. Iter 46/100, IoU = 0.64
# Train. Epoch 99. Iter 47/100, IoU = 0.64
# Train. Epoch 99. Iter 48/100, IoU = 0.64
# Train. Epoch 99. Iter 49/100, IoU = 0.64
# Train. Epoch 99. Iter 50/100, IoU = 0.65
# Train. Epoch 99. Iter 51/100, IoU = 0.64
# Train. Epoch 99. Iter 52/100, IoU = 0.65
# Train. Epoch 99. Iter 53/100, IoU = 0.65
# Train. Epoch 99. Iter 54/100, IoU = 0.65
# Train. Epoch 99. Iter 55/100, IoU = 0.65
# Train. Epoch 99. Iter 56/100, IoU = 0.66
# Train. Epoch 99. Iter 57/100, IoU = 0.66
# Train. Epoch 99. Iter 58/100, IoU = 0.66
# Train. Epoch 99. Iter 59/100, IoU = 0.66
# Train. Epoch 99. Iter 60/100, IoU = 0.66
# Train. Epoch 99. Iter 61/100, IoU = 0.66
# Train. Epoch 99. Iter 62/100, IoU = 0.66
# Train. Epoch 99. Iter 63/100, IoU = 0.66
# Train. Epoch 99. Iter 64/100, IoU = 0.66
# Train. Epoch 99. Iter 65/100, IoU = 0.66
# Train. Epoch 99. Iter 66/100, IoU = 0.67
# Train. Epoch 99. Iter 67/100, IoU = 0.66
# Train. Epoch 99. Iter 68/100, IoU = 0.66
# Train. Epoch 99. Iter 69/100, IoU = 0.66
# Train. Epoch 99. Iter 70/100, IoU = 0.66
# Train. Epoch 99. Iter 71/100, IoU = 0.66
# Train. Epoch 99. Iter 72/100, IoU = 0.66
# Train. Epoch 99. Iter 73/100, IoU = 0.66
# Train. Epoch 99. Iter 74/100, IoU = 0.66
# Train. Epoch 99. Iter 75/100, IoU = 0.66
# Train. Epoch 99. Iter 76/100, IoU = 0.66
# Train. Epoch 99. Iter 77/100, IoU = 0.66
# Train. Epoch 99. Iter 78/100, IoU = 0.66
# Train. Epoch 99. Iter 79/100, IoU = 0.66
# Train. Epoch 99. Iter 80/100, IoU = 0.66
# Train. Epoch 99. Iter 81/100, IoU = 0.67
# Train. Epoch 99. Iter 82/100, IoU = 0.67
# Train. Epoch 99. Iter 83/100, IoU = 0.66
# Train. Epoch 99. Iter 84/100, IoU = 0.67
# Train. Epoch 99. Iter 85/100, IoU = 0.67
# Train. Epoch 99. Iter 86/100, IoU = 0.67
# Train. Epoch 99. Iter 87/100, IoU = 0.67
# Train. Epoch 99. Iter 88/100, IoU = 0.67
# Train. Epoch 99. Iter 89/100, IoU = 0.67
# Train. Epoch 99. Iter 90/100, IoU = 0.67
# Train. Epoch 99. Iter 91/100, IoU = 0.67
# Train. Epoch 99. Iter 92/100, IoU = 0.67
# Train. Epoch 99. Iter 93/100, IoU = 0.67
# Train. Epoch 99. Iter 94/100, IoU = 0.67
# Train. Epoch 99. Iter 95/100, IoU = 0.67
# Train. Epoch 99. Iter 96/100, IoU = 0.67
# Train. Epoch 99. Iter 97/100, IoU = 0.67
# Train. Epoch 99. Iter 98/100, IoU = 0.67
# Train. Epoch 99. Iter 99/100, IoU = 0.67
# Train. Epoch 99. Iter 100/100, IoU = 0.67
# Test. Epoch 99. Iter 1/68, IoU = 0.48
# Test. Epoch 99. Iter 2/68, IoU = 0.67
# Test. Epoch 99. Iter 3/68, IoU = 0.75
# Test. Epoch 99. Iter 4/68, IoU = 0.76
# Test. Epoch 99. Iter 5/68, IoU = 0.78
# Test. Epoch 99. Iter 6/68, IoU = 0.73
# Test. Epoch 99. Iter 7/68, IoU = 0.74
# Test. Epoch 99. Iter 8/68, IoU = 0.76
# Test. Epoch 99. Iter 9/68, IoU = 0.77
# Test. Epoch 99. Iter 10/68, IoU = 0.78
# Test. Epoch 99. Iter 11/68, IoU = 0.77
# Test. Epoch 99. Iter 12/68, IoU = 0.78
# Test. Epoch 99. Iter 13/68, IoU = 0.79
# Test. Epoch 99. Iter 14/68, IoU = 0.79
# Test. Epoch 99. Iter 15/68, IoU = 0.77
# Test. Epoch 99. Iter 16/68, IoU = 0.78
# Test. Epoch 99. Iter 17/68, IoU = 0.79
# Test. Epoch 99. Iter 18/68, IoU = 0.79
# Test. Epoch 99. Iter 19/68, IoU = 0.79
# Test. Epoch 99. Iter 20/68, IoU = 0.79
# Test. Epoch 99. Iter 21/68, IoU = 0.79
# Test. Epoch 99. Iter 22/68, IoU = 0.80
# Test. Epoch 99. Iter 23/68, IoU = 0.80
# Test. Epoch 99. Iter 24/68, IoU = 0.81
# Test. Epoch 99. Iter 25/68, IoU = 0.81
# Test. Epoch 99. Iter 26/68, IoU = 0.81
# Test. Epoch 99. Iter 27/68, IoU = 0.81
# Test. Epoch 99. Iter 28/68, IoU = 0.82
# Test. Epoch 99. Iter 29/68, IoU = 0.82
# Test. Epoch 99. Iter 30/68, IoU = 0.82
# Test. Epoch 99. Iter 31/68, IoU = 0.83
# Test. Epoch 99. Iter 32/68, IoU = 0.82
# Test. Epoch 99. Iter 33/68, IoU = 0.81
# Test. Epoch 99. Iter 34/68, IoU = 0.82
# Test. Epoch 99. Iter 35/68, IoU = 0.82
# Test. Epoch 99. Iter 36/68, IoU = 0.82
# Test. Epoch 99. Iter 37/68, IoU = 0.82
# Test. Epoch 99. Iter 38/68, IoU = 0.82
# Test. Epoch 99. Iter 39/68, IoU = 0.81
# Test. Epoch 99. Iter 40/68, IoU = 0.82
# Test. Epoch 99. Iter 41/68, IoU = 0.82
# Test. Epoch 99. Iter 42/68, IoU = 0.82
# Test. Epoch 99. Iter 43/68, IoU = 0.82
# Test. Epoch 99. Iter 44/68, IoU = 0.82
# Test. Epoch 99. Iter 45/68, IoU = 0.83
# Test. Epoch 99. Iter 46/68, IoU = 0.82
# Test. Epoch 99. Iter 47/68, IoU = 0.83
# Test. Epoch 99. Iter 48/68, IoU = 0.83
# Test. Epoch 99. Iter 49/68, IoU = 0.83
# Test. Epoch 99. Iter 50/68, IoU = 0.83
# Test. Epoch 99. Iter 51/68, IoU = 0.83
# Test. Epoch 99. Iter 52/68, IoU = 0.83
# Test. Epoch 99. Iter 53/68, IoU = 0.83
# Test. Epoch 99. Iter 54/68, IoU = 0.83
# Test. Epoch 99. Iter 55/68, IoU = 0.83
# Test. Epoch 99. Iter 56/68, IoU = 0.82
# Test. Epoch 99. Iter 57/68, IoU = 0.82
# Test. Epoch 99. Iter 58/68, IoU = 0.82
# Test. Epoch 99. Iter 59/68, IoU = 0.82
# Test. Epoch 99. Iter 60/68, IoU = 0.83
# Test. Epoch 99. Iter 61/68, IoU = 0.83
# Test. Epoch 99. Iter 62/68, IoU = 0.83
# Test. Epoch 99. Iter 63/68, IoU = 0.82
# Test. Epoch 99. Iter 64/68, IoU = 0.83
# Test. Epoch 99. Iter 65/68, IoU = 0.82
# Test. Epoch 99. Iter 66/68, IoU = 0.82
# Test. Epoch 99. Iter 67/68, IoU = 0.82
# Test. Epoch 99. Iter 68/68, IoU = 0.82

# %% [markdown]
# # Bing Huts

# %% [markdown]
# Rename the files in the dataset to have the format *_000.png*

# %%
#!/usr/bin/python3

import shutil
import os
import re

sourcedir = "/content/DSAC/dataset/single_buildings/"; number_ofdigits = 3; extensions = (".png", ".jpeg")


files = os.listdir(sourcedir)
for item in files:
    if item.endswith(extensions):
        name = re.compile(r'(\d{1,3})').split(item) # item.split("."); 
        zeros = number_ofdigits-len(name[1])
        newname = name[0]+ str(zeros*"0") + name[1] + name[2]
        #print("oldaname:" + str(newname))
        shutil.move(sourcedir+"/"+item, sourcedir+"/"+newname)

# %%
# %%time

# %run main_bing.py -i "./dataset/single_buildings/"
# Out:
# Namespace(inputdatapath='./dataset/single_buildings/', outputfilename=None, verbose=True)
# ./dataset/single_buildings/
# /content/DSAC/main_bing.py:100: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   this_im  = scipy.misc.imread(data_path+'building_'+str(i).zfill(3)+'.png')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /content/DSAC/main_bing.py in <module>()
#      99     [GT[:,0,i], GT[:,1,i]] = interpolate.splev(np.linspace(0, 1, L), tck)
#     100     this_im  = scipy.misc.imread(data_path+'building_'+str(i).zfill(3)+'.png')
# --> 101     images[:,:,:,i] = np.float32(this_im)/255
#     102     img_mask = scipy.misc.imread(data_path+'building_mask_' + str(i).zfill(3) + '.png')/65535
#     103     masks[:,:,0,i] = img_mask
#
# ValueError: could not broadcast input array from shape (64,64,3) into shape (80,80,3)
# CPU times: user 18.2 ms, sys: 57.4 ms, total: 75.6 ms
# Wall time: 79.7 ms

# %%
from pathlib import Path

BASE_DIR = Path().resolve()
data_path = BASE_DIR.joinpath("./dataset/single_buildings/")

# %%
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   git-lfs
# 0 upgraded, 1 newly installed, 0 to remove and 8 not upgraded.
# Need to get 2,129 kB of archives.
# After this operation, 7,662 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 git-lfs amd64 2.3.4-1 [2,129 kB]
# Fetched 2,129 kB in 0s (15.1 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package git-lfs.
# (Reading database ... 131183 files and directories currently installed.)
# Preparing to unpack .../git-lfs_2.3.4-1_amd64.deb ...
# Unpacking git-lfs (2.3.4-1) ...
# Setting up git-lfs (2.3.4-1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Updated git hooks.
# Git LFS initialized.

# %%
# !git lfs track "*.png"
# !git lfs track "*.zip"
# !git lfs track "*.jpg"
# !git lfs track "*.tif"
# !git lfs track "*.png"
# Out:
# Tracking "*.png"
# Tracking "*.zip"
# Tracking "*.jpg"
# Tracking "*.tif"
# "*.png" already supported

# %%
! du -chd 1 | sort -h
# ! du -hs $pwd
# Out:
# 40K	./__pycache__
# 57M	./models
# 340M	./dataset
# 391M	./.git
# 787M	.
# 787M	total

# %%
! git add -A

# %%
! git commit -m "dataset upload"
# Out:
# On branch master
# Your branch is ahead of 'origin/master' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git push -u origin master
# Out:
# Git LFS: (0 of 2489 files) 0 B / 332.49 MB
# batch response: @IslamAlam can not upload new objects to public fork IslamAlam/DSAC
# batch response: @IslamAlam can not upload new objects to public fork IslamAlam/DSAC
# batch response: @IslamAlam can not upload new objects to public fork IslamAlam/DSAC
# batch response: @IslamAlam can not upload new objects to public fork IslamAlam/DSAC
# batch response: @IslamAlam can not upload new objects to public fork IslamAlam/DSAC
# batch response: @IslamAlam can not upload new objects to public fork IslamAlam/DSAC
# batch response: @IslamAlam can not upload new objects to public fork IslamAlam/DSAC
# batch response: @IslamAlam can not upload new objects to public fork IslamAlam/DSAC
# batch response: @IslamAlam can not upload new objects to public fork IslamAlam/DSAC
# batch response: @IslamAlam can not upload new objects to public fork IslamAlam/DSAC
# batch response: @IslamAlam can not upload new objects to public fork IslamAlam/DSAC
# batch response: @IslamAlam can not upload new objects to public fork IslamAlam/DSAC
# batch response: @IslamAlam can not upload new objects to public fork IslamAlam/DSAC
# batch response: @IslamAlam can not upload new objects to public fork IslamAlam/DSAC
# batch response: @IslamAlam can not upload new objects to public fork IslamAlam/DSAC
# batch response: @IslamAlam can not upload new objects to public fork IslamAlam/DSAC
# batch response: @IslamAlam can not upload new objects to public fork IslamAlam/DSAC
# batch response: @IslamAlam can not upload new objects to public fork IslamAlam/DSAC
# batch response: @IslamAlam can not upload new objects to public fork IslamAlam/DSAC
# batch response: @IslamAlam can not upload new objects to public fork IslamAlam/DSAC
# batch response: @IslamAlam can not upload new objects to public fork IslamAlam/DSAC
# batch response: @IslamAlam can not upload new objects to public fork IslamAlam/DSAC
# batch response: @IslamAlam can not upload new objects to public fork IslamAlam/DSAC
# batch response: @IslamAlam can not upload new objects to public fork IslamAlam/DSAC
# batch response: @IslamAlam can not upload new objects to public fork IslamAlam/DSAC
# error: failed to push some refs to 'git@github.com:IslamAlam/DSAC.git'

# %%
# !git pull
# Out:
# Already up to date.

# %%
! git reset HEAD~
